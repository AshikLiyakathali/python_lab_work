# %% [markdown]
# # Lab-P10: Files and Formats for Youtube Data
#
# In this lab, you'll get practice with files and formats, in preparation for p10. If you haven't already done so, make sure to download data.zip from Github and extract it to your lab10 folder.

# %% [markdown]
# ## File Vocabulary
#
# For p10, you'll need to be familiar with the following file-related terms to know what we're asking you to do.
#
# Before we get started with the assignment, let's talk about the distinction between these terms, which will become important as we go along.
#
# * **Directory:** a collection of files and directories.  "Folder" is a less-technical synonym you've doubtless heard frequently.
#
# * **File Name:** a name you can use for a file if you know what directory you're in.  For example, `movies.csv`, `test.py`, and `main.ipynb` are examples of file names.  Note that different files can have the same name, as long as those files are in different directories.
#
# * **Path:** a more-complete name that tells you the file name AND what directory it is in. For example, `p8/main.ipynb` and `p9/main.ipynb` are examples of path names on a Mac, referring to a file named `main.ipynb` in the p8 directory and a second file with the same name in the p9 directory, respectively. Windows uses back-slashes instead of forward slashes, so on a Windows laptop the paths would be `p8\main.ipynb` and `p9\main.ipynb`. There may be more levels in a path to represent more levels of directories. For example, `courses\cs220\p8\test.py` refers to the test.py file in the p8 directory, which is in the cs220 directory, which is in the courses directory.
#
# * **Absolute vs Relative Path:** A relative path specifies a location on your computer based on the current working directory (in this case, the folder you ran the jupyter notebook in). On the other hand, an absolute path specifies the location based on the root folder on your computer. As an example of both, the relative path to the `channel_ids1.json` file in the `data` folder would be `data/channel_ids1.json`, but the absolute path would look something like `C:/Users/Tim/Documents/Lab10/data/channel_ids1.json`

# %% [markdown]
# You will also need to import the following libraries to complete the lab and project. We've gone ahead and filled them out for you:

# %%
# import statements

import os
import csv
import json

# %% [markdown]
# ## Segment 1: File and Directories
#
# ### Task 1.1 Sort the output of os.listdir()
# `os.listdir` can be used to list the files of a directory. For example, `os.listdir(".")` would list the files in the current directory.
#
# Create a variable named `data_files` and save the names of the files in the "data" directory to it. Then, **sort** `data_files` based on the file's name.
#
# **Note:** You should *always* sort the output of `os.listdir()` because the output of `os.listdir()` is **OS dependent**. This means that if you run this code on a different OS, the paths might be sorted in a different order, which could lead to different results.

# %%
# TODO: read the names of the files in the "data" directory
# TODO: sort the files by name
# TODO: display data_files.

data_files = os.listdir("./data")

data_files.sort()

data_files
# Out:
# ['.channel_ids0.json',
#  '.hidden.txt',
#  'channel_ids1.json',
#  'channel_ids2.json',
#  'channel_ids3.json',
#  'channel_ids4.json',
#  'channel_ids5.json',
#  'comment_data1.csv',
#  'comment_data2.csv',
#  'comment_data3.csv',
#  'comment_data4.csv',
#  'comment_data5.csv',
#  'video_data.csv',
#  'video_data_shuffled.csv',
#  'video_ids.json']

# %% [markdown]
# Your output should look like this...
#
# ```python
# ['.channel_ids0.json',
#  '.hidden.txt',
#  'channel_ids1.json',
#  'channel_ids2.json',
#  'channel_ids3.json',
#  'channel_ids4.json',
#  'channel_ids5.json',
#  'comment_data1.csv',
#  'comment_data2.csv',
#  'comment_data3.csv',
#  'comment_data4.csv',
#  'comment_data5.csv',
#  'video_data.csv',
#  'video_data_shuffled.csv',
#  'video_ids.json']
# ```

# %% [markdown]
# ### Task 1.2 Filter out `data_files` that start with "."

# %% [markdown]
# Now, filter `data_files` so that it does not contain files that start with a "."
#
# Your output should be the same as Task 1.1, but without `.hidden.txt` and `.channel_ids0.json`

# %%
# TODO: Filter out file names that begin with a "."

data_files = [file for file in data_files if file[0] != "."]

data_files
# Out:
# ['channel_ids1.json',
#  'channel_ids2.json',
#  'channel_ids3.json',
#  'channel_ids4.json',
#  'channel_ids5.json',
#  'comment_data1.csv',
#  'comment_data2.csv',
#  'comment_data3.csv',
#  'comment_data4.csv',
#  'comment_data5.csv',
#  'video_data.csv',
#  'video_data_shuffled.csv',
#  'video_ids.json']

# %% [markdown]
# ### Task 1.3 Use os.path.join() to create a path

# %% [markdown]
# Tasks 1.1 and 1.2 asked you to list files in the current directory, but sometimes we may be interested in files in other locations. In this assignment, whenever we say "path", we are implying "relative path". Also, "path" and "pathname" are used interchangeablely. We will not be the using absolute path.
#
# For this Task, create a variable named `specific_file_path` for the file `channel_ids1.json` located in the `data` folder. Use `os.paths.join` to join the directory name with the file name.
#
# **Note:** Always join paths using `os.path.join`. Never use the regular string `join` method, because the paths
# are **OS dependent**. If you hardcode `/` or `\` in your paths, your code will not work on other computers.

# %%
specific_file_path = os.path.join("data", "channel_ids1.json")

specific_file_path
# Out:
# 'data/channel_ids1.json'

# %% [markdown]
# Expected output for Windows users: `data\channel_ids1.json` or `data\\channel_ids1.json`
#
# Expected output for Linux/Mac users: `data/channel_ids1.json`

# %% [markdown]
# ### Task 1.4 Create a function that list files at a path location
#
# Using Tasks 1.1 and 1.2, write a function that returns a list of the files at a path location, ignoring files that start with a ".". Files should be sorted alphabetically.

# %%
def list_files_in(pathname):
    """
    Given a (relative) path called pathname, return a list of files at this path. 
    Make sure to exclude files that start with a "." from your list, 
    and that your list of files is sorted alphabetically before you return it.
    """
    
    files_list = os.listdir("./" + pathname)
    
    files_list.sort()
    
    files_list = [file for file in files_list if file[0] != "."]
    
    return files_list

list_files_in("data")
# Out:
# ['channel_ids1.json',
#  'channel_ids2.json',
#  'channel_ids3.json',
#  'channel_ids4.json',
#  'channel_ids5.json',
#  'comment_data1.csv',
#  'comment_data2.csv',
#  'comment_data3.csv',
#  'comment_data4.csv',
#  'comment_data5.csv',
#  'video_data.csv',
#  'video_data_shuffled.csv',
#  'video_ids.json']

# %% [markdown]
# Your output should be the following...
#
# ```python
# ['channel_ids1.json',
#  'channel_ids2.json',
#  'channel_ids3.json',
#  'channel_ids4.json',
#  'channel_ids5.json',
#  'comment_data1.csv',
#  'comment_data2.csv',
#  'comment_data3.csv',
#  'comment_data4.csv',
#  'comment_data5.csv',
#  'video_data.csv',
#  'video_data_shuffled.csv',
#  'video_ids.json']
# ```

# %% [markdown]
# Furthermore, if any of the following assertions fail, check your code!

# %%
assert '.hidden.txt' not in list_files_in('data')
assert list_files_in("data")[0] == 'channel_ids1.json'
assert list_files_in("data")[1] == 'channel_ids2.json'
assert list_files_in("data")[-1] == 'video_ids.json'

# %% [markdown]
# ### Task 1.5 Create a function that outputs relative paths to files
#
# `list_files_in` takes in a path and returns a *list of file names*, but you can't open those files unless you join them with their relative path. Create a function called `list_paths_in` that creates a *list of pathnames* to those files.
#
# Be sure to use `os.path.join` like in Task 1.3.

# %%
def list_paths_in(pathname):
    """
    Gets a list of files in pathname directory and generates relative paths to all the files,
    using os.path.join function.
    Returns a list of relative paths to each file inside pathname directory.
    """
    files = list_files_in(pathname)
    
    specific_file_path = [os.path.join(pathname, file) for file in files]

    return specific_file_path

list_paths_in("data")
# Out:
# ['data/channel_ids1.json',
#  'data/channel_ids2.json',
#  'data/channel_ids3.json',
#  'data/channel_ids4.json',
#  'data/channel_ids5.json',
#  'data/comment_data1.csv',
#  'data/comment_data2.csv',
#  'data/comment_data3.csv',
#  'data/comment_data4.csv',
#  'data/comment_data5.csv',
#  'data/video_data.csv',
#  'data/video_data_shuffled.csv',
#  'data/video_ids.json']

# %% [markdown]
# Your output should be the following (with `\\` being whatever file seperator your OS uses)...
#
# ```python
# ['data\\channel_ids1.json',
#  'data\\channel_ids2.json',
#  'data\\channel_ids3.json',
#  'data\\channel_ids4.json',
#  'data\\channel_ids5.json',
#  'data\\comment_data1.csv',
#  'data\\comment_data2.csv',
#  'data\\comment_data3.csv',
#  'data\\comment_data4.csv',
#  'data\\comment_data5.csv',
#  'data\\video_data.csv',
#  'data\\video_data_shuffled.csv',
#  'data\\video_ids.json']
# ```

# %% [markdown]
# ## Segment 2: JSON file format
#
# ### Task 2.1 Load JSON Data
# Given the function `read_json` from lecture, load the data in `channel_ids1.json` into a variable called `json_data`. Remember, `channel_ids1.json` is located in the `data` directory.
#
# Use [Lecture 19 (JSON)](https://www.msyamkumar.com/cs220/s22/materials/lecture_ppts/lec_19_S22.pdf) as reference.

# %%
def read_json(path):
    with open(path, encoding="utf-8") as f:
        return json.load(f) # dict, list, etc

# TODO: invoke read_json - make sure to use os.path.join to generate the releative path to "channel_ids1.json"

json_data = read_json(os.path.join("data", "channel_ids1.json")) 

json_data
# Out:
# {'UCpi8TJfiA4lKGkaXs__YdBA': 'The Try Guys',
#  'UCERUmrDh9hmqEXBsnYFNTIA': 'DashieGames',
#  'UCIOrUVVyfoWnmcwG6IwCULQ': 'Loserfruit',
#  'UCR_J_SntqJh5eXw66d5hJxA': 'Matthew Beem',
#  'UCNye-wNBqNL5ZzHSJj3l8Bg': 'Al Jazeera English',
#  'UCHRTfR2r0Ss3UjFyw7gSA-A': 'Ryguyrocky',
#  'UCCbDhjYocBWYPTqoUONCPRA': 'Allie Schnacky',
#  'UCuN9hYw2RpoAW8rZ3VK3isA': 'NASCAR',
#  'UCugJq15BiB-c1NDYPHiznWQ': 'Total War',
#  'UCXVxMuWK6l_pCyxEk07EIRw': 'STARZ',
#  'UCRijo3ddMTht_IHyNSNXpNQ': 'Dude Perfect',
#  'UCEdTLCzuunuFLbAVfD1-Jpw': 'The Blondie Boys Shorts',
#  'UCq3QBWXCKvMnltjwqWuB5bQ': 'Cam&Fam',
#  'UCjbhchq-wEJBNJ-_faXsOmA': 'INTHESOOP_TV',
#  'UCjmJDM5pRKbUlVIzDYYWb6g': 'Warner Bros. Pictures',
#  'UC1T0JN1hhHfNsiKtqKn_dEQ': 'Sarah Schauer',
#  'UCA19mAJURyYHbJzhfpqhpCA': 'Action Lab Shorts',
#  'UCja8sZ2T4ylIqjggA1Zuukg': 'CBS Sports HQ',
#  'UC9PIn6-XuRKZ5HmYeu46AIw': 'Barely Sociable',
#  'UCXOE3YlluOUu_-5DdUUbAtw': 'WSOCTV9',
#  'UCUKi4zY5ETSqrKAjTBgjM-g': 'sWooZie',
#  'UCqZQlzSHbVJrwrn5XvzrzcA': 'NBC Sports',
#  'UCXcMEuLWTxA2D8IZcfouBiA': 'Davidjustinn',
#  'UCwx2yZG4irNLMDBuB-JGxMw': 'TapWater',
#  'UClOf1XXinvZsy4wKPAkro2A': 'PlayOverwatch',
#  'UCeBnbqt4VRhotq2TQjkIi2A': 'LaurenzSide',
#  'UCSo19KhHogXxu3sFsOpqrcQ': 'TUDN USA',
#  'UCkDtCKtPKlsg-gJO_m5D0mQ': 'Telepurte',
#  'UC-SV8-bUJfXjrRMnp7F8Wzw': 'Roman Atwood Vlogs',
#  'UCJcQeT8LADOXRROXCGM4dRg': 'TheCrazyGorilla',
#  'UCKaCalz5N5ienIbfPzEbYuA': 'Jordan Matter',
#  'UCF9imwPMSGz4Vq1NiTWCC7g': 'Paramount Pictures',
#  'UCY30JRSgfhYXA6i6xX1erWg': 'Smosh',
#  'UCE86oyLVAcsSkRAEWVtDUlA': '4 Shooters Only',
#  'UCe7cIhm4_RWsThRzBCXtmOQ': 'ABC11',
#  'UCOxoGn23BBHWghJelrqGkhg': 'Braydon Price',
#  'UCzMjRlKVO9XIqH_crIFpi6w': 'Skeppy',
#  'UCqseWqrl7r-hNoWme7hIfTw': 'Rebecca Rogers (Mrs. Rogers)',
#  'UCYCOimM5ykUJO4WrZD7kDeQ': 'Jaycoset',
#  'UCxl79GCsb6-xhrdQuPgnuJA': 'Acura',
#  'UCq0OueAsdxH6b8nyAspwViw': 'Universal Pictures',
#  'UCY8SLLJjWpS4sx1dEqECaIw': 'Tyler Oliveira',
#  'UC4ijq8Cg-8zQKx8OH12dUSw': 'Kara and Nate',
#  'UCnmGIkw-KdI0W5siakKPKog': 'Ryan Trahan',
#  'UCHxSZ6vUjipY6rf4bWnIJ1A': 'watchyourhaircut',
#  'UCE_--R1P5-kfBzHTca0dsnw': 'Complex',
#  'UCTz8K5TMmkQkRArybXfoVDg': 'Investment Joy',
#  'UCjpPTefVqOp_sPToSyUaEMg': 'Mr.Askick',
#  'UC1KsxDW7hhfeq5QQmFtInIw': 'julien solomita',
#  'UC0h07r_UgTD0Tc-Dn5XLX3g': 'Wisp',
#  'UC6QWhGQqf0YDYdRb0n6ojWw': 'Brooklyn and Bailey',
#  'UCDZH6sjXpWd1k9kJyXJZn9g': 'Cj Dachamp',
#  'UCPgMAS8woHJ_o_OZdTR7kcQ': 'Peacock',
#  'UCcW055_DGSkCEGWoKsW7gFQ': 'scribblejuice',
#  'UC-8zLYB2DB1fFCP3KJxe0Sg': 'MiniBloxia',
#  'UC2D-GCxeE69hCUmRwISXABw': 'Logdotzip',
#  'UChKqgm5CfsjC_bXiZlVnACA': 'Bigwunna',
#  'UCRw5sR-ZubiAr3Dxh_sJ64w': 'THE WADS',
#  'UCVJgocEWT3u49_4GtulGHnQ': 'Off Grid w/ Jake & Nicolle',
#  'UChFDOD4WPd2FgTCkSA4qzXg': "Vader's Fortress",
#  'UC7FldPQ7aT7Slikg7tZc30g': 'Mitten Squad',
#  'UCY4AlDv6wL2qhrX29iwdqAg': '2HYPE',
#  'UCUaT_39o1x6qWjz7K2pWcgw': 'Beast Reacts',
#  'UC3L9XPe0_FGfRG-CMGtBvFg': 'JxmyHighroller',
#  'UCSUf5_EPEfl4zlBKZHkZdmw': 'Danny Gonzalez',
#  'UC9tXyGZiEft9J4ZiI8dHb3Q': 'TapL',
#  'UCxDZs_ltFFvn0FDHT6kmoXA': 'bald and bankrupt',
#  'UCQ7Lqg5Czh5djGK6iOG53KQ': 'Wolves',
#  'UC6nSFpj9HTCZ5t-N3Rm3-HA': 'Vsauce',
#  'UCKQECjul8nw1KW_JzfBTP1A': 'KPRC 2 Click2Houston',
#  'UCLaduTRRWdzU8kq9AoqTRlw': 'RellGames',
#  'UCXMwCQVey4PhdWFJ6WhAVhA': 'SockStudios',
#  'UCtWIUAvZuWaNorJImG2Riqg': 'Damn Seconds',
#  'UCo00rI10S3Wpk4hVkL5IDTg': 'Alex Choi',
#  'UCJbYdyufHR-cxOuY96KIoqA': 'AMP',
#  'UC-O9o5coq8iFSVthivq__tw': 'Lexi Hensler',
#  'UCFKDEp9si4RmHFWJW1vYsMA': 'EthosLab',
#  'UCvNBXWGykQrWb7kPAn5eLUQ': 'Battlefield',
#  'UCEvC-HQ7ST5h8iC1IDgVtgw': 'Telanthric',
#  'UCBVEb6W9dMpIConICMS0B5Q': 'ImNotaCasualty',
#  'UChnGFN2LRHBq-0PM6dOaq5A': 'Bachelor Nation',
#  'UCIPPMRA040LQr5QPyJEbmXA': 'MrBeast Gaming',
#  'UCpIafFPGutTAKOBHMtGen7g': 'Gus Johnson',
#  'UCiS882YPwZt1NfaM0gR0D9Q': 'Genshin Impact',
#  'UCsEgeyBfOnGGBpjIvkDJbWg': 'Socksfor1',
#  'UCh8gHdtzO2tXd593_bjErWg': 'Doobydobap',
#  'UC_ovJB6xS99RQGIq7ik5T_A': 'Benny Soliven',
#  'UC35TiyFAjzQCyOrFt5ccbhw': 'JGGLS',
#  'UCpOXWy4Erc4UNoxI9xW-CXw': 'Steel Wool Studios',
#  'UCSJWlswfVUgyVliZaEFoaBw': 'TheSorryGirls',
#  'UCfPUcG3oCmXEYgdFuwlFh8w': 'Dingo Doodles',
#  'UCBgcPSn61UQ4l_-FvcEgLQA': 'NBC 6 South Florida',
#  'UC0Eqb484X8EiNrFLSUQVsaA': 'SoundSmith'}

# %% [markdown]
# If any of the following assertions fail, check your code!

# %%
assert json_data['UCqZQlzSHbVJrwrn5XvzrzcA'] == 'NBC Sports'
assert json_data['UCh8gHdtzO2tXd593_bjErWg'] == 'Doobydobap'
assert json_data['UCRijo3ddMTht_IHyNSNXpNQ'] == 'Dude Perfect'
assert json_data['UC6nSFpj9HTCZ5t-N3Rm3-HA'] == 'Vsauce'

# %% [markdown]
# ### Task 2.2 Handle JSONDecodeError
#
# Define the function `get_mapping` that uses the `read_json` function above.
#
# The `read_json` function can throw an error! If the JSON file is formatted incorrectly (missing a closing brace, missing a value for a key, or some other syntax error), a JSONDecodeError will occur. If you encounter a malformed JSON file like this, you should return an empty dictionary.
#
# Use a try/except to catch *only* a `json.JSONDecodeError`. See [Lecture 25 (Error Handling)](https://www.msyamkumar.com/cs220/s22/materials/lecture_ppts/lec_25_S22.pdf) for reference.

# %%
# TODO: Define this function; make sure it handles malformed JSON files! 

def get_mapping(pathname):
    """
    Given a path called pathname, load the json data at the path and return the loaded json data.
    If a json.JSONDecodeError is thrown, an empty dictionary is returned.
    """
    try:
        mapped_data = read_json(pathname) 
        
    except json.JSONDecodeError:
        mapped_data = {}

    return mapped_data

# Note: if you try to use JSONDecodeError, that won't work because it is part of the json module
# If you want to use it just as JSONDecodeError, you must use the from style of import to import it
# from the json module

# %%
# Make sure your code passes the assertions below.

mapping = get_mapping(os.path.join("data", "channel_ids2.json"))

assert mapping['UCRlEFn0L2G_DktbyvN0AZ5A'] == 'WadZee'
assert mapping['UCDVYQ4Zhbm3S2dlz7P1GBDg'] == 'NFL'
assert mapping['UC06E4Y_-ybJgBUMtXx8uNNw'] == 'TheBackyardScientist'
assert get_mapping(os.path.join("data", "channel_ids5.json")) == {}

# %% [markdown]
# This test ensures that you do not catch anything besides a `JSONDecodeError`. It's a bit fishy, so if you get `TypeError: 'NoneType' object is not callable`, try Restart and Run all. If that doesn't work, ask a TA to help.

# %%
# You don't have to understand this code. 
# Just know that, if your get_mapping is correct, this code does nothing.

old_load = json.load

try:
    json.load = None
    get_mapping(os.path.join("data", "channel_ids1.json"))
    assert False   

except AssertionError:
    print("Failed: You caught an exception besides JSONDecodeError")

except:
    pass

json.load = old_load

# %% [markdown]
# ## Segment 3: Video Data

# %% [markdown]
# ### Task 3.1: Familiarize yourself with the video data files files
#
# Examine the contents of `video_data.csv`. For example, the first two rows look like this:
#
# ```python
# [['video_id',
#   'channel_id',
#   'published_at',
#   'duration',
#   'category',
#   'tags',
#   'views',
#   'likes',
#   'dislikes'],
#  ['ex98DxvUiAc',
#   'UC94lW_-Hr_uA7RcJ3D-WPOg',
#   '2021-10-01 01:54:20',
#   '00:15:12',
#   'Comedy',
#   'danny duncan|danny duncan 69|danny duncan vlog|danny duncan pranks|danny duncan vlogs|vlogs|pranks|danny duncan tour|danny duncan florida|danny duncan merch',
#   '3250076',
#   '146039',
#   '1800']]
# ```
#
# Also examine `video_ids.json`, which contains a mapping of the video IDs to the title of the video. It looks like this:
#
# ```python
# {'ex98DxvUiAc': 'Guess Who’s Back!',
#  '8y9QnS_tMkY': 'The Ultimate "Kung Fu Panda" Recap Cartoon',
#  'IwTkLFYYBKc': 'Old Master, New Tricks! (Clash of Clans Season Challenges)',
#  ...}
# ```
#
# Our goal is to combine the data from these two files.
#
# In order to do this, we must be able to load data from CSV and JSON files.
#
# **Note:** When reading in a CSV, do not use `csv.DictReader` to read the csv files; use `process_csv`. Run the cell below, it will be used in the following tasks.

# %%
# source:  Automate the Boring Stuff with Python Ch 12

def process_csv(filename):
    exampleFile = open(filename, encoding="utf-8")  
    exampleReader = csv.reader(exampleFile) 
    exampleData = list(exampleReader)        
    exampleFile.close()  
    return exampleData

# TODO: invoke process_csv - make sure to use os.path.join 
#       to generate the relative path to "video_data.csv"

raw_video_data = process_csv(os.path.join("data", "video_data.csv"))

raw_video_data

# TODO: split the header and the data into the those variables

video_header = raw_video_data[0]

video_data = raw_video_data[1:]

# TODO: Use print function calls to display header and data's first list entry

print(video_header)
print(video_data[0])
# Out:
# ['video_id', 'channel_id', 'published_at', 'duration', 'category', 'tags', 'views', 'likes', 'dislikes']
# ['ex98DxvUiAc', 'UC94lW_-Hr_uA7RcJ3D-WPOg', '2021-10-01 01:54:20', '00:15:12', 'Comedy', 'danny duncan|danny duncan 69|danny duncan vlog|danny duncan pranks|danny duncan vlogs|vlogs|pranks|danny duncan tour|danny duncan florida|danny duncan merch', '3250076', '146039', '1800']

# %%
# TODO: invoke read_json - make sure to use os.path.join 
#       to generate the releative path to "video_ids.json"

video_ids_json = read_json(os.path.join("data", "video_ids.json"))

# TODO: display the dictionary returned by read_json

video_ids_json
# Out:
# {'ex98DxvUiAc': 'Guess Who’s Back!',
#  '8y9QnS_tMkY': 'The Ultimate "Kung Fu Panda" Recap Cartoon',
#  'IwTkLFYYBKc': 'Old Master, New Tricks! (Clash of Clans Season Challenges)',
#  '2_9LOiY9Lpc': 'Making Spiral Light',
#  'bUrxLCWy-us': 'I Highballed People on Facebook Marketplace',
#  '65yHrAJhHMk': 'Out of pocket tik toks 4',
#  'VAnS_67h1Fw': "hi (what's going on with me)",
#  'wgZes7y6Bh8': 'Meet My Boyfriend...',
#  '3iEHVVgCTPI': 'Aang Showcase – Nickelodeon All-Star Brawl',
#  'PxsGaHMQTC4': 'Realistic Golem Transforming',
#  '4P8fKd0IVOs': 'How Does The James Webb Space Telescope Work? - Smarter Every Day 262',
#  'g9pyKmmF3VM': '1500rpm Slow Motion Paint Flinger - The Slow Mo Guys',
#  'p_i-ferkaoM': 'Guess the color challenge, too high, save it for later play! ! # Funny # Party Game Challenge#shorts',
#  'tu-w3QDw46w': 'Zillow Gone Wild, Sacrifice Edition! (feat. Brittany Broski) | Sarah Schauer',
#  'lwRkRFnbMTQ': 'TotalEnergies BWF Sudirman Cup 2021 | Chia/Soh (MAS) vs Gideon/Sukamuljo (INA) | QF',
#  'WrX1aGHK1lM': 'Enter the World of Grand Cathay | Total War: WARHAMMER III',
#  'q-1HikE4b54': 'The Book Tied To 75,000 Disappearances',
#  'C8RAVJV6Je4': 'Stephen A. reacts to Joel Embiid calling Simmons’ situation ‘borderline disrespectful’ | First Take',
#  'vKTl6DczK9k': 'Jaguars vs. Bengals Week 4 Highlights | NFL 2021',
#  'itWFfuFFoSI': 'The Best Selling Consoles of All Time - Scott The Woz',
#  'g7yKe_W_nRY': 'Finding Our Makeup at a CLEARANCE STORE!',
#  '707Rhr-QD3Y': 'i have been exposed.. again..',
#  'vWT6YhSs76c': 'If Black People Were in Squid Game',
#  'iGVpcKidejI': 'You Laugh You Lose Is Even Funnier In Real Life...',
#  'V3Ql2DthLJ8': 'GENIUS INVENTIONS THAT SHOULD EXIST EVERYWHERE!! #Shorts',
#  'DjRwSlVmEbc': 'I Survived 100 Days as a PANDA in HARDCORE Minecraft!',
#  '97Z3qSSbwkY': 'Was LOST even a good show?',
#  'BDsaIzfB_qc': 'Switching CREDIT CARDS w/ Alisha Marie *no limit*',
#  'zk7_fyQDc5s': 'Taking Air-Delivery of my First Supercar!',
#  'jJie6c5vJJs': 'drunk lily & drunk michael',
#  'iTSn_mCgQ0c': '1 In A Million Coincidences! 🤯',
#  'iyM0rkoO-XI': "Dangerous Toys - Gas Powered Pogo Stick from 1960's",
#  'oCBF03d4u0o': 'How LEGO Super Mario 64 TRIGGERS You!',
#  'mraaayzfg9w': 'Mini Crewmate Kills in Squid Game | Among Us',
#  '3tWbx5YhGF0': 'can 1 pixel of water save you?',
#  '1ERTKpn9qI8': 'MY BEST FRIEND IS PREGNANT FOR A DAY!',
#  'hePyHdb6CMk': 'I Survived 100 Days as an ENDER DRAGON in Minecraft',
#  '1jrZrVGQoZ0': 'DISMANTLING A RUTHLESS CLAN - Rust',
#  'KSUWDJXPk6o': 'Trying The Squid Game Honeycomb Candy Challenge',
#  'kpNjkd4rVXM': 'Philza And Wilbur TEACH Tommy To FLY And Its SCUFFED LORE! ORIGINS SMP',
#  'tzU2P1JfEJM': 'Switching CREDIT CARDS w/ Lauren Giraldo!! *no limit*',
#  'WTyBK0w90T0': 'Brock Lesnar lays waste to Roman Reigns and The Bloodline: SmackDown, Oct. 1, 2021',
#  '0MGmz9zxBG8': 'IF I SCREAM YOU WIN $20,000!',
#  'sJ6SQBWCPcQ': 'Realistic Water in Minecraft...',
#  'tUeIM8iTx3Q': "Minecraft, But There's Custom End City Items...",
#  '9KapEXWynrA': "Inside Nina Dobrev's 1920's Spanish-Style Home | Open Door | Architectural Digest",
#  'RrwQG38ovYw': 'SURPRISED BEST FRIEND WITH A YACHT AND THIS!',
#  'dPnSpIKbgfg': 'Pranking My Guy Bestfriend 😅😂 #shorts',
#  'L5jBHzsLiwQ': 'Mini Crewmate Kills Squid Game Characters #1 - Among us',
#  'MhaZFNjaIw8': "Rosie Steals Caillou's Snickers Bar Rap #shorts",
#  '1yLK-yfM3sc': 'Kleavor Pokémon Meme Review',
#  'OrcIAKgimfk': 'She Wants Us DEAD! 💀 Dark Deception Chapter 4 (FGTeeV Telekinesis Gameplay)',
#  'wHJBH4uwNfA': 'Try Guys Get Gen Z Makeovers',
#  'H9yhnMIpRS8': 'VFX Artists React to SHANG-CHi Bad & Great CGi',
#  '6K_oo-AeNWQ': 'I Ordered Pizza. It went wrong somehow',
#  '8ghEl_ibLiI': 'I REALLY NEED YOUR HELP',
#  'uzEPvj46rGQ': 'Biden Unites Democrats Cold Open - SNL',
#  'XFZxbKmUCp0': 'Farewell, Naruto | Boruto: Naruto Next Generations',
#  'qNUTz6dk4HE': '13 Types of People in SQUID GAME',
#  'asasI0kxZrU': 'Building AUTOMATIC FARMS in Minecraft Hardcore (#52)',
#  'Sd7E_EQxy_g': 'Hermitcraft 8 Episode 14:  BETRAYING BOATEM',
#  'afCRuGS5zJo': "Film Theory: Venom's SECRET Weapon! (Venom vs Carnage)",
#  'emcfCsiIdE0': "Introducing The World's First STREET LEGAL Lamborghini Super Trofeo Evo - Unicorn V4 [4K UHD]",
#  '-u5Dzq83YOI': 'I started a War over a Piece of Paper',
#  'xXTK7Atcgio': 'Luis Suarez SCORES as Atletico Madrid dominates Barcelona | LaLiga Highlights | ESPN FC',
#  'nv6kbR-0tMQ': 'I Found the RICHEST Server in Minecraft! *millionaire*',
#  'jXxwVUYhseU': 'I have skin cancer',
#  'gXvPIdLWYQs': 'Rennes vs PSG | LIGUE 1 HIGHLIGHTS | 10/3/2021 | beIN SPORTS USA',
#  'yEHAv9_OwY0': '*JOB SIMULATOR* Mod in Among Us',
#  '2fsM4KLI7TI': 'Best Bottle Flippers Challenge',
#  'C2dj59Db1C4': 'School Board Meeting - SNL',
#  'GHkUdA68YNI': 'The Demonic Possessions of Loudun • Puppet History',
#  'EAp1piWU4pQ': 'Weekend Update: Pete Davidson on the Met Gala - SNL',
#  'dwI6JYirwzo': '1v1ing Players I Eliminated In Season 1...',
#  'qlbBVSpVhjM': 'JAMIE OLIVER FINALLY IMPRESS UNCLE ROGER?',
#  'p3c4FneCNCU': "Minecraft, But You Can't Leave The End...",
#  'laDllIpLs2s': 'I Got A 5 Ton Military Truck For My Ghost Town!',
#  '75yLWfqDTIU': 'So I Destroyed *TRYHARDS* While Using A *FACECAM* In Roblox BedWars!',
#  'eFyMO9ro9mI': 'Minecraft but all Mobs are Dragons',
#  'wVD7TB0VUVI': 'A DOUBLE FOR HWANG! | Wolves 2-1 Newcastle | Highlights',
#  '0FkYz2-KVS0': 'Version 2.2 Special Program｜Genshin Impact',
#  'PukB9J1Mih8': 'Version 2.2 "Into the Perilous Labyrinth of Fog" Trailer | Genshin Impact',
#  'ZUS8XfybkxQ': 'Real Things Said in Classrooms Pt. 31 #shorts',
#  'N9Ujzz7AQpk': 'Shaq spends $400 Million 💰 | #shorts',
#  '_Lx5VmAdZSI': 'Facebook Whistleblower Frances Haugen: The 60 Minutes Interview',
#  'DqwvyZxcW3g': 'NETS at LAKERS | NBA PRESEASON FULL GAME HIGHLIGHTS | October 3, 2021',
#  'g2rk1MA-aLU': 'Facebook, Instagram and WhatsApp down in global outage',
#  '9W74aeuqsiU': 'PFAS: Last Week Tonight with John Oliver (HBO)',
#  'A2g4u9F9i90': 'I thought the Schmid Peoplemover was impossible',
#  'aEOX3OYIkds': 'SPOOKY HELLUVA BOSS + HAZBIN HOTEL HALLOWEEN DROP!',
#  'wYoSuBUrcFQ': 'Minecraft but I battle the NOOB KING',
#  'wN_s6_S2ppU': "SEC Shorts - Alabama and Georgia get sent to the principal's office",
#  'y3VebhRs0GQ': 'Buccaneers vs. Patriots Week 4 Highlights | NFL 2021',
#  '8phM1_ODAIE': 'Countdown to Tyson Fury vs Deontay Wilder III | PBC ON FOX',
#  '4iVpjqcSzQw': 'Liverpool v. Manchester City | PREMIER LEAGUE HIGHLIGHTS | 10/3/2021 | NBC Sports',
#  'j34GWfCyC1E': '*ANGRY* IMPOSTER in Among Us',
#  'WNLRVNbNNW0': 'Dwight Howard Gets a Tech for Talking to James Harden During Flagrant Foul Review 😅😭',
#  'Q6nrP6zKhmA': 'Yes, that IRS letter you got in the mail is legit | WSOC-TV',
#  'bGIaSg9RlDU': 'what happened / the answers',
#  'hhmTrkxBNKc': 'Panthers vs. Cowboys Week 4 Highlights | NFL 2021',
#  'laRhj-bERB0': 'Fake Bartender Puts Full Size Umbrella in Customers’ Drinks',
#  'uRBsnXLLC3Y': 'Clash Royale: Get SHOCKED in Shocktober! ⚡ (New Season!)',
#  '60fbrXXIRI8': 'Billions Season 6 (2022) Official Teaser | SHOWTIME',
#  '6GM9aDU_9cE': 'ARIE RE-PROPOSES AND SURPRISES LAUREN WITH A NEW ENGAGEMENT RING !',
#  'QzjnugM8RXM': 'Cardinals vs. Rams Week 4 Highlights | NFL 2021',
#  'BiXOs0YuJvE': 'Tom Brady on Return to New England, Breaking All-Time Passing Yards Record | Press Conference',
#  'vfG6Zu3WkrA': 'BUILDING a *THANOS* ROBOT ARMY in Minecraft (Insane Craft)',
#  'bk284SXBxoo': 'Deltarune Is An Experience | Chapter 1',
#  'YEaa62uBGa0': "Halo Infinite's multiplayer is very, very, very good (Impressions)",
#  'lapFQl6RezA': 'The Insane Engineering of the 787',
#  'Ai5vNEDY8V8': 'CM Punk Goes Sneaker Shopping With Complex',
#  'Fxn9yKqz66k': "Anderson Cooper on witnessing Tony Bennett's final act",
#  'L-q6Gz_4Yqc': 'Super Smash Bros.™ Ultimate – Battling with Sora – Nintendo Switch',
#  'fNwwt25mheo': 'House Of The Dragon | Official Teaser | HBO Max',
#  '361LgylscdI': 'Super Smash Bros. Ultimate Sora Reveal Trailer',
#  'B7gKA1o31rM': "The Best Friend's Betrayal Caused By An Internet Monster ?? | Mystery & Makeup | Bailey Sarian",
#  'nzWLvjloblc': 'WARRIORS at TRAIL BLAZERS | NBA PRESEASON FULL GAME HIGHLIGHTS | October 4, 2021',
#  'Gj45dMUaLbc': 'THEY ACTUALLY ADDED SORA TO SMASH ULTIMATE',
#  'EmwWVGm6P_c': 'I Cheated with a "FAKE" Professional Builder in a Building Competition...',
#  'qlKTNK7HKic': 'Peacemaker | Exclusive Clip | HBO Max',
#  '3Ic1s8wELrc': 'SQUID GAME: THE VIDEO GAME!',
#  'gG1mjH2Dd6k': 'Smart Appliances, Gadgets For Every Home 🤩 Versatile Utensils, Kitchen, Makeup, Beauty #Shorts',
#  'Ncs06UwPe2Y': 'JoJo Siwa’s Argentine Tango – Dancing with the Stars',
#  'VTVX9xw9OL0': 'Ken Block Shreds  Audi  e-tron Vision GT Prototype & 11,500rpm Audi V8 DTM Car',
#  'e0ogNfICYek': 'TOKYO REVENGERS = BLACK AIR FORCE ENERGY THE ANIME 2',
#  'tivlrT6TSHA': 'KINGDOM HEARTS 20th Anniversary Trailer',
#  'ddZzhumKs6k': 'Knot',
#  'sJ78CXTjtqE': "'Get us out of this horrible mess': Brian Laundrie's sister pleads for him to surrender to police",
#  'f-1Pkce_jK0': '$10 DATE VS $10,000 DATE! - Merrell Twins',
#  'gMbUeO4iGhY': 'Why SpaceX Cares About Concrete',
#  'foyDzdFbCmA': '[In the SOOP BTS ver. Season 2] Official Teaser 2',
#  'I1Rei-EpAB8': 'Behind The Set Of Squid Game',
#  'zoXwtMbAqWI': 'How One Mistake Changed The Entire NBA',
#  'ynhNuSs2Xs0': "TOOK OUR BESTFRIENDS ON A YACHT! **Elsy's Bday**",
#  '0lUesZzjO00': 'Doctor Reacts to Severe Eczema Problems #shorts #eczema',
#  'gF69voHU_ys': 'A Mukbanger Ate 1 Gallon Pickles. This Is What Happened To Her Brain.',
#  'BX-YLG7wQmA': 'Buying The Bass Pro Shops FOUR-WHEELER! Is it really JUNK?',
#  'z4jlhW4Ws2s': 'Venom 2 - Cosmonaut Quickie',
#  'as2u_EGqyqE': 'I AM IN PAIN!',
#  'NvXRgTj4wG4': 'HAWKS at HEAT | NBA PRESEASON FULL GAME HIGHLIGHTS | October 4, 2021',
#  'kbgUCVwbW3Y': 'STADE RENNAIS FC - PARIS SAINT-GERMAIN (2 - 0) - Highlights - (SRFC - PSG) / 2021-2022',
#  '2yNnklW5HZU': "Highlights: Liverpool 2-2 Man City | Salah's sensational strike in thrilling draw",
#  'cR9J_lRPzYc': 'Højbjerg goal & two Son assists secure return to winning ways | Highlights: Spurs 2-1 Aston Villa',
#  '3FRN4ZkYKho': 'pay to win squid games',
#  'xPLDmGVHQW0': 'Do you mind wearing a mask? 💀',
#  'XH4Y8rziMg0': 'A Month In The Life Of Tom Simons',
#  'qo9Ri1qPInM': 'The Squid Game Cast Reveals All Including Origin of The Red Light, Green Light Doll | Tonight Show',
#  'l0bzbVewmfY': 'Minecraft, But I Add A Marshmallow Every Minute...',
#  'ngTnjhV1fHs': 'LAKERS at SUNS | NBA PRESEASON FULL GAME HIGHLIGHTS | October 6, 2021',
#  'PyLy4MgZXw0': 'SURVIVING SQUID GAME in GTA 5',
#  '7wVXO3Z7q2k': 'I made a custom mod in minecraft with your ideas',
#  'gs0rZx309h4': 'Insanely Realistic Minecraft (wow)',
#  'CVl0hTaIOOw': 'Yankees vs. Red Sox AL Wild Card Game Highlights (10/5/21) | MLB Highlights',
#  'WRqYkw_NRT8': 'Cardinals vs. Dodgers NL Wild Card Game Highlights (10/6/21) | MLB Highlights',
#  '9SQeFvp4rY0': "Nelly Delivers Turned Up Performance Medley Of His Biggest Hits | Hip Hop Awards '21",
#  's8TM6D_jLsU': 'Tyson Fury vs Deontay Wilder III | FINAL PRESS CONFERENCE | PBC ON FOX',
#  'Vh8Hg7U2eFg': 'First Big Race with The Cummins Mustang',
#  'rrpYKmU--10': 'AMP HIDE AND SEEK AT THE AMP MANSION',
#  't2AB05DypWk': 'First To Raid Island Wins $100,000!',
#  'zNtNTpCVCbE': 'First Look at The Real Housewives of Beverly Hills Season 11 Reunion | Bravo',
#  'OBTs01UT6ec': 'He threw this into the stratosphere 😱| #Shorts',
#  '4Rjxj_5Y5go': 'Bailey & Asa GET MARRIED! | Behind the Scenes BTS',
#  'Jk7OQpfxCe8': 'BEING A PARENT FOR A DAY',
#  '02G9UKwkpEY': 'Minecraft, But I Add A Marshmallow Every Minute... - Extra Scenes',
#  'Btv-d7SkoG8': 'She Will NEVER Forgive ME!!',
#  'QmkUHwA-IXI': 'This Man Has The Longest Nails In The World! 🤯',
#  'Dxnr2FAADAs': 'Take a look inside Steam Deck™!',
#  'QsOrrd7HM_s': 'Tyson Fury v Deontay Wilder 3: Full Final Press conference',
#  '94eqq_wZdYM': 'Everyday Objects But MINI',
#  'AE9tZ1sfcFE': "DC Young Fly, Karlous Miller & Chico Bean Pay Homage To Rap Legends | Hip Hop Awards '21",
#  'CVsldjBMb3I': '[TF2] Scream Fortress XIII UNBOXING!! (CRAZY LOOT!! (UNUSUAL?!?!? (GONE FISHING)))',
#  'KpNA2habe1c': 'Teaching my Coworker how to make rolled ice cream',
#  'UIGI5PxvzEs': 'He couldn’t trade in his #phone cause of Bloated battery😱 #shorts #samsung #android #iphone13 #ios',
#  '-Ba4QVAE4q0': '3 True Disturbing October Horror Stories',
#  '87lWco0ChoA': 'BuzzFeed Unsolved: Supernatural • Season 7 Trailer',
#  '5rY6sMfX8P0': 'Keith Has Cancer',
#  '5e8apSFDXsQ': 'CYRANO | Official Trailer | MGM Studios',
#  'Ldcs4Venq1Q': 'If People Had Instant Butlers.',
#  '6MEYdCUfQpc': 'I Won SQUID GAME In GTA 5! (Mods)',
#  'JXUz8Js8Weg': 'What a DISGRACE',
#  'MbWq-EwUy_M': 'Dice Stacks from $1 to $100',
#  'SrLSYrQDFFY': 'Italians reacting to ketchup on pasta 😱🇮🇹 #shorts',
#  't9-VPmOMznk': 'So I beat Roblox Squid Game..',
#  'f64eYElIWPU': 'Joe & Serena Get Engaged 💍 | Bachelor In Paradise',
#  'lD19jNPXYEo': 'Minecraft - Last Life #3: Frightening Exploit Tactics',
#  'RAoUdFDEUnM': "I Built SpongeBob's House In My Backyard",
#  '0xn2RKnMhlc': 'Can 4 Guys Beat A Competitive Hot Dog Eater?  (ft. Matt Stonie)',
#  'Kdmm362PTo8': 'Freddy & Friends: On Tour Episode 3',
#  'KU2EVVhfe44': 'POV You Are The Gatekeeper... Again (Part 2)',
#  '4p8tWdEIdho': '"I would train AJ to beat Usyk for free!" Tyson Fury on Joshua fight and Wilder trilogy',
#  'BN_BHcfxPQU': 'GTA 5 Races where everything goes wrong',
#  'cEh85Xt5Rr8': 'CAVALIERS at BULLS | NBA PRESEASON FULL GAME HIGHLIGHTS | October 5, 2021',
#  'CMQAM-nfuBw': 'Tyson Fury vs. Deontay Wilder 3 • FULL GRAND ARRIVALS IN LAS VEGAS • T-Mobile Arena',
#  'mCdubmKVf8g': "Sasuke's NEW Arm And Rinnegan - Boruto Destroys Sasuke's Rinnegan! Why Naruto & Sasuke Were NERFED.",
#  'UUhxtitgJFo': 'Lil Baby & Lil Durk "Hats Off" ft. Travis Scott (Music Video)',
#  '1QzsgYY9leI': 'Raiders vs. Chargers Week 4 Highlights | NFL 2021',
#  'tqSwVr89fRA': 'Bubba Wallace makes history in Talladega! | Extended Highlights | NASCAR',
#  'jWIAoAzb4tk': 'The Haunting of Shane Dawson',
#  'rkiu8IGjG5Q': 'i played squid game..',
#  'NtNDgOWN_2o': 'Game Theory: I Solved The Wilbur Soot ARG... And It Only Took 3 Years!',
#  'KCVjsbmVi0E': 'Jon Bernthal Gets Punished By Spicy Wings | Hot Ones',
#  'qxI-Ob8lpLE': "Schlatt's Chips Tier List",
#  '4q6UGCyHZCI': 'RESIDENT EVIL: WELCOME TO RACCOON CITY - Official Trailer (HD) | In Theaters Nov 24',
#  '8IBg0D5aUhs': 'Apex Legends Monsters Within Event',
#  'ZZxF5cs3ZjM': 'Surprise Announcement',
#  'w0HgHet0sxg': 'DUNE – FINAL TRAILER',
#  'uDH_o8RqR0Y': 'Inside Perm 36: The Last Gulag',
#  'FatRcVCV6IY': 'No Time to Die - Movie Review',
#  '_AzXUuM97Qk': "The Battlefield 2042 Beta is really fun but there's a problem...",
#  '35gEQuOWxow': 'Minecraft Live 2021: Are You Ready?',
#  'XgZcEO3JKHk': 'What is the Safest Base Possible in Minecraft?',
#  'U2SNwtE-0Us': 'Nardo Wick - Who Want Smoke?? ft. Lil Durk, 21 Savage & G Herbo (Directed by Cole Bennett)',
#  '3eRRwcTdhtE': 'The Legend of Vox Machina - Title Sequence | Prime Video',
#  '0XYQHB5Oy20': 'Madonna on Madame X and Getting Into Good Trouble | The Tonight Show Starring Jimmy Fallon',
#  'JSYSVcn60ik': 'The Legend of Vox Machina - NYCC Live Read with Animation | Prime Video',
#  'U2D1GHHMb9g': 'Trope Talk: Fridging',
#  'uoY-O8D9F6I': 'This Man Can WALK FASTER Than YOU CAN RUN!',
#  'RtYND6JaLe0': 'FULL FORSAKEN EASTER EGG GUIDE: Cold War Zombies Easter Egg Walkthrough Tutorial',
#  'Oxa1CUR2KzM': 'Minecraft but PROS rule the world',
#  '1vNRxP-oLOY': 'Did I get it?!🤯🎮#xbox#playstation',
#  'V3Dv2hnZTDs': 'Jumping SQUID GAME CARS Across ENTIRE MAP In GTA 5! (Mods)',
#  'X3e_4Ns58pE': 'Playing SQUID GAME In Minecraft!',
#  'Sc1YMgz9Fys': 'HERE I COME',
#  'dJzHcEDddW0': 'No One Lives Under the Lighthouse Review',
#  'XDt12oC0dEk': 'The Worst Day of My Life..',
#  'RL6vMvIF2B8': '5 Fake Mexicans vs 1 Real Mexican | Guess the Liar',
#  'TnBv-37zN50': 'When Searching Your Dads Phone Takes A Weird Turn',
#  'vEETehA9_Hc': 'How Sakurai Got Sora into Smash',
#  '2_wJfTsOzjc': 'I Competed in Squid Game...',
#  '8Za7hj3GY5o': 'Did you know that in POLICE ACADEMY...',
#  'F0dfaONvhCQ': 'My Pregnancy Story (Why I Kept It a Secret…)',
#  'wujAEGPVVuA': 'THE DAY THAT CHANGED MY LIFE',
#  'ALRtRJ1NQqc': 'Backyard Vibes',
#  '92WQjz9qStQ': 'If I lose a boss fight, the video ends 2 (Genshin Impact)',
#  'BsKtDfMjHEo': 'Rams vs. Seahawks Week 5 Highlights | NFL 2021',
#  'leQc25bA3jg': 'I know your favourite athlete?🤔🥇#mindread',
#  'QQu9QpBYos4': 'LAKERS at WARRIORS | NBA PRESEASON FULL GAME HIGHLIGHTS | October 8, 2021',
#  'TYd_pT9hZrM': 'Squid Game stars take on the Dalgona Challenge [ENG SUB]',
#  '2yDp41EpvdU': 'FORTNITE SQUID GAME!',
#  'OSXbYwoCc5Y': "World's Most Dangerous Jobs!",
#  'BbzSoQCdIl8': 'Playing SQUID GAME in Minecraft!',
#  '77hrMO0ZarU': 'My Friend Betrayed me, so I Void Trapped him',
#  'WXBcZDxobo0': 'I Survived 69 Hours Using Only Minecraft Tools',
#  'ymXnK6UX5zE': 'I Survived 1,900 Days in HARDCORE Minecraft...',
#  'Hz_DslzN2IA': 'True Facts: The Mosquito',
#  'gsA6_yLOaoI': 'Recreating My Old MYSPACE Photos 🖤 WEIRDO Collection & Halloween Mystery Box REVEAL!',
#  'aRuCjdEqsa8': 'Becoming SQUID GAME Host in GTA 5! (GTA 5 Mods)',
#  'udNXMAflbU8': 'Holey Plugs, Batman! But... what are they for?',
#  '1VN420bDjVY': 'TINY VS GIANT UNBREAKABLE BOX!!',
#  'NYlVKEFmGMI': 'how Imagine Dragons got their name',
#  'JIPT9WC6Vsk': 'Star Trek: Discovery | Season 4 Official Trailer | Paramount+',
#  'c-X9C4k9wAk': 'Minecraft Mobs when you log off...',
#  'KjFxNXB5Pwo': "2b2t's Obsidian War is Getting Ridiculous",
#  'Sf6H8kSunRA': 'The Insane Engineering of the GEnX',
#  'F6fQLX0uW24': 'I bought a ABANDONED laundromat, we found $$$ inside #shorts',
#  'AwvyrO_yM4c': 'Dog Reviews Food With Son | Tucker Taste Test 22',
#  'xIebUcOxkMg': 'MURDER DRONES [OFFICIAL TRAILER]',
#  'q5HI2V7tV5I': 'Tyson Fury vs Deontay Wilder III | WEIGH-IN | PBC ON FOX',
#  'bnjcauzuIas': 'How did I start?',
#  '8moZaaNqhV8': 'How the Nintendo Switch (OLED Model) TRIGGERS You!',
#  '0JrGRiUOcfQ': 'This is the MOST Unrelatable Channel on YouTube: TROOM TROOM',
#  '3iXhVImidBo': 'Volcano forms huge delta on the ocean, its collapse likely to lead to explosions | La Palma, Spain',
#  'IWTxF9r2EaM': 'Basketball CHALLENGE = DARES *EXTREME* #shorts #challenge',
#  '2gWTmImEeXc': 'Jelly fruit Hit or Miss with Twinsfromrussia! #jellyfruit #shorts',
#  'NDk1GEkJyGs': 'LAST TO LEAVE THE POND WINS $10,000',
#  'O14UfDsNOrQ': 'Cheap vs Expensive: Bath Bomb Making for the First Time',
#  'YYukZ8hDt8I': 'TOXIC Clan vs PRO Clan.. (Roblox Bedwars)',
#  '9KWvZ-jCyqg': '19 Cool Things Minecraft Hides From You',
#  'QRu06HWdFiE': 'Magnetic Face Mask VS. 3200lb Magnet!',
#  't9u6JMLpAUw': 'Roblox BedWars LUCKY BLOCK CHALLENGE...',
#  'UeFnH1DKYIE': 'Eliminatorias Sudamericanas | Perú 2-0 Chile | Fecha 11',
#  '1V-KE-Sy7Qg': '2  DAYS OUT | CARB LOAD BEGINS, WEIGH-INS, PRESS CONFERENCE',
#  'ST1WQpQf624': 'France STUNS Belgium with last-minute winner to reach Nations League final | Highlights | ESPN FC',
#  'CyBsAI19hj4': 'VFX Artists React to Bad & Great CGi 54 (ft. SETH ROGEN)',
#  'q3EHZCa38n0': '"If you can\'t knock somebody out you better be able to box!" - Lennox Lewis on Fury vs Wilder 3!',
#  '02g_Mn_rEoU': 'Top moments from Tyson Fury vs. Deontay Wilder III | PBC on FOX',
#  'ES4S1aNsSb0': '"Sore loser! An idiot!" Tyson Fury reveals what was said between him & Deontay Wilder after huge win',
#  'oSzziSyV7vU': "Minecraft, But We're All Mutant Superhumans...",
#  'se4snb8F9ZA': 'Tyson Fury • FULL POST FIGHT PRESS CONFERENCE vs. Deontay Wilder 3 • T-Mobile Arena',
#  'A8rrr_w8rfk': 'The Dream Guy - SNL',
#  'AtW81jzLx2o': '#1 Alabama Vs Texas A&M Extended Highlights | CBS Sports HQ',
#  'Ar_qqRShHHU': 'Deontay Wilder and Tyson Fury electric walkouts | PBC ON FOX | Fury vs Wilder III',
#  'yAKgRQ0kmm4': 'Tyson Fury reacts after epic win over Deontay Wilder and he SINGS for the Las Vegas crowd!',
#  '74LaDIdx64c': 'Food Theory: Yes, You SHOULD Eat Your Pokemon!',
#  '2BCFGjsrwyY': 'Minecraft Live 2021: Introducing new mobs!',
#  'LQCQym6hVMo': 'Kim Kardashian West Monologue - SNL',
#  'aA_6z82JV8Q': 'Can 2HYPE Take a Punch from Pro Boxer Ryan Garcia? *KNOCKOUT*',
#  'rv_Y4hRDVzI': 'Anti-Social Club',
#  'ZQJCVFhNZI4': "I went UNDERCOVER in Lachlan's Game!",
#  'KwUkFly-xQU': 'Facebook Hearings Cold Open - SNL',
#  'SR1nlD_IFkg': '[In the SOOP BTS ver. Season 2] Official Teaser 3',
#  'pm702Pj0IBQ': "He Can't Keep Getting Away With This!",
#  'WrV3EAUNJ6U': "Ar'mon And Trey - Chanel ft. Queen Naija (OFFICIAL MUSIC VIDEO)",
#  'jVd2_R5FJhc': 'I Trapped 10 YouTubers on One Block',
#  'Vft6BTps8Ow': 'TOM and JERRY Mod in Among Us',
#  'f63MPkALoRA': 'This Is The MOST Satisfying Video Ever!!😱 #Shorts',
#  'Zd_C71THulw': 'Change | Marvel Studios’ Eternals',
#  '9yhfZqCX2Tk': 'CRUSHING A TOXIC CREW - Sea of Thieves',
#  'Xbwg9ZBwMCU': '[1250 Spins & 30k RC] Update 100, Narumaki Tentacion',
#  'o8UGIgfDhPs': 'What Trevor Bauer Has Been Doing',
#  'NWkOSBGqe48': '46 Minecraft Blocks Mojang Had To Remove',
#  'ACFuVRLvauI': 'SHE KILLED HER DOG TO LIVE w/@Kelsey Animated',
#  '5zv1N78Tyw4': 'Minecraft but you can Eat Mobs',
#  '94l272tK_Xk': 'Tik Toks Only Girls Understand',
#  'ZGRpHy0qoN4': 'Race Highlights | 2021 Turkish Grand Prix',
#  'WYsrIhJEhio': 'Christopher Ramirez, the 3-year-old boy missing since Wednesday in Grimes County has been found,...',
#  'cPy9u3sGk9Y': 'DID I GET IT?!🍿🤯🎥#mindread#movies',
#  'IPCbpZ6dXrs': 'If You See BUSEATER Outside Your House, RUN AWAY FAST!!',
#  'uYIQsr9vsws': 'Minecraft Live 2021: Vote for the glare!',
#  'Q3tSVS4CeW4': "Trying Troom Troom's Awful Kidnapping Hacks",
#  'T82RPTVgIz4': 'Highlights | México 3-0 Honduras | Eliminatoria Catar 2021 | TUDN',
#  'VY_equ7zL0s': 'I Survived 100 Days as a FOX in HARDCORE Minecraft!',
#  'TkOC6B3A5w0': 'We Fought a Viking Horde...',
#  'mnApD7lD2iY': 'Argentina 3-0 Uruguay I Eliminatorias a Catar 2022',
#  'OP-CQdYR71s': 'I Designed Custom Minecraft Bosses...',
#  'FTIAXw28Z3Q': "Hairdresser Reacts To People Doing 'Wolf Cuts' (as seen on tiktok)",
#  'P3Pl8hy5G2w': 'Can You Beat Fallout: New Vegas In 24 Hours?',
#  'yxiOnaTUows': 'Bills vs. Chiefs Week 5 Highlights | NFL 2021',
#  'lhEdmYFGvao': 'How To WIN EVERY SQUID GAME In GTA 5 (Scary)',
#  'CzPS719c1vo': 'OFFICIAL LABOR & DELIVERY VIDEO | BABY GIRL IS HERE! 💖',
#  'q0-OlbIif0I': 'my experience playing sports',
#  'lynVyLpeSnk': 'WOOD FIRED "HIPPIE" HOT TUB JACUZZI | Fishing & Smoking Wild Salmon - Chanterelle Hunting - Ep. 143',
#  'iI2lyqUbA0I': "Forza Horizon 5 Let's Play : Choosing Our First Car!! (Part 1) [FH5 Gameplay]",
#  '1WzZ9nH-8tw': 'Most Oddly Satisfying Video to watch before sleep',
#  'JPbd-25_Vi0': 'France beats Spain to win UEFA Nations League! | ESPN FC Highlights',
#  'I4yJ8KKGfpY': 'Giants vs. Cowboys Week 5 Highlights | NFL 2021',
#  '9J_FQUUiS0M': 'Browns vs. Chargers Week 5 Highlights | NFL 2021',
#  'KXiRxAxD-QY': 'CRAFTING a LOST INFINITY TRAP in Minecraft (Insane Craft)',
#  'jRN2QDmyXx4': 'Socksfor1 Died... (Reddit Review #13)',
#  '1305aQZDojw': 'I GOT MY WISDOM TEETH REMOVED and called my CRUSH!',
#  '7TcvY_IBG04': 'PICKING Up My FRIENDS As An UNDERCOVER UBER DRIVER!!',
#  'j_uOOGWMZfY': 'SEC Shorts - Alabama needs an ambulance',
#  '_tpxHU2NFLk': 'George Foreman on his Post Fight Wilder vs. Fury',
#  'ZEII5so6XpY': "The People's Kourt - SNL",
#  'b9n2TX-86Vk': 'The Inside Man: The SSA Scam',
#  'hDf-Gv-1ZpU': 'MOLE | Mexican Survival Guide',
#  '9x3ZnXKYNdM': 'LAST TO LEAVE THE MYSTERY MACHINE WINS $10,000',
#  'ZQecEVOlZh4': 'The GROTTO IS BACK in New Fortnite Update!',
#  'RC5EXFmzEs0': 'Deadly Mass Shooting At St. Paul, Minnesota Bar',
#  'zBelKODpgU4': 'I Built an AUTOMATIC Mob Loot Farm in Minecraft Hardcore! (#22)',
#  '_l0hpFGlGeo': 'Real Things Said in Classrooms Pt. 33 #shorts',
#  '9Ihtbm8Ztrg': 'U.S. Navy nuclear engineer, wife charged with selling nuclear submarine secrets',
#  'beToTslH17s': 'Scream | Official Trailer (2022 Movie)',
#  'Flj-KI9fOoM': "World's Smallest TV | OT 30",
#  'XdxGwg7cgjw': 'Minecraft Live 2021: Vote for the allay!',
#  'xaQJbozY_Is': 'What Dinosaurs ACTUALLY Looked Like?',
#  'a6fBD_XlSPE': 'Fortnite Squid Games (insane)',
#  'kWfy87P__v0': '*Strange* Blood Rituals By A Teen Vampire Clan, Turns Deadly? Mystery & Makeup | Bailey Sarian',
#  '2BkVf2voCr0': 'Home Sweet Home Alone | Official Trailer | Disney+',
#  '4ePYr_BM66Q': 'have you ever seen a yellow laser?',
#  'Z74O41hD_dE': 'Destiny 2: Season of the Lost - Festival of the Lost Trailer',
#  '9QyDBOsu178': 'Pokemon Pro plays the hardest official Pokemon game for the first time',
#  'dIjmRLJHi5o': 'First Take reacts to Sean Marks saying Kyrie can’t rejoin Nets until he can be a ‘full participant’',
#  'TMlwH1Up6uM': 'I have 3 names',
#  'evzsfVW-BnU': "D&D Story: Ep 22- ESCALATION TIME! [Fool's Gold]",
#  'wNVHLe8qgzw': 'Surviving 99 Years In SQUID GAME In GTA 5!',
#  'fRw61WnEdD8': 'Minecraft but I FIGHT in the PRO arena',
#  's5SqsNPWYA4': 'Binging with Babish: Dalgona from Squid Game',
#  's6KHm2_cmbE': 'Overwatch Seasonal Event | Halloween Terror 2021',
#  'laPC4ibZnSM': 'The third Deontay Wilder - Tyson Fury fight lived up to the expectations - Shannon I UNDISPUTED',
#  'GYlMID6G4Gc': 'Giving Away My Beard For Charity!',
#  'iCvNo_bJMEg': 'I RIGGED a Squid Game Fashion Show... (Fortnite)',
#  'FxQ39O0XtLo': 'Colts vs. Ravens Week 5 Highlights | NFL 2021',
#  'JNhmhw60QDk': 'Super Sponge Bros.',
#  'rqRqH30XGOk': '1v1 Against DevInTheLab ... THE FULL REMATCH !',
#  'Y-JnzpbfVkA': 'ITS NOT The FRIST TIME SHE TASTED THE RAINBOW! (Squid games in real life)',
#  'DgaRmRDtbWo': 'Mini Ice Breakers 🧊 #shorts',
#  'O2W2gUXAt78': 'My hidden talent #shorts',
#  '-PwfZcU-LQI': 'What Happened When Vader Discovered A Luke Skywalker Imposter? #shorts',
#  '6JtKkvxJiQ4': '[최초공개] ENHYPEN(엔하이픈) - 모 아니면 도(Go Big or Go Home) (4K) | ENHYPEN COMEBACKSHOW | Mnet 211012 방송',
#  'Hi2gayxePM4': 'lol im redoing my whole house ... | Making Home | EP 18',
#  'zKWIV_6LQ8c': 'Greif.',
#  'QilgLV6jbxU': 'Last Life: Episode 4 - UH OH!',
#  'HXzhcfYlKFQ': "50 Hours In A Country That Doesn't Exist On A Map (Transnistria)",
#  'eas0dYKPU5M': 'Testing Customer’s Engagement Ring (Part 3)',
#  '5NXlGgZQICs': '[최초공개] ENHYPEN(엔하이픈) - Tamed-Dashed (4K) | ENHYPEN COMEBACKSHOW | Mnet 211012 방송',
#  'FdzPV69i4Aw': 'Great Idea 💡 #shorts #tips #short',
#  'SjHHJi5Sz8s': 'Try Not To Laugh #80 - Luck of the Dice',
#  '7TDZdB0QtcQ': 'If Your White Friend Was in Squid Game',
#  '40_wdosHJaQ': 'I Was In The Funniest Minecraft Competition With Dream',
#  'z7zSQAHvH-U': 'HAIDEN DEEGAN SIGNS WITH FACTORY MONSTER ENERGY STAR YAMAHA!!',
#  '6Mk5Mj43xIk': 'Final Jeopardy! 10/11/21 Plus Exclusive Overheard On Set Clip | JEOPARDY!',
#  'AxpxI8WCXCk': 'The Rebels',
#  '6NXbU2nAUD4': 'WHAT, JUST, HAPPENED?!! 😮🎩 #shorts',
#  'VDxqKt4sZFU': 'Overtime 30 | Outtakes',
#  'PoBquo2zdGI': 'The Real Housewives Ultimate Girls Trip | Official Trailer | Peacock Original',
#  'keAOhf4FFkQ': '6 Steak Temps (Ketchup - Vampire) #shorts',
#  'jVdBhu0KgJo': 'Minecraft Live 2021: Vote for the copper golem!',
#  'eIQuuoTQIoc': 'Megan Fox & Machine Gun Kelly Ask Each Other 40 Questions | The Couples Quiz | GQ',
#  'VDZ7_PUKseA': 'REVEALING MY NEW BODY! (MOMMY MAKEOVER)',
#  'FLOcPilRw-M': 'Lakers new Big 3 looked like a "fire drill" in loss to Warriors — Skip & Shannon | NBA | UNDISPUTED',
#  'nj6SlvxChEs': 'Minecraft Manhunt but I have CUSTOM COMMANDS',
#  'fkMW60W180E': 'SWAWS | Totally Accurate Battlegrounds',
#  '3eGP6im8AZA': 'The Black Phone - Official Trailer',
#  'ZjFcB1IeJuY': 'I Cooked A Whole Wagyu Cow (ft. Guga Foods)',
#  'DYBM3myR914': 'Exandria: An Intimate History | Narrated by Matthew Mercer',
#  'R6HA8lGJ1-w': 'Minecraft Mobs if they were Parents',
#  'GlYS_wYsD44': "Trying SPICY AF Snacks ft Becky G and Manny MUA | Louie's Life",
#  'EIVvDm9rjJE': 'Chef turns Chick Fil A into… an ENCHILADA?!🤔',
#  'eSsc1K27gek': 'Battlefield Friends 2042 Teaser',
#  'G5s9D6DRLvk': 'Sarah’s Savings Plan PART 2  pam_a_cake #shorts',
#  'p4iUUjpVLM4': 'Sounds from the Sideline: Week 5 vs NYG | Dallas Cowboys 2021',
#  'XmF1fraGbJg': 'My Embarrassing Fashion Choices',
#  '22gBV3YhwFk': 'WARRIORS at LAKERS | NBA PRESEASON FULL GAME HIGHLIGHTS | October 12, 2021',
#  'CznrNHHeF8k': '"Eternal" - A Minecraft Music Video ♪',
#  'jDKWMHfy7T0': 'Avoid This College Essay Mistake',
#  'r8e-QPSF5Yc': 'Kraken @ Golden Knights 10/12/21 | NHL Highlights',
#  'KS20rs_aC5s': 'Poppy Playtime - Hug Me Let Me Squeeze Till You Go Bye Bye forever',
#  'nC7i1Kqt8iU': 'THIS TERRIFYING TOY IS CRAWLING AFTER ME IN THE VENTS.. - Poppy Playtime (Chapter 1 Ending)',
#  'JXpKSh1S91U': 'Winning EVERY SQUID GAME Against 1,000,000 RAGDOLLS',
#  'Ujev6uH63RY': 'If I get hit, it spawns random enemies (Skyrim)',
#  'lNin9Oj7bDQ': 'BANANA CREW FINALLY LINK UP FACE TO FACE FT TRAY BILLS AND CHRIS GILLY | IAMJUSTAIRI VLOGS',
#  'qKu_rKQgFjY': 'North Miami Beach Restaurant Manager Finds GPS Under SUV',
#  'g0-kd1r8Too': 'Alisal Fire grows to 8,000 acres, burns out of control in Santa Barbara County',
#  'cNG1QNQPlNE': 'Summoner Changes | FFXIV Endwalker Media Tour',
#  'iYTK_1Sq8ZQ': 'Reaper Overview | FFXIV Endwalker Media Tour',
#  's72dhTVYKtM': '$45,600 Squid Game Challenge!',
#  '8swCrPIt4nY': 'Zombies Reveal Trailer | Call of Duty: Vanguard',
#  'dfJaOg3jo1M': 'Insane Cake Cutting!',
#  'kDx5WNdbCSU': 'Megan Thee Stallion Turns Into Hot Girl Meg While Eating Spicy Wings | Hot Ones',
#  'sR0DLq2lMzU': 'Transforming My Daughter Into A Cheerleader ft/ Anna McNulty',
#  'nkMiPwL8G1w': 'Battlefield 2042 | Hazard Zone Official Trailer',
#  'R2ZFZte8YTE': 'Which Mob Am I Voting For in Minecraft Live 2021?!',
#  '65WKv51FtiU': 'El Salvador vs. México 0-2 | Rumbo al Mundial | Telemundo Deportes',
#  'lBFPpQubOiE': 'Minecraft But I Upgrade EVERYTHING - The ULTIMATE Survival World! | Part 4',
#  '34j2S_FILJw': 'I found out how deep the ocean actually is 😳🌊',
#  '4O1w9XFfZ2I': 'Squid Game (Arab Version) | Anwar Jibawi',
#  'vyXUaNhqpqE': '“Change of Plans” | Marvel Studios’ Hawkeye | Disney+',
#  'mLEZNNqcnLc': 'The End | Moving Out Vlog',
#  '4Oy9s3aHpjo': 'Money or Backflip? #shorts',
#  'uZca3-jLlFw': 'First Look at Zombies | Call of Duty: Vanguard',
#  'sr8-2gN50ug': 'Why I Changed My Mind to Have a Baby',
#  '4K_onb6zqc8': 'YES or NO (w/ CRAZY PRANKS & CHALLENGES) #shorts',
#  'm244qbMUYZU': "Stephen A. reacts to Kyrie Irving's Instagram Live about his stance on the vaccine | First Take",
#  'QTS3Rsp8j1M': "PSYCHIC READS MY TWINS' FUTURE!",
#  'n0vHo4Nf3Fg': 'Halo Infinite Competitive Settings Reveal',
#  'Q0Fy-jiahN4': 'Labor and Delivery for Baby #11',
#  'p7_TZagxjyk': 'Returning to a War-Torn Ghost Town Sealed for 50 years | Cyprus, Uncharted Ep. 1',
#  'B5B52z9-gIM': 'Do This With Your College Essays',
#  'NGMTYj6m7F8': '[aespa - Savage] Comeback Stage | #엠카운트다운 EP.729 | Mnet 211014 방송',
#  'CB3MxRVzZZw': 'Feds charge 5 in deadly shooting of Chicago rapper FBG Duck',
#  's58orudNZ94': 'Minecraft Live 2021: Vote for the next new mob!',
#  'kqUUPueWUxE': "Bailey & Asa's OFFICIAL WEDDING VIDEO",
#  'oiY8yujLo5U': 'SQUID GAME In Real Life',
#  'NEe0kkYQ9Cw': 'Letting my new coworker make rolled ice cream (part 1)',
#  'WwkzItbI65E': 'Embarrassed vs. Embarazada',
#  'd_6qa-eWmPQ': 'What Mob Should Be Added To Minecraft?',
#  'qbXCBKGKdVU': 'Using Squid Game to CHEAT in Fashion Show... (Fortnite)',
#  'bY26w4p3gEE': 'Tik Toks That Feel ILLEGAL To Watch',
#  'uMkrHwehUhA': 'Kyrie Irving is more likely to be traded than play for Nets this season — Shannon | NBA | UNDISPUTED',
#  'g6LdBAbT1Xw': 'Animal Crossing: New Horizons Direct 10.15.2021',
#  'z2sGFFXuu38': 'So I made Dance Moves control Minecraft...',
#  '8-Cz_uG2OUM': 'I Bought Every Seat On An Airplane!',
#  '3lfBDZaMqM4': 'Haunted Theories with Shane Dawson',
#  '8eBzunFJG1M': 'Worlds Most INSANE Videos',
#  'tXMXIj5nLno': 'Joe on Tyson Fury vs. Deontay Wilder 3',
#  'D6V85qfsu3g': 'I Went To An Amazon Returns Store',
#  'dDxe0vdWmU0': 'I tested them in Minecraft early and so should you...',
#  'Z_SkdXnEyNU': 'Dodgers vs. Giants NLDS Game 5 Highlights (10/14/21) | MLB Highlights',
#  'SH9sgaNQg9g': 'Minecraft Mobs if they were Superheroes',
#  'sOhDuMGBfL4': 'I sculpted a GIANT MONSTER and scared my friends...',
#  'UJzhOguEZlo': 'Halloween Kills - Movie Review',
#  'n7-RReFPXag': 'Eliminatorias | Brasil 4-1 Uruguay | Fecha 12',
#  'ffYTbzvJsr4': 'GETTING YANDERE SIMULATORS TRUE ENDING BY NOT ELIMINATING ANY RIVALS | Yandere Simulator (S Rank)',
#  'KX2DolRhv1E': "We're Building a Sleeper Ford Ranger (LS V8 Swapped)",
#  '3menRFvxja0': 'When someone walks in while you using the bathroom😭',
#  'v0gUM1FNd6g': "Addison and Amelia Reunite - Grey's Anatomy",
#  '7Shn-TJaOrQ': 'FRIDAY NIGHT FUNKIN ANIMATION COMPILATION #3',
#  'Kdo3VfD3S7U': 'Answer This Question to Get Into Harvard',
#  '52zuk_GcGUI': 'Enter the World of Tzeentch | Total War: WARHAMMER III',
#  'BlLMALH5Fzk': 'Minecraft, But You Can Upgrade TNT...',
#  'v9pprUeZRU0': 'Power Book II: Ghost | Season 2 Trailer | STARZ',
#  'Zw9Ezf43zmk': 'Lava Vs Bulletproof Glass!',
#  '3AJyg6sGBzs': 'GOOD NEWS!! COURT DAY + BABY E & ME PHOTOSHOOT!',
#  'sNsfvfEi27Y': 'Chocolate & Coffee Dry Aged Ribeye #shorts',
#  'Meaw4DlhNRE': 'RCXD Cars Are Bugged Right Now, Right? #warzone #callofduty #pipboyfresh',
#  'GbPEQHzJaw0': '30 Things You NEVER Seen In Fortnite',
#  'kDFE92gA3Ag': 'Generational Shift: New Acura Integra Reveals Manual Transmission',
#  'Z_xUiW-ozHw': 'Buccaneers vs. Eagles Week 6 Highlights | NFL 2021',
#  'p646h_jLbeM': "All 15 of Ed's cars are for sale! What's next?",
#  '2nv7qmefMqc': 'the worst part of squid game (SPOILERS)',
#  'unkqwbJAKHs': 'Stephon Marbury calls out Stephen A. for his comments on Kyrie Irving | First Take',
#  'zRCMPMGDN00': 'Curb Your Enthusiasm (2021) | Season 11 Official Trailer | HBO',
#  'Oz2CuVf1MGo': "Bun B: Pimp C Told Jay Z The TV Ain't Got No Temperature, Jay Looked At Me And Said.. Big Pimpin $1M",
#  'ZMgY-J51i54': 'Playing SQUID GAME in Real Life! △○□',
#  'Ht9v8YLy-O4': 'Minecraft Death Shuffle...',
#  'OODneEUWUQY': 'Peacemaker | Official Teaser | HBO Max',
#  'QPRiHtDLdag': 'Dream - Minecraft Death Shuffle Extra Scenes',
#  '5qcKiL7AOD8': 'Lesnar returns for the Universal Title Match Contract Signing with Reigns: SmackDown, Oct. 15, 2021',
#  '3B8g1RsZrlw': 'The Demonic Possession of the Conjuring House',
#  'htok8ZvRwhM': 'WE’RE PREGNANT!!!! (16 WEEKS)',
#  '6KZi3PviIbA': '100 Days, But There Are Custom Dimensions...',
#  'awTXXr6D9nc': 'I found out which countries have the most GOLD 😳💰'}

# %% [markdown]
# ### Task 3.2: Lookups using videos dictionary
#
# Recall that each video has a `video_id` that can be combined with the mapping from `video_ids.json` to obtain the `title` of each video. For example the video with ID `ex98DxvUiAc` has the title `'Guess Who’s Back!'`.
#
# Below, given the following `sample_video_id`, store its corresponding title to `sample_video_title`, by using dict lookup operation.

# %%
sample_video_id = "4P8fKd0IVOs"
sample_video_title = video_ids_json[sample_video_id]

assert sample_video_title == 'How Does The James Webb Space Telescope Work? - Smarter Every Day 262'

sample_video_title
# Out:
# 'How Does The James Webb Space Telescope Work? - Smarter Every Day 262'

# %% [markdown]
# Now, we want to generalize this to all videos. You will be writing a function called `get_videos`, which will be very similar to the `get_movies` function from P8 and P9. Each video will be represented as a dictionary of its title and all its attributes in the columns above. To keep things simple, let's start by assuming each video only has a `title` like this:
#
# ```python
# {'title': 'The Ultimate "Kung Fu Panda" Recap Cartoon'}
# ```
#
# We want to do this for each video, mapping their `video_id` to a dictionary of the video, so our end goal is something like this...
#
# ```python
# {
#  'ex98DxvUiAc': {'title': 'Guess Who’s Back!'},
#  '8y9QnS_tMkY': {'title': 'The Ultimate "Kung Fu Panda" Recap Cartoon'},
#  'IwTkLFYYBKc': {'title': 'Old Master, New Tricks! (Clash of Clans Season Challenges)'},
#  '2_9LOiY9Lpc': {'title': 'Making Spiral Light'},
#  ...
# }
# ```
#
# Complete the function `get_videos` below.
#
# **Note:** There exists some videos in `video_data.csv` that don't exist in `video_ids.json`. If you get a KeyError, skip that video. A try/except will be useful here.

# %%
def get_videos(data_file, video_mapping_file):
    """
    Given data_file (csv file) and video_mapping_file (json) file, generates a video
    dictionary, mapping video ID to a dictionary containing title, and other details of the video.
    Handles missing entry in video_ids.json by using try / except blocks to handle KeyError.
    """
    data = process_csv(data_file)
    
    header = data[0]
    all_videos = data[1:]
    
    video_mapping = get_mapping(video_mapping_file)
    videos_dict = dict()
    
    for video in all_videos:
        try:
            key = video[header.index('video_id')]
            
            title = video_mapping[key]
            published_at = video[header.index('published_at')] 
            duration = video[header.index('duration')] 
            category = video[header.index('category')] 
            views = int(video[header.index('views')])
            tags = video[header.index('tags')].split("|")
            likes = video[header.index('likes')]
            dislikes = video[header.index('dislikes')]

            if likes != "" and dislikes != "": 
                ratings_enabled = True
                likes = int(likes)
                dislikes = int(dislikes)

            else:
                ratings_enabled = False
                likes = None
                dislikes = None
            
            value = {'title': title, 
                     'published_at': published_at, 
                     'duration': duration, 
                     'category': category, 
                     'views': views,
                     'tags': tags,
                     'likes': likes,
                     'dislikes': dislikes,
                     'ratings_enabled': ratings_enabled
                    }
            
            videos_dict[key] = value
        
        except KeyError:
            continue
            
        except Exception:
            continue
    
    return videos_dict

videos = get_videos(os.path.join('data','video_data.csv'), os.path.join('data','video_ids.json'))
videos
# Out:
# {'ex98DxvUiAc': {'title': 'Guess Who’s Back!',
#   'published_at': '2021-10-01 01:54:20',
#   'duration': '00:15:12',
#   'category': 'Comedy',
#   'views': 3250076,
#   'tags': ['danny duncan',
#    'danny duncan 69',
#    'danny duncan vlog',
#    'danny duncan pranks',
#    'danny duncan vlogs',
#    'vlogs',
#    'pranks',
#    'danny duncan tour',
#    'danny duncan florida',
#    'danny duncan merch'],
#   'likes': 146039,
#   'dislikes': 1800,
#   'ratings_enabled': True},
#  '8y9QnS_tMkY': {'title': 'The Ultimate "Kung Fu Panda" Recap Cartoon',
#   'published_at': '2021-10-01 15:00:09',
#   'duration': '00:04:12',
#   'category': 'Film & Animation',
#   'views': 6981143,
#   'tags': ['kung fu panda',
#    'cas',
#    'cas van de pol',
#    'recap',
#    'cartoon',
#    'ultimate',
#    'ultimate recap cartoon',
#    'dreamworks',
#    'disney',
#    'jack black',
#    'panda',
#    'kung fu',
#    'tigress',
#    'po',
#    'monkey',
#    'mmm monkey',
#    'meme',
#    'memes',
#    'animated',
#    'animation',
#    'master oogway',
#    'oogway',
#    'shifu',
#    'turtle',
#    'cartoon by cas',
#    'parody',
#    '2008',
#    'remake',
#    'ultimate recap',
#    'madagascar',
#    'mort',
#    'penguins',
#    'chunky',
#    'funny',
#    'tai lung',
#    'dragon scroll',
#    'america',
#    'jackie chan',
#    'dustin hoffman',
#    'seth rogan',
#    'bowser',
#    'the mario movie',
#    'voice actor',
#    'the super mario bros movie',
#    'jablinski',
#    'jablinskigames'],
#   'likes': 332036,
#   'dislikes': 6326,
#   'ratings_enabled': True},
#  'IwTkLFYYBKc': {'title': 'Old Master, New Tricks! (Clash of Clans Season Challenges)',
#   'published_at': '2021-10-01 08:00:02',
#   'duration': '00:00:49',
#   'category': 'Gaming',
#   'views': 6505595,
#   'tags': ['clash of clans',
#    'COC',
#    'Clash of Clans Gameplay',
#    'Clash of Clans Strategy',
#    'Clash of Clans Animation',
#    'Clash of Clans Commercial',
#    'Clash of Clans Attacks',
#    'Clash of Clans Town Hall',
#    'Hog Rider',
#    'PEKKA',
#    'Clan Wars',
#    'season challenges',
#    'clan war leagues',
#    'clash on',
#    'clan game',
#    'clan games',
#    'warden master',
#    'kung fu warden',
#    'new skin',
#    'grand warden',
#    'grand warden new skin',
#    'october season'],
#   'likes': 104207,
#   'dislikes': 2748,
#   'ratings_enabled': True},
#  '2_9LOiY9Lpc': {'title': 'Making Spiral Light',
#   'published_at': '2021-10-01 16:00:01',
#   'duration': '00:00:49',
#   'category': 'Science & Technology',
#   'views': 3567571,
#   'tags': ['Science', 'quantum physics', 'the action lab'],
#   'likes': 219696,
#   'dislikes': 4072,
#   'ratings_enabled': True},
#  'bUrxLCWy-us': {'title': 'I Highballed People on Facebook Marketplace',
#   'published_at': '2021-10-01 15:00:37',
#   'duration': '00:09:54',
#   'category': 'Entertainment',
#   'views': 2020187,
#   'tags': ['Ryan',
#    'Trahan',
#    'I highballed people on facebook marketplace',
#    'highballed',
#    'lowball',
#    'facebook',
#    'marketplace',
#    'garage sale',
#    'yard sale',
#    'overpaying',
#    'actually paid them',
#    'ryan trahan',
#    'i lowballed people on facebook marketplace',
#    'lowballing people',
#    'highballing people',
#    'fb marketplace',
#    'i sent a dm'],
#   'likes': 101699,
#   'dislikes': 851,
#   'ratings_enabled': True},
#  '65yHrAJhHMk': {'title': 'Out of pocket tik toks 4',
#   'published_at': '2021-10-01 16:55:14',
#   'duration': '00:17:42',
#   'category': 'Comedy',
#   'views': 1315115,
#   'tags': ['noel miller',
#    'tiny meat gang',
#    'cody ko',
#    'tmg',
#    'love island',
#    'steamy tweets',
#    'suki',
#    'fortnite',
#    'games',
#    'cody and noel',
#    'uncle noel',
#    'thats cringe',
#    'thenoelmiller',
#    'noelle miller',
#    'comedy',
#    'satire',
#    'vine',
#    'rap',
#    'sketch comedy',
#    'roast',
#    'stand up'],
#   'likes': 104361,
#   'dislikes': 802,
#   'ratings_enabled': True},
#  'VAnS_67h1Fw': {'title': "hi (what's going on with me)",
#   'published_at': '2021-10-01 17:45:21',
#   'duration': '00:08:48',
#   'category': 'Entertainment',
#   'views': 1206198,
#   'tags': ['julien solomita',
#    'vlogs',
#    'vlogs by julien',
#    'how to',
#    'vegan',
#    'vegan recipe',
#    'vegan cooking',
#    'diy vegan',
#    'diy',
#    'julien cooking',
#    'gluten free',
#    'aries',
#    'aries kitchen',
#    'chef',
#    'julen',
#    'julien',
#    'best',
#    'meals',
#    'cinematic',
#    '4k'],
#   'likes': 104283,
#   'dislikes': 808,
#   'ratings_enabled': True},
#  'wgZes7y6Bh8': {'title': 'Meet My Boyfriend...',
#   'published_at': '2021-10-01 13:26:38',
#   'duration': '00:11:05',
#   'category': 'People & Blogs',
#   'views': 998649,
#   'tags': ['cam and fam',
#    'camandfam',
#    'cam fam',
#    'teen mom',
#    'camfam',
#    'teen pregnancy',
#    'cam',
#    'teen parents',
#    'camily',
#    'teen moms',
#    'teenage pregnancy',
#    'teenage mom',
#    'moms',
#    'teen',
#    'teen mom vlog',
#    'teen mom vlogs',
#    'vlog',
#    'day in my life',
#    'motherhood',
#    'family',
#    'baby',
#    'family vlogers',
#    'family vlogs',
#    'family channel',
#    'coco',
#    'meet my boyfriend',
#    'cameron'],
#   'likes': 66308,
#   'dislikes': 932,
#   'ratings_enabled': True},
#  '3iEHVVgCTPI': {'title': 'Aang Showcase – Nickelodeon All-Star Brawl',
#   'published_at': '2021-10-01 17:27:59',
#   'duration': '00:06:39',
#   'category': 'Gaming',
#   'views': 350928,
#   'tags': ['aang',
#    'avatar',
#    'the last airbender',
#    'nickelodeon',
#    'nickelodeon all-star brawl',
#    'nick brawl'],
#   'likes': 10195,
#   'dislikes': 271,
#   'ratings_enabled': True},
#  'PxsGaHMQTC4': {'title': 'Realistic Golem Transforming',
#   'published_at': '2021-10-01 15:49:07',
#   'duration': '00:00:52',
#   'category': 'Gaming',
#   'views': 959693,
#   'tags': ['Minecraft',
#    'compilation',
#    'top',
#    'movie',
#    'animation',
#    'machinima',
#    'realistic',
#    'shader',
#    'textures',
#    'graphics',
#    'quasar',
#    'real',
#    'life',
#    'mod',
#    'pack',
#    'animation vs minecraft',
#    'edition',
#    'minecraft 2',
#    'pocket',
#    'mobile',
#    'Майнкрафт',
#    'топ',
#    'анимация',
#    'реалистик',
#    'моды',
#    'в реальной жизни',
#    'Villager',
#    'village',
#    'Житель',
#    'Деревня',
#    'emerald',
#    'изумруд',
#    'алмаз',
#    'diamond',
#    'Cave',
#    'adventure',
#    'redstone',
#    'iron',
#    'trade'],
#   'likes': 19591,
#   'dislikes': 2268,
#   'ratings_enabled': True},
#  '4P8fKd0IVOs': {'title': 'How Does The James Webb Space Telescope Work? - Smarter Every Day 262',
#   'published_at': '2021-10-01 05:15:01',
#   'duration': '00:29:46',
#   'category': 'Science & Technology',
#   'views': 2068377,
#   'tags': ['Smarter',
#    'Every',
#    'Day',
#    'Science',
#    'Physics',
#    'Destin',
#    'Sandlin',
#    'Education',
#    'Math',
#    'Smarter Every Day',
#    'experiment',
#    'nature',
#    'demonstration',
#    'slow',
#    'motion',
#    'slow motion',
#    'education',
#    'math',
#    'science',
#    'science education',
#    'what is science',
#    'Physics of',
#    'projects',
#    'experiments',
#    'science projects'],
#   'likes': 101666,
#   'dislikes': 860,
#   'ratings_enabled': True},
#  'g9pyKmmF3VM': {'title': '1500rpm Slow Motion Paint Flinger - The Slow Mo Guys',
#   'published_at': '2021-10-01 15:32:29',
#   'duration': '00:10:42',
#   'category': 'Entertainment',
#   'views': 727959,
#   'tags': ['slomo',
#    'slow',
#    'mo',
#    'super',
#    'motion',
#    'Slow Motion',
#    '1000',
#    '1000fps',
#    'gav',
#    'dan',
#    'slowmoguys',
#    'phantom',
#    'guys',
#    'HD',
#    'flex',
#    'gavin',
#    'free',
#    'gavin free',
#    'high speed camera',
#    'the slow mo guys',
#    '2000',
#    '2000fps',
#    '5000',
#    '5000fps',
#    'paint',
#    'spin',
#    'rotating',
#    'art'],
#   'likes': 53409,
#   'dislikes': 422,
#   'ratings_enabled': True},
#  'p_i-ferkaoM': {'title': 'Guess the color challenge, too high, save it for later play! ! # Funny # Party Game Challenge#shorts',
#   'published_at': '2021-10-01 04:15:35',
#   'duration': '00:00:30',
#   'category': 'People & Blogs',
#   'views': 56545672,
#   'tags': [''],
#   'likes': 2174220,
#   'dislikes': 177668,
#   'ratings_enabled': True},
#  'tu-w3QDw46w': {'title': 'Zillow Gone Wild, Sacrifice Edition! (feat. Brittany Broski) | Sarah Schauer',
#   'published_at': '2021-10-01 01:43:08',
#   'duration': '00:29:43',
#   'category': 'Comedy',
#   'views': 620150,
#   'tags': ['sarah schauer',
#    'Sarah',
#    'schauer',
#    'Sarah schauer all vines',
#    'Sarah schauer vines',
#    'Sarah schauer i hate waitressing',
#    'vlog',
#    'storytime',
#    'story time',
#    'Brittany Broski',
#    'Brittany Broski Tiktok',
#    'zillow gone wild'],
#   'likes': 37090,
#   'dislikes': 165,
#   'ratings_enabled': True},
#  'lwRkRFnbMTQ': {'title': 'TotalEnergies BWF Sudirman Cup 2021 | Chia/Soh (MAS) vs Gideon/Sukamuljo (INA) | QF',
#   'published_at': '2021-10-01 13:56:35',
#   'duration': '00:48:50',
#   'category': 'Sports',
#   'views': 213489,
#   'tags': ['b_full_match',
#    'TotalEnergies BWF Sudirman Cup 2021',
#    '2021',
#    'Grade 1 - Team Tournaments',
#    'Sudirman Cup',
#    't_1BD7E5BD-0C17-496D-B17F-F60CD04626C0',
#    'm_1BD7E5BD-0C17-496D-B17F-F60CD04626C0_133',
#    'r_QF',
#    'Aaron CHIA',
#    'p_56203',
#    'SOH Wooi Yik',
#    'p_99389',
#    'Marcus Fernaldi GIDEON',
#    'p_26394',
#    'Kevin Sanjaya SUKAMULJO',
#    'p_80057',
#    'Malaysia',
#    'Indonesia',
#    'donotshow'],
#   'likes': 1278,
#   'dislikes': 64,
#   'ratings_enabled': True},
#  'WrX1aGHK1lM': {'title': 'Enter the World of Grand Cathay | Total War: WARHAMMER III',
#   'published_at': '2021-10-01 13:59:51',
#   'duration': '00:01:31',
#   'category': 'Gaming',
#   'views': 359101,
#   'tags': ['Total War',
#    'warhammer',
#    'total war warhammer',
#    'rome total war',
#    'warhammer 2 total war',
#    'total war rome 2',
#    'arena total war',
#    'total war empire',
#    'medieval total war',
#    'medieval total war 2',
#    'three kingdoms total war',
#    'total war gameplay',
#    'shogun 2 total war',
#    'total war saga',
#    'total war warhammer gameplay',
#    '3 kingdoms',
#    'new',
#    'gameplay',
#    'trailer',
#    'cathay',
#    'grand cathay',
#    'cathay warhammer'],
#   'likes': 16377,
#   'dislikes': 940,
#   'ratings_enabled': True},
#  'q-1HikE4b54': {'title': 'The Book Tied To 75,000 Disappearances',
#   'published_at': '2021-10-01 05:36:16',
#   'duration': '00:27:29',
#   'category': 'People & Blogs',
#   'views': 1001478,
#   'tags': ['missing people',
#    'fake identity',
#    'missing people cases',
#    'living under a fake identity',
#    'book'],
#   'likes': 54416,
#   'dislikes': 1159,
#   'ratings_enabled': True},
#  'C8RAVJV6Je4': {'title': 'Stephen A. reacts to Joel Embiid calling Simmons’ situation ‘borderline disrespectful’ | First Take',
#   'published_at': '2021-10-01 16:25:44',
#   'duration': '00:06:55',
#   'category': 'Sports',
#   'views': 415950,
#   'tags': ['joel embiid on ben simmons',
#    'ben simmons',
#    'joel embiid',
#    'philadelphia 76ers',
#    'sixers',
#    '76ers',
#    'nba',
#    'joel embiid ben simmons',
#    'espn',
#    'ben simmons trade',
#    'ben simmons news',
#    'ben simmons 76ers',
#    'nba news',
#    'nba on espn',
#    'espn nba',
#    'simmons',
#    'nba espn',
#    'first take',
#    '#espn',
#    'joel embiid 76ers',
#    'nba 2021',
#    '#nba',
#    'embiid',
#    'ben simmons sixers',
#    'first take ben simmons',
#    'stephen a smith',
#    'first take espn',
#    'first take today',
#    'stephen a',
#    'stephen a. smith',
#    'first take nba',
#    'espn first take',
#    'ben simmons joel embiid'],
#   'likes': 4426,
#   'dislikes': 555,
#   'ratings_enabled': True},
#  'vKTl6DczK9k': {'title': 'Jaguars vs. Bengals Week 4 Highlights | NFL 2021',
#   'published_at': '2021-10-01 03:48:39',
#   'duration': '00:10:58',
#   'category': 'Sports',
#   'views': 2398200,
#   'tags': [''],
#   'likes': 29226,
#   'dislikes': 804,
#   'ratings_enabled': True},
#  'itWFfuFFoSI': {'title': 'The Best Selling Consoles of All Time - Scott The Woz',
#   'published_at': '2021-10-01 00:00:24',
#   'duration': '00:29:35',
#   'category': 'Gaming',
#   'views': 1375875,
#   'tags': [''],
#   'likes': 70928,
#   'dislikes': 815,
#   'ratings_enabled': True},
#  'g7yKe_W_nRY': {'title': 'Finding Our Makeup at a CLEARANCE STORE!',
#   'published_at': '2021-10-02 16:00:34',
#   'duration': '00:13:12',
#   'category': 'Howto & Style',
#   'views': 2118758,
#   'tags': ['jeffree star cosmetics',
#    'jeffree star nordstrom rack',
#    'jeffree star tj maxx',
#    'shane dawson',
#    'ryland adams',
#    'jeffree and shane',
#    'jeffree star discount makeup',
#    'makeup tutorial',
#    'cheap makeup',
#    'velour liquid lipstick',
#    'conspiracy palette',
#    'nordstrom makeup haul'],
#   'likes': 90545,
#   'dislikes': 15085,
#   'ratings_enabled': True},
#  '707Rhr-QD3Y': {'title': 'i have been exposed.. again..',
#   'published_at': '2021-10-02 17:17:35',
#   'duration': '00:20:18',
#   'category': 'Entertainment',
#   'views': 2490748,
#   'tags': ['dantdm', 'dan tdm', 'gaming', 'video games', 'funny'],
#   'likes': 202094,
#   'dislikes': 1054,
#   'ratings_enabled': True},
#  'vWT6YhSs76c': {'title': 'If Black People Were in Squid Game',
#   'published_at': '2021-10-01 20:39:32',
#   'duration': '00:01:47',
#   'category': 'Comedy',
#   'views': 9794245,
#   'tags': [''],
#   'likes': 486497,
#   'dislikes': 10985,
#   'ratings_enabled': True},
#  'iGVpcKidejI': {'title': 'You Laugh You Lose Is Even Funnier In Real Life...',
#   'published_at': '2021-10-01 19:00:25',
#   'duration': '00:10:23',
#   'category': 'Gaming',
#   'views': 6130121,
#   'tags': ['tommyinnit',
#    'minecraft',
#    'mine craft',
#    'dream minecraft',
#    'dream smp',
#    'funny',
#    'minecraft funny',
#    'minecraft speedrun',
#    'minecraft challenge',
#    'minecraft but',
#    'fun',
#    'date',
#    'ranboo',
#    'tubbo',
#    'you laugh you lose',
#    'ylyl',
#    'try not to laugh',
#    'smosh',
#    'Minecraft you laugh you lose',
#    'group channel',
#    'You Laugh You Lose IN REAL LIFE'],
#   'likes': 535764,
#   'dislikes': 5441,
#   'ratings_enabled': True},
#  'V3Ql2DthLJ8': {'title': 'GENIUS INVENTIONS THAT SHOULD EXIST EVERYWHERE!! #Shorts',
#   'published_at': '2021-10-01 20:00:11',
#   'duration': '00:00:46',
#   'category': 'Entertainment',
#   'views': 5408793,
#   'tags': [''],
#   'likes': 488926,
#   'dislikes': 5707,
#   'ratings_enabled': True},
#  'DjRwSlVmEbc': {'title': 'I Survived 100 Days as a PANDA in HARDCORE Minecraft!',
#   'published_at': '2021-10-02 14:00:08',
#   'duration': '00:50:12',
#   'category': 'Gaming',
#   'views': 3303382,
#   'tags': ['Minecraft',
#    'I survived 100 days as a panda in minecraft',
#    'I survived',
#    '100 days',
#    'panda',
#    'i survived 100 days',
#    'minecraft panda',
#    'hardcore minecraft',
#    'minecraft hardcore',
#    'hardcore',
#    'minecraft 100 days',
#    '100 days minecraft',
#    '100 days challenge',
#    '100 days in hardcore',
#    '100 days hardcore minecraft',
#    '100 days hardcore',
#    'moosecraft',
#    'moose',
#    'I survived 100 days in minecraft',
#    'I survived 100 days as a',
#    'Aphmau',
#    'SSundee',
#    'Beckbrojack',
#    'Ryguyrocky',
#    'craftee',
#    'luke thenotable'],
#   'likes': 110272,
#   'dislikes': 2553,
#   'ratings_enabled': True},
#  '97Z3qSSbwkY': {'title': 'Was LOST even a good show?',
#   'published_at': '2021-10-01 19:10:59',
#   'duration': '00:21:29',
#   'category': 'Comedy',
#   'views': 1904305,
#   'tags': ['drew gooden',
#    'comedy',
#    'commentary',
#    'reaction',
#    'vine',
#    'drew gooden vine',
#    'road work ahead guy',
#    'parody',
#    'rant',
#    'cringe',
#    'lost',
#    'lost video essay',
#    'lost review',
#    'michael giacchino',
#    'lost soundtrack',
#    'up soundtrack',
#    'married life up'],
#   'likes': 143386,
#   'dislikes': 1220,
#   'ratings_enabled': True},
#  'BDsaIzfB_qc': {'title': 'Switching CREDIT CARDS w/ Alisha Marie *no limit*',
#   'published_at': '2021-10-01 23:37:03',
#   'duration': '00:20:21',
#   'category': 'Entertainment',
#   'views': 497207,
#   'tags': ['Lauren giraldo',
#    'Lauren Giraldo vlog',
#    'Alisha marie',
#    'Switching CREDIT CARDS w/ Alisha Marie *no limit*',
#    'credit card swap',
#    'credit card challenge',
#    'Switching CREDIT CARDS w/ Alisha Marie For 24 Hours'],
#   'likes': 24345,
#   'dislikes': 467,
#   'ratings_enabled': True},
#  'zk7_fyQDc5s': {'title': 'Taking Air-Delivery of my First Supercar!',
#   'published_at': '2021-10-02 17:05:03',
#   'duration': '00:12:56',
#   'category': 'Autos & Vehicles',
#   'views': 491400,
#   'tags': ['Emelia Hartford',
#    'Automotive',
#    'Cars',
#    'Vlog',
#    'supercar',
#    'suprise',
#    'new car',
#    'helicopter',
#    'plane',
#    'stunt',
#    'viral',
#    'hypercar',
#    'taking delivery',
#    'new',
#    'dangerous',
#    'emotional',
#    'funny',
#    'sad',
#    'pagani',
#    'mclaren',
#    'lamborghini',
#    'ferrari',
#    'senna',
#    'koenisegg',
#    'f1',
#    'race car',
#    'box',
#    'unboxing',
#    'reveal'],
#   'likes': 34896,
#   'dislikes': 1013,
#   'ratings_enabled': True},
#  'jJie6c5vJJs': {'title': 'drunk lily & drunk michael',
#   'published_at': '2021-10-02 16:45:01',
#   'duration': '00:15:15',
#   'category': 'Entertainment',
#   'views': 890814,
#   'tags': ['lilypichu',
#    'lily',
#    'highlights',
#    'hilarious',
#    'funny',
#    'twitchtv',
#    'moments',
#    'offlinetv'],
#   'likes': 49610,
#   'dislikes': 346,
#   'ratings_enabled': True},
#  'iTSn_mCgQ0c': {'title': '1 In A Million Coincidences! 🤯',
#   'published_at': '2021-10-02 16:34:42',
#   'duration': '00:00:46',
#   'category': 'People & Blogs',
#   'views': 7174518,
#   'tags': [''],
#   'likes': 503204,
#   'dislikes': 13272,
#   'ratings_enabled': True},
#  'iyM0rkoO-XI': {'title': "Dangerous Toys - Gas Powered Pogo Stick from 1960's",
#   'published_at': '2021-10-02 02:13:32',
#   'duration': '00:09:31',
#   'category': 'Science & Technology',
#   'views': 3574939,
#   'tags': [''],
#   'likes': 126936,
#   'dislikes': 2443,
#   'ratings_enabled': True},
#  'oCBF03d4u0o': {'title': 'How LEGO Super Mario 64 TRIGGERS You!',
#   'published_at': '2021-10-02 15:30:14',
#   'duration': '00:07:41',
#   'category': 'Gaming',
#   'views': 512153,
#   'tags': ['LEGO Super Mario 64',
#    'Super Mario 64',
#    'lego mario 64',
#    'lego mario',
#    'lego luigi',
#    'lego peach',
#    'lego bowser',
#    'lego yoshi',
#    'lego super mario',
#    'triggered',
#    'trigger',
#    'triggers',
#    'nathaniel bandy'],
#   'likes': 16949,
#   'dislikes': 338,
#   'ratings_enabled': True},
#  'mraaayzfg9w': {'title': 'Mini Crewmate Kills in Squid Game | Among Us',
#   'published_at': '2021-10-01 18:45:03',
#   'duration': '00:01:14',
#   'category': 'Film & Animation',
#   'views': 8454825,
#   'tags': ['among us',
#    'among us animation',
#    'among us kill animations',
#    'impostor',
#    'among us kills',
#    'among us cartoon',
#    'mini crewmate kills',
#    'damn seconds',
#    'squid game',
#    'among us kills squid game',
#    'among us squid game',
#    'mini crewmate squid game',
#    'squid game trailer',
#    'squid game episode',
#    'squid game roblox',
#    'among us roblox'],
#   'likes': 106581,
#   'dislikes': 5091,
#   'ratings_enabled': True},
#  '3tWbx5YhGF0': {'title': 'can 1 pixel of water save you?',
#   'published_at': '2021-10-02 02:01:28',
#   'duration': '00:01:03',
#   'category': 'Gaming',
#   'views': 10863371,
#   'tags': ['minecraft',
#    'meme',
#    'memes',
#    'speedrun',
#    'Which end crystal is better?',
#    'villager vs anvil',
#    'i gave goats jump boost',
#    'can mobs see me',
#    'tetherball i guess',
#    'how to make a gaming pc with this screen (no mods)',
#    'how to make binoculars',
#    'riding a boat on lava',
#    'DO NOT show this to DREAM...',
#    'this fight will actually never end',
#    'this video will satisfy you',
#    '31415 IQ?',
#    '10 ways to destroy your PC',
#    'ALL of your Minecraft questions in 1 min (hehe)',
#    'alexa real',
#    'can 1 pixel of water save you?'],
#   'likes': 299333,
#   'dislikes': 4062,
#   'ratings_enabled': True},
#  '1ERTKpn9qI8': {'title': 'MY BEST FRIEND IS PREGNANT FOR A DAY!',
#   'published_at': '2021-10-01 20:27:36',
#   'duration': '00:14:05',
#   'category': 'Comedy',
#   'views': 644809,
#   'tags': ['colleen ballinger',
#    'colleen',
#    'ballinger',
#    'psychosoprano',
#    'miranda sings',
#    'no lipstick',
#    'vlog',
#    'vlogging',
#    'singing',
#    'without lipstick',
#    'comedy',
#    'how to',
#    'tutorial',
#    'silly',
#    'funny',
#    'pregnant',
#    'twins',
#    'twin pregnancy',
#    'pregnancy',
#    'kory desoto',
#    'best friend',
#    'boy pregnant',
#    'watermelon',
#    'watermelon pregnancy',
#    'challenge'],
#   'likes': 39376,
#   'dislikes': 393,
#   'ratings_enabled': True},
#  'hePyHdb6CMk': {'title': 'I Survived 100 Days as an ENDER DRAGON in Minecraft',
#   'published_at': '2021-10-02 13:00:16',
#   'duration': '00:30:14',
#   'category': 'Gaming',
#   'views': 1002736,
#   'tags': ['Minecraft',
#    'minecraft roleplay',
#    'ryguyrocky',
#    '100 day challenge',
#    'ryguyrocky ender',
#    'ryguyrocky 100 day enderdragon',
#    'minecraft ender dragon',
#    'roleplays',
#    'roleplay',
#    'minecraft enderdragon',
#    'end dragon morph',
#    'morph mod',
#    'minecraft morph',
#    'moose',
#    'minecraft mod',
#    'minecraft mods',
#    'farmer unicorn',
#    'minecraft end',
#    'no cursing',
#    'no swearing',
#    'family friendly',
#    'kid friendly',
#    'kid',
#    'kids',
#    'ryguyrocky 100 days'],
#   'likes': 22983,
#   'dislikes': 949,
#   'ratings_enabled': True},
#  '1jrZrVGQoZ0': {'title': 'DISMANTLING A RUTHLESS CLAN - Rust',
#   'published_at': '2021-10-01 19:34:05',
#   'duration': '00:47:24',
#   'category': 'Gaming',
#   'views': 1513620,
#   'tags': ['welyn',
#    'Rust Solo Survival',
#    'Rust PVP Highlights',
#    'Survival Games',
#    'Rust Gameplay',
#    'Rust Funny Moments',
#    'Rust raids',
#    'rust huge loot',
#    'rust plays',
#    'rust roleplayer',
#    'rust clans',
#    'rust solo',
#    'rust best start ever',
#    'rust fastest start ever',
#    'rust solo infiltration',
#    'rust solo pvp',
#    'rust compound',
#    'rust base build',
#    'rust jackpot raid',
#    'Rust',
#    'welyn rust',
#    'rust survival',
#    'rust movie',
#    'rust server',
#    'rust streamer',
#    'rust pro',
#    'rust revenge',
#    'welyn revenge',
#    'welyn clan',
#    'solo survival'],
#   'likes': 57869,
#   'dislikes': 701,
#   'ratings_enabled': True},
#  'KSUWDJXPk6o': {'title': 'Trying The Squid Game Honeycomb Candy Challenge',
#   'published_at': '2021-10-01 19:31:00',
#   'duration': '00:09:17',
#   'category': 'Entertainment',
#   'views': 11441486,
#   'tags': ['sssniperwolf',
#    'sniper wolf',
#    'reacting',
#    'reaction',
#    'funny',
#    'squid game',
#    'honeycomb',
#    'dalgona candy',
#    '오징어 게임'],
#   'likes': 305492,
#   'dislikes': 6397,
#   'ratings_enabled': True},
#  'kpNjkd4rVXM': {'title': 'Philza And Wilbur TEACH Tommy To FLY And Its SCUFFED LORE! ORIGINS SMP',
#   'published_at': '2021-10-02 11:21:40',
#   'duration': '00:15:55',
#   'category': 'Gaming',
#   'views': 383948,
#   'tags': ['minecraft',
#    'dream',
#    'tubbo',
#    'tommyinnit',
#    'smp',
#    'twitch',
#    'live',
#    'stream',
#    'roleplay',
#    'war',
#    'fundy',
#    'punz',
#    'quackity',
#    'sapnap',
#    'nihachu',
#    'niki',
#    'willbur',
#    'soot',
#    'awesamduude',
#    'hbomb',
#    'technoblade',
#    'george',
#    'georgenotfound',
#    'badboyhalo',
#    'tommy',
#    'clips',
#    'videos',
#    'best',
#    'of',
#    'jschlatt',
#    'schlat',
#    'schlatt',
#    'pogtopia',
#    'menberg',
#    'manberg',
#    'lmanberg',
#    'lmenberg',
#    'capitain puffy',
#    'sonic',
#    'connor',
#    'connoreatspants',
#    'philza',
#    'lore',
#    'ranboo',
#    'enderman',
#    'chicken',
#    'ghost',
#    'nerfed',
#    'phantom',
#    'origins',
#    'superpowers',
#    'mutants',
#    'elytra'],
#   'likes': 19830,
#   'dislikes': 163,
#   'ratings_enabled': True},
#  'tzU2P1JfEJM': {'title': 'Switching CREDIT CARDS w/ Lauren Giraldo!! *no limit*',
#   'published_at': '2021-10-01 23:45:15',
#   'duration': '00:15:22',
#   'category': 'Howto & Style',
#   'views': 565262,
#   'tags': ['Alisha Marie',
#    'alisha',
#    'alishamarie',
#    'alisha marie vlogs',
#    'credit card',
#    'switching credit cards',
#    'swapping credit cards',
#    'credit',
#    'card',
#    'lauren',
#    'lauren giraldo',
#    'giraldo',
#    'fashion',
#    'shopping',
#    'haul',
#    'clothing haul',
#    'luxury',
#    'luxury haul',
#    'rodeo drive',
#    'beverly hills'],
#   'likes': 26916,
#   'dislikes': 285,
#   'ratings_enabled': True},
#  'WTyBK0w90T0': {'title': 'Brock Lesnar lays waste to Roman Reigns and The Bloodline: SmackDown, Oct. 1, 2021',
#   'published_at': '2021-10-02 02:03:13',
#   'duration': '00:03:13',
#   'category': 'Sports',
#   'views': 8276659,
#   'tags': ['Brock Lesnar',
#    'Jey Uso',
#    'Jimmy Uso',
#    'Paul Heyman',
#    'Roman Reigns',
#    'SmackDown',
#    'The Bloodline',
#    'Usos',
#    'superstars',
#    'world wrestling entertainment',
#    'wrestle',
#    'wrestler',
#    'wrestling',
#    'wwe',
#    'wwe 2021',
#    'مصارعه',
#    'कुश्ती',
#    'डब्लू डब्लू ई',
#    'पहलवान',
#    'मैच',
#    'व्यावसायिक कुश्ती',
#    'सुपरस्टार',
#    'Smackdown clips',
#    'smackdown highlights',
#    'smackdown winners',
#    'smackdown match card',
#    'smackdown tonight',
#    'friday night smackdown',
#    'wwe smackdown',
#    'smackdown 2021',
#    'smackdown fox',
#    'roman reigns vs brock lesnar'],
#   'likes': 196187,
#   'dislikes': 5336,
#   'ratings_enabled': True},
#  '0MGmz9zxBG8': {'title': 'IF I SCREAM YOU WIN $20,000!',
#   'published_at': '2021-10-02 18:00:00',
#   'duration': '00:13:08',
#   'category': 'Comedy',
#   'views': 2330578,
#   'tags': [''],
#   'likes': 68937,
#   'dislikes': 1054,
#   'ratings_enabled': True},
#  'sJ6SQBWCPcQ': {'title': 'Realistic Water in Minecraft...',
#   'published_at': '2021-10-01 12:09:08',
#   'duration': '00:08:25',
#   'category': 'Gaming',
#   'views': 4737517,
#   'tags': ['child friendly',
#    'kid friendly',
#    'minecraft',
#    'realistic',
#    'physics',
#    'jelly',
#    'reaction'],
#   'likes': 153326,
#   'dislikes': 5437,
#   'ratings_enabled': True},
#  'tUeIM8iTx3Q': {'title': "Minecraft, But There's Custom End City Items...",
#   'published_at': '2021-10-02 01:25:34',
#   'duration': '00:19:36',
#   'category': 'Gaming',
#   'views': 410191,
#   'tags': ['shadowapples',
#    'shadow apples',
#    'minecraft',
#    'minecraft but',
#    'mine craft',
#    'Minecraft',
#    'Minecraft But',
#    'MC But',
#    'minecraft craft',
#    'minecraft challenge',
#    'beating minecraft',
#    'manhunt',
#    'minecraft but challenge',
#    'minecraft op',
#    'minecraft but you can craft',
#    'minecraft but you can',
#    'but',
#    'custom',
#    'craft',
#    'you can',
#    'structures',
#    'structure',
#    'custom structure',
#    'custom temple',
#    'custom structures',
#    'if',
#    'end city',
#    'endcity',
#    'end cities',
#    'end city loot',
#    'end',
#    'the end',
#    "But There's Custom End City Items..."],
#   'likes': 13656,
#   'dislikes': 354,
#   'ratings_enabled': True},
#  '9KapEXWynrA': {'title': "Inside Nina Dobrev's 1920's Spanish-Style Home | Open Door | Architectural Digest",
#   'published_at': '2021-10-01 19:15:02',
#   'duration': '00:16:53',
#   'category': 'Entertainment',
#   'views': 3050160,
#   'tags': ['ad celebrity home',
#    'ad celebrity home tour',
#    'ad dobrev',
#    'ad home tour',
#    'ad home tours',
#    'ad nina dobrev',
#    'arch digest home tour',
#    'arch digest home tours',
#    'arch digest nina dobrev',
#    'architectural digest',
#    'architectural digest nina dobrev',
#    'dobrev',
#    'inside nina dobrev home',
#    'nina dobrev',
#    'nina dobrev 2021',
#    'nina dobrev hollywood home',
#    'nina dobrev home',
#    'nina dobrev home tour',
#    'nina dobrev house tour',
#    'nina dobrev mansion',
#    'nina dobrev now',
#    'open door',
#    'spanish style home',
#    'spanish-style home'],
#   'likes': 107256,
#   'dislikes': 919,
#   'ratings_enabled': True},
#  'RrwQG38ovYw': {'title': 'SURPRISED BEST FRIEND WITH A YACHT AND THIS!',
#   'published_at': '2021-10-01 18:43:15',
#   'duration': '00:13:24',
#   'category': 'People & Blogs',
#   'views': 637399,
#   'tags': ['alondradessy',
#    'alo and benny',
#    'alondra and benny',
#    'alo and elsy',
#    'Louies life',
#    'jenny69',
#    'ace fam',
#    'ace family',
#    'Landon and shyla',
#    'through Ryans eyes',
#    'Catherine paiz',
#    'Austin mcbroom',
#    'James charles',
#    'daisy marquez',
#    'bram fam',
#    'bramty',
#    'alondradessy and benny',
#    'benny and alondradessy',
#    'comedy',
#    'alondra dessy',
#    'paeka',
#    'kb and karla',
#    'les do makeup',
#    'Laura mellado',
#    'alondra baby',
#    'malu trevejo',
#    'lve fam',
#    'juju and des',
#    'alondradessy labor and delivery',
#    'landonandshyla',
#    'landon',
#    'shyla'],
#   'likes': 38068,
#   'dislikes': 443,
#   'ratings_enabled': True},
#  'dPnSpIKbgfg': {'title': 'Pranking My Guy Bestfriend 😅😂 #shorts',
#   'published_at': '2021-10-02 17:00:16',
#   'duration': '00:01:00',
#   'category': 'People & Blogs',
#   'views': 479046,
#   'tags': [''],
#   'likes': 24110,
#   'dislikes': 474,
#   'ratings_enabled': True},
#  'L5jBHzsLiwQ': {'title': 'Mini Crewmate Kills Squid Game Characters #1 - Among us',
#   'published_at': '2021-10-01 18:10:03',
#   'duration': '00:01:07',
#   'category': 'Gaming',
#   'views': 2935676,
#   'tags': ['among us',
#    'among us animation',
#    'among us kill animations',
#    'impostor',
#    'among us kills',
#    'among us cartoon',
#    'mini crewmate kills',
#    'Ralf dummer',
#    'among us Squid Game',
#    'Squid Game',
#    'mini crewmate kills Squid Game',
#    'among us meme',
#    'Squid Game kills',
#    '오징어 게임',
#    'Green Light',
#    'Red Light',
#    'squid game animation'],
#   'likes': 36115,
#   'dislikes': 3004,
#   'ratings_enabled': True},
#  'MhaZFNjaIw8': {'title': "Rosie Steals Caillou's Snickers Bar Rap #shorts",
#   'published_at': '2021-10-01 22:00:10',
#   'duration': '00:00:53',
#   'category': 'Comedy',
#   'views': 4908374,
#   'tags': ['vincentmottola',
#    'Vincent Mottola',
#    'the Vincent Mottola',
#    'TheVincentMottola',
#    'voice impressions',
#    'voice actor',
#    'voice acting',
#    'voice impersonations',
#    'sketches',
#    'funny sketches',
#    'funny skits',
#    'skits',
#    'comedy',
#    'comedy videos',
#    'cartoons for kids',
#    'thevincentmottola',
#    'shorts',
#    'youtube shorts',
#    'shorts youtube',
#    'snickers',
#    'snickers bar',
#    'chocolate',
#    'snickers chocolate',
#    'caillou',
#    'cailloux',
#    'caillou new episode',
#    'caillou full',
#    'caillou in english',
#    'caillou rap',
#    'caillou new episodes',
#    'caillou english',
#    'caillou new'],
#   'likes': 217333,
#   'dislikes': 19354,
#   'ratings_enabled': True},
#  '1yLK-yfM3sc': {'title': 'Kleavor Pokémon Meme Review',
#   'published_at': '2021-10-02 15:15:00',
#   'duration': '00:14:47',
#   'category': 'Gaming',
#   'views': 541109,
#   'tags': ['New Pokemon games',
#    'New Pokemon',
#    'Top Pokemon',
#    'Pokemon Talk',
#    'MandJTV',
#    'MandJTV Pokevids',
#    'gaming',
#    'video games',
#    'nintendo switch',
#    'nintendo',
#    'pokemon',
#    'new games',
#    'family friendly',
#    'top 10',
#    'top 5',
#    'charizard',
#    'greninja',
#    'pikachu',
#    'best pokemon',
#    'all pokemon',
#    'original pokemon',
#    'retro games',
#    'retro pokemon games',
#    'nintendo pokemon',
#    'brilliant diamond',
#    'shining pearl',
#    'pokemon legends arceus',
#    'legends arceus',
#    'pokemon sword and shield',
#    'kleavor',
#    'meme review',
#    'aspitpiay',
#    'pokemon funny',
#    'pokemon memes'],
#   'likes': 27429,
#   'dislikes': 374,
#   'ratings_enabled': True},
#  'OrcIAKgimfk': {'title': 'She Wants Us DEAD! 💀 Dark Deception Chapter 4 (FGTeeV Telekinesis Gameplay)',
#   'published_at': '2021-10-02 15:28:17',
#   'duration': '00:20:32',
#   'category': 'Gaming',
#   'views': 2572496,
#   'tags': ['fgteev',
#    'fgteev youtube',
#    'youtube fgteev',
#    'fgteev gaming',
#    'fgteev minecraft',
#    'fgteev roblox',
#    'family gaming',
#    'gameplay',
#    'ape chase',
#    'fgteev ape chase',
#    'fgteev skit',
#    'dark deception nurse',
#    'dark deception ending',
#    'scary game',
#    'new scary games',
#    'dark deception',
#    'torment therapy',
#    'dark deception torment therapy',
#    'fgteev boys',
#    'fgteev shaw',
#    'fgteev chase',
#    'fgteev duddz',
#    'fv family gaming',
#    'fgteev vlogs'],
#   'likes': 36616,
#   'dislikes': 1575,
#   'ratings_enabled': True},
#  'wHJBH4uwNfA': {'title': 'Try Guys Get Gen Z Makeovers',
#   'published_at': '2021-10-02 15:00:33',
#   'duration': '00:19:06',
#   'category': 'Comedy',
#   'views': 1252390,
#   'tags': ['try guys',
#    'keith',
#    'ned',
#    'zach',
#    'eugene',
#    'habersberger',
#    'fulmer',
#    'kornfeld',
#    'yang',
#    'buzzfeedvideo',
#    'buzzfeed',
#    'ariel',
#    'ned & ariel',
#    'comedy',
#    'education',
#    'funny',
#    'try',
#    'learn',
#    'fail',
#    'experiment',
#    'test',
#    'tryceratops',
#    'gen z tiktoks',
#    'gen z cringe',
#    'gen z tiktok',
#    'gen z tiktok cringe',
#    'gen z moments',
#    'gen z',
#    'gen z funny',
#    'gen z vs millennials',
#    'makeover',
#    'makeovers',
#    'transformation',
#    'glow up makeover',
#    'styling tips',
#    'fashion styling',
#    'clothing',
#    'style',
#    'mens style',
#    'mens fashion',
#    'outfits of the week',
#    'outfit ideas',
#    'outfits',
#    '2021 trends'],
#   'likes': 64177,
#   'dislikes': 1284,
#   'ratings_enabled': True},
#  'H9yhnMIpRS8': {'title': 'VFX Artists React to SHANG-CHi Bad & Great CGi',
#   'published_at': '2021-10-02 16:00:06',
#   'duration': '00:17:29',
#   'category': 'Entertainment',
#   'views': 1344370,
#   'tags': ['vfx',
#    'vfx artists react',
#    'react',
#    'cgi',
#    'Shang-Chi and the Legend of the Ten Rings',
#    'Shang-Chi',
#    'shang chi',
#    'shot breakdown',
#    'behind the scenes',
#    'visual effects',
#    'Simu Liu',
#    'Awkwafina',
#    'Tony Chiu-Wai Leung',
#    'Ben Kingsley',
#    'Michelle Yeoh',
#    'new',
#    'marvel'],
#   'likes': 66414,
#   'dislikes': 671,
#   'ratings_enabled': True},
#  '6K_oo-AeNWQ': {'title': 'I Ordered Pizza. It went wrong somehow',
#   'published_at': '2021-10-02 17:00:03',
#   'duration': '00:13:36',
#   'category': 'Gaming',
#   'views': 442328,
#   'tags': ['RTGame',
#    'RT Game',
#    'Irish',
#    'funny',
#    'moments',
#    'gameplay',
#    'rt game',
#    'stream highlights',
#    'funny stream highlights',
#    'rtgame pizza',
#    'rtgame pizza stream'],
#   'likes': 35719,
#   'dislikes': 144,
#   'ratings_enabled': True},
#  '8ghEl_ibLiI': {'title': 'I REALLY NEED YOUR HELP',
#   'published_at': '2021-10-03 18:25:32',
#   'duration': '00:00:44',
#   'category': 'Film & Animation',
#   'views': 3933384,
#   'tags': ['jaiden', 'animations', 'jaidenanimation', 'jaidenanimations'],
#   'likes': 436974,
#   'dislikes': 3050,
#   'ratings_enabled': True},
#  'uzEPvj46rGQ': {'title': 'Biden Unites Democrats Cold Open - SNL',
#   'published_at': '2021-10-03 04:40:45',
#   'duration': '00:07:04',
#   'category': 'Comedy',
#   'views': 2402841,
#   'tags': ['SNL10022021',
#    'snl snl',
#    'saturday night live',
#    'season 47',
#    'snl 47',
#    'snl cold open',
#    'cold open',
#    'president biden',
#    'james austin johnson',
#    'senator kyrsten sinema',
#    'cecily strong',
#    'senator joe manchin',
#    'aidy bryant',
#    'representative ilhan omar',
#    'ego nwodim',
#    'representative alexandria ocasio-cortez',
#    'melissa villaseñor',
#    'infastructure',
#    'andrew cuomo',
#    'pete davidson',
#    'chuck schumer',
#    'alex moffat',
#    's47',
#    's47e1',
#    'premiere',
#    'live',
#    'new york',
#    'comedy',
#    'sketch',
#    'funny',
#    'hilarious',
#    'late night',
#    'host'],
#   'likes': 31040,
#   'dislikes': 4995,
#   'ratings_enabled': True},
#  'XFZxbKmUCp0': {'title': 'Farewell, Naruto | Boruto: Naruto Next Generations',
#   'published_at': '2021-10-03 15:00:32',
#   'duration': '00:03:09',
#   'category': 'Film & Animation',
#   'views': 5519210,
#   'tags': ['kurama death',
#    'kurama',
#    'kyuubi death',
#    'kyuubi',
#    'partners',
#    'two-man team',
#    'crunchyroll',
#    'anime',
#    'anime trailer',
#    'anime preview',
#    'anime full episode',
#    'crunchyroll collection',
#    'daily clips',
#    'anime pv',
#    'anime op',
#    'anime opening',
#    'anime highlights',
#    'boruto',
#    'naruto',
#    'next generations',
#    'boruto 218',
#    'boruto episode 218'],
#   'likes': 207446,
#   'dislikes': 2785,
#   'ratings_enabled': True},
#  'qNUTz6dk4HE': {'title': '13 Types of People in SQUID GAME',
#   'published_at': '2021-10-03 13:00:05',
#   'duration': '00:09:50',
#   'category': 'Comedy',
#   'views': 16700173,
#   'tags': ['jianhao tan',
#    'jian hao tan',
#    'jianhao',
#    'the jianhao tan',
#    'thejianhaotan',
#    'jian hao',
#    'jianhaotan',
#    'kim lee',
#    'singapore',
#    'singaporean',
#    'youtuber',
#    'youtubers',
#    'youtube',
#    'squid',
#    'squid game',
#    'PE',
#    'parody',
#    'in',
#    'real life',
#    'types of students',
#    'students',
#    'exams',
#    'organization',
#    'yana',
#    'miss Sofia',
#    'Madam Soot Beng',
#    'ben Debbie',
#    'ben and Debbie',
#    'push',
#    'Vicky',
#    'among us',
#    'red light',
#    'green light',
#    'roblox',
#    't1t5',
#    'titan academy',
#    'Denise',
#    'cheat'],
#   'likes': 299198,
#   'dislikes': 14822,
#   'ratings_enabled': True},
#  'asasI0kxZrU': {'title': 'Building AUTOMATIC FARMS in Minecraft Hardcore (#52)',
#   'published_at': '2021-10-03 13:21:08',
#   'duration': '00:14:19',
#   'category': 'Gaming',
#   'views': 3330676,
#   'tags': ['Building AUTOMATIC FARMS in Minecraft Hardcore',
#    'I Built Automatic Farms in Minecraft',
#    'Automatic Farms to make in hardcore minecraft',
#    'WadZee',
#    'Minecraft',
#    'WadZee Minecraft',
#    'WadZee hardcore Minecraft',
#    'Minecraft Hardcore',
#    'WadZee Automatic farms',
#    'Minecraft Squid farm',
#    'Minecraft sugarcane farm',
#    'Minecraft wheat farm',
#    'Minecraft carrot farm',
#    'Automatic sugarcane farm',
#    'automatic wheat farm',
#    'minecraft survival'],
#   'likes': 211542,
#   'dislikes': 1584,
#   'ratings_enabled': True},
#  'Sd7E_EQxy_g': {'title': 'Hermitcraft 8 Episode 14:  BETRAYING BOATEM',
#   'published_at': '2021-10-03 18:10:15',
#   'duration': '00:28:21',
#   'category': 'Gaming',
#   'views': 998582,
#   'tags': ['minecraft',
#    'hermitcraft season 8',
#    'hermitcraft season 8 scar',
#    'hermitcraft',
#    'hermitcraft 8 scar',
#    'hermitcraft 8',
#    'minecraft hermitcraft',
#    'hermitcraft mega base',
#    'hermitcraft smp',
#    'hermitcraft season 8 big eyes',
#    'hermitcraft traps',
#    'hermitcraft trap shop',
#    'swaggon',
#    'hermitcraft swaggon',
#    'hermitcraft boatem',
#    'boatem',
#    'goodtimeswithscar',
#    'scar',
#    'hermitcraft charged creeper',
#    'hermitcraft charged creeper shop',
#    'hermitcraft 8 shop',
#    'hermitcraft 8 shopping district'],
#   'likes': 61870,
#   'dislikes': 556,
#   'ratings_enabled': True},
#  'afCRuGS5zJo': {'title': "Film Theory: Venom's SECRET Weapon! (Venom vs Carnage)",
#   'published_at': '2021-10-03 17:06:21',
#   'duration': '00:14:16',
#   'category': 'Film & Animation',
#   'views': 2365659,
#   'tags': ['venom',
#    'carnage',
#    'venom 2',
#    'venom 2 trailer',
#    'venom 2 let there be carnage',
#    'let there be carnage',
#    'venom carnage',
#    'venom 2 carnage',
#    'venom 2 scene',
#    'venom vs carnage',
#    'venom carnage fight',
#    'marvel',
#    'film theory venom',
#    'film theory venom 2',
#    'film theory spiderman',
#    'venom 2 post credit scene',
#    'venom 2 spiderman',
#    'venom 2 spiderman scene',
#    'film theory',
#    'matpat',
#    'film theorists',
#    'venom 2 breakdown',
#    'venom 2 easter eggs',
#    'venom let there be carnage',
#    'spiderman no way home',
#    'venom versus carnage'],
#   'likes': 120694,
#   'dislikes': 2099,
#   'ratings_enabled': True},
#  'emcfCsiIdE0': {'title': "Introducing The World's First STREET LEGAL Lamborghini Super Trofeo Evo - Unicorn V4 [4K UHD]",
#   'published_at': '2021-10-03 16:00:30',
#   'duration': '00:07:17',
#   'category': 'Autos & Vehicles',
#   'views': 873888,
#   'tags': [''],
#   'likes': 56976,
#   'dislikes': 864,
#   'ratings_enabled': True},
#  '-u5Dzq83YOI': {'title': 'I started a War over a Piece of Paper',
#   'published_at': '2021-10-03 14:00:00',
#   'duration': '00:11:26',
#   'category': 'Gaming',
#   'views': 822088,
#   'tags': ['rekrap2', 'rekrap', 'rek', 'Echocraft', 'Boatclutch'],
#   'likes': 22942,
#   'dislikes': 352,
#   'ratings_enabled': True},
#  'xXTK7Atcgio': {'title': 'Luis Suarez SCORES as Atletico Madrid dominates Barcelona | LaLiga Highlights | ESPN FC',
#   'published_at': '2021-10-02 21:02:14',
#   'duration': '00:05:42',
#   'category': 'Sports',
#   'views': 884920,
#   'tags': ['atletico madrid',
#    'barcelona',
#    'atletico madrid vs barcelona',
#    'atletico',
#    'barca',
#    'atletico madrid highlights',
#    'barcelona highlights',
#    'barca highlights',
#    'la liga highlights',
#    'la liga',
#    'laliga highlights',
#    'laliga',
#    'luis suarez',
#    'suarez goal',
#    'suarez goal vs barcelona',
#    'atletico madrid goals',
#    'ronald koeman',
#    'antoine griezmann',
#    'suarez barcelona',
#    'thomas lemar',
#    'lemar goal',
#    'suarez koeman',
#    'joao felix',
#    'football',
#    'football highlights',
#    'soccer highlights',
#    'espn',
#    'espnfc',
#    'espn fc',
#    'espn la liga',
#    'espn laliga'],
#   'likes': 7823,
#   'dislikes': 206,
#   'ratings_enabled': True},
#  'nv6kbR-0tMQ': {'title': 'I Found the RICHEST Server in Minecraft! *millionaire*',
#   'published_at': '2021-10-03 14:00:17',
#   'duration': '00:47:40',
#   'category': 'Gaming',
#   'views': 5213141,
#   'tags': ['minecraft',
#    'mcpe',
#    'family',
#    'family friendly',
#    'challenge',
#    'funny',
#    'comedy',
#    'preston',
#    'brianna',
#    'prestonplayz',
#    'briannaplayz'],
#   'likes': 135295,
#   'dislikes': 4034,
#   'ratings_enabled': True},
#  'jXxwVUYhseU': {'title': 'I have skin cancer',
#   'published_at': '2021-10-03 14:00:13',
#   'duration': '00:12:34',
#   'category': 'Travel & Events',
#   'views': 1296648,
#   'tags': ['skin cancer',
#    'skin cancer story',
#    '#vanlife',
#    'couple vlog',
#    'full time travel',
#    'kara and nate',
#    'kara and nate vlog',
#    'travel',
#    'travel couple',
#    'travel couple vlog',
#    'travel vlog',
#    'van life',
#    'van life couple',
#    'van life vlog',
#    'vlog'],
#   'likes': 62476,
#   'dislikes': 1252,
#   'ratings_enabled': True},
#  'gXvPIdLWYQs': {'title': 'Rennes vs PSG | LIGUE 1 HIGHLIGHTS | 10/3/2021 | beIN SPORTS USA',
#   'published_at': '2021-10-03 13:52:41',
#   'duration': '00:10:43',
#   'category': 'Sports',
#   'views': 550932,
#   'tags': ['DiMaria',
#    'FC Metz',
#    'Football',
#    'France Football',
#    'France League 1',
#    'France League1',
#    'France Ligue 1',
#    'France Ligue1',
#    'France Soccer',
#    'French Football',
#    'French Soccer',
#    'Futbol',
#    'Hakimi Achraf',
#    'League 1',
#    'League1',
#    'Ligue 1',
#    'Ligue 1 Highlights',
#    'Ligue1',
#    'Ligue1 Highlights',
#    'Lionel Messi',
#    'Messi',
#    'Metz',
#    'Metz Paris Saint Germain',
#    'Metz vs PSG',
#    'PSG',
#    'Paris Saint Germain',
#    'Rennes',
#    'beIN SPORTS',
#    'beIN SPORTS USA'],
#   'likes': 4122,
#   'dislikes': 170,
#   'ratings_enabled': True},
#  'yEHAv9_OwY0': {'title': '*JOB SIMULATOR* Mod in Among Us',
#   'published_at': '2021-10-03 15:00:20',
#   'duration': '00:15:09',
#   'category': 'Gaming',
#   'views': 7292792,
#   'tags': [''],
#   'likes': 295529,
#   'dislikes': 4421,
#   'ratings_enabled': True},
#  '2fsM4KLI7TI': {'title': 'Best Bottle Flippers Challenge',
#   'published_at': '2021-10-03 01:42:38',
#   'duration': '00:00:57',
#   'category': 'Sports',
#   'views': 20147401,
#   'tags': [''],
#   'likes': 1864628,
#   'dislikes': 51956,
#   'ratings_enabled': True},
#  'C2dj59Db1C4': {'title': 'School Board Meeting - SNL',
#   'published_at': '2021-10-03 05:16:57',
#   'duration': '00:06:41',
#   'category': 'Comedy',
#   'views': 2340341,
#   'tags': ['SNL10022021',
#    'snl snl',
#    'saturday night live',
#    'season 47',
#    'snl 47',
#    'snl school board meeting',
#    'owen wilson',
#    'aidy bryant',
#    'mimkey day',
#    'chloe fineman',
#    'heidi gardner',
#    'alex moffat',
#    'kyle mooney',
#    'ego nwodim',
#    'chris redd',
#    'cecily strong',
#    'kenan thompson',
#    'melissa Villasenor',
#    'bowen yang',
#    'aristotle athari',
#    'Andrew dismukes',
#    'james austin johnson',
#    'punkie johnson',
#    'sarah sherman',
#    's47',
#    's47e1',
#    'premiere',
#    'live',
#    'new york',
#    'Wedding Crashers',
#    'Night at the Museum',
#    'Marley and Me',
#    'Loki',
#    'Zoolander'],
#   'likes': 35344,
#   'dislikes': 4390,
#   'ratings_enabled': True},
#  'GHkUdA68YNI': {'title': 'The Demonic Possessions of Loudun • Puppet History',
#   'published_at': '2021-10-03 17:00:08',
#   'duration': '00:41:57',
#   'category': 'Entertainment',
#   'views': 830455,
#   'tags': ['History',
#    'Puppet history',
#    'shane madej',
#    'ryan bergara',
#    'shane and ryan',
#    'the professor',
#    'funny',
#    'trivia',
#    'educational',
#    'musical',
#    'buzzfeed unsolved',
#    'ruining history',
#    'buzzfeed',
#    'musical history',
#    'weird history',
#    'game show',
#    'puppets',
#    'puppetry',
#    'quiz',
#    'quiz show',
#    'bizarre history',
#    'funny history',
#    'songs',
#    'sara rubin',
#    'loudun',
#    'demon',
#    'posessions',
#    'finale'],
#   'likes': 56898,
#   'dislikes': 452,
#   'ratings_enabled': True},
#  'EAp1piWU4pQ': {'title': 'Weekend Update: Pete Davidson on the Met Gala - SNL',
#   'published_at': '2021-10-03 05:59:49',
#   'duration': '00:03:15',
#   'category': 'Comedy',
#   'views': 2318964,
#   'tags': ['SNL10022021',
#    'snl snl',
#    'saturday night live',
#    'season 47',
#    'snl 47',
#    'snl',
#    'weekend update',
#    'pete davidson',
#    'michael che',
#    'colin jost',
#    's47',
#    's47e1',
#    'premiere',
#    'live',
#    'new york',
#    'comedy',
#    'sketch',
#    'funny',
#    'hilarious',
#    'late night',
#    'host',
#    'music',
#    'guest',
#    'laugh',
#    'impersonation',
#    'actor',
#    'musician',
#    'Owen Wilson',
#    'Kacey Musgraves Wedding Crashers',
#    'Night at the Museum',
#    'Marley and Me',
#    'Loki',
#    'Zoolander',
#    'Starsky and Hutch',
#    'Midnight in Paris',
#    'The Internship',
#    'Meet the Fockers'],
#   'likes': 53010,
#   'dislikes': 1244,
#   'ratings_enabled': True},
#  'dwI6JYirwzo': {'title': '1v1ing Players I Eliminated In Season 1...',
#   'published_at': '2021-10-02 17:48:46',
#   'duration': '00:10:12',
#   'category': 'Gaming',
#   'views': 952063,
#   'tags': ['fortnite',
#    'fortnite season 1',
#    'og fortnite',
#    'og skins fortnite',
#    '1v1ing my biggest hater',
#    '1v1ing people from season 1',
#    '1v1ing Players I Eliminated In OG Fortnite',
#    'tilted towers coming back',
#    "Things Only Fortnite OG's Remember",
#    "Fortnite Moments ONLY OG's Remember",
#    'best fortnite moments',
#    'new fortnite',
#    'fortnite moments only ogs remember',
#    'fortnite og moments',
#    'fortnite nostalgia',
#    'fortnite new update',
#    'new fortnite update',
#    'old fortnite',
#    'history of fortnite',
#    'milo',
#    'soar milo',
#    '1v1'],
#   'likes': 20291,
#   'dislikes': 598,
#   'ratings_enabled': True},
#  'qlbBVSpVhjM': {'title': 'JAMIE OLIVER FINALLY IMPRESS UNCLE ROGER?',
#   'published_at': '2021-10-03 14:00:16',
#   'duration': '00:13:57',
#   'category': 'Comedy',
#   'views': 2776504,
#   'tags': ['nigel ng', 'uncle roger', 'nigel ng comedy'],
#   'likes': 122184,
#   'dislikes': 1410,
#   'ratings_enabled': True},
#  'p3c4FneCNCU': {'title': "Minecraft, But You Can't Leave The End...",
#   'published_at': '2021-10-03 18:15:01',
#   'duration': '00:16:31',
#   'category': 'Gaming',
#   'views': 1529385,
#   'tags': ['minecraft',
#    'mine craft',
#    'manhunt',
#    'speedrunner vs hunter',
#    'Speedrunner vs 3 hunters',
#    'Speedrunner vs 4 hunters',
#    'minecraft but challenge',
#    'minecraft challenge',
#    'beating minecraft',
#    'four hunters',
#    '4 hunters',
#    'wisp',
#    'wispexe',
#    'dream',
#    'henwy',
#    'minecraft manhunt',
#    'minecraft manhunt but',
#    'speedrun',
#    'speedrunner',
#    'manhunt minecraft',
#    'hacks',
#    'op items',
#    'custom',
#    'custom item',
#    'random items',
#    'there are custom',
#    'cant leave the end',
#    'without leaving the end',
#    'better end mod',
#    'the end',
#    'minecraft but you cant leave the end'],
#   'likes': 81065,
#   'dislikes': 1259,
#   'ratings_enabled': True},
#  'laDllIpLs2s': {'title': 'I Got A 5 Ton Military Truck For My Ghost Town!',
#   'published_at': '2021-10-02 20:15:09',
#   'duration': '00:27:05',
#   'category': 'People & Blogs',
#   'views': 646780,
#   'tags': [''],
#   'likes': 47260,
#   'dislikes': 258,
#   'ratings_enabled': True},
#  '75yLWfqDTIU': {'title': 'So I Destroyed *TRYHARDS* While Using A *FACECAM* In Roblox BedWars!',
#   'published_at': '2021-10-03 16:00:09',
#   'duration': '00:08:22',
#   'category': 'Gaming',
#   'views': 501094,
#   'tags': ['Roblox BedWars',
#    'How to win every roblox bedwars game',
#    'best roblox bedwars player',
#    'RobloxBedWars',
#    'Roblox BedWars Kit',
#    'Roblox BedWars Strategy',
#    'Roblox BedWars Tips',
#    'Roblox BedWars Pro',
#    'Roblox BedWars Wins',
#    'MiniBloxia Face Reveal'],
#   'likes': 24387,
#   'dislikes': 327,
#   'ratings_enabled': True},
#  'eFyMO9ro9mI': {'title': 'Minecraft but all Mobs are Dragons',
#   'published_at': '2021-10-03 14:00:12',
#   'duration': '00:19:39',
#   'category': 'Gaming',
#   'views': 4983667,
#   'tags': ['minecraft',
#    'minecraft but',
#    'new minecraft',
#    'craftee',
#    'craft',
#    'crafter',
#    'crafty',
#    'crafting',
# ...
#   'likes': 171598,
#   'dislikes': 2660,
#   'ratings_enabled': True},
#  'v0gUM1FNd6g': {'title': "Addison and Amelia Reunite - Grey's Anatomy",
#   'published_at': '2021-10-15 05:00:30',
#   'duration': '00:04:34',
#   'category': 'Entertainment',
#   'views': 1025911,
#   'tags': ['doctors',
#    'emergency',
#    'hospital',
#    'patients',
#    'residents',
#    'scene'],
#   'likes': 16844,
#   'dislikes': 122,
#   'ratings_enabled': True},
#  '7Shn-TJaOrQ': {'title': 'FRIDAY NIGHT FUNKIN ANIMATION COMPILATION #3',
#   'published_at': '2021-10-15 13:00:09',
#   'duration': '00:08:25',
#   'category': 'Gaming',
#   'views': 1980206,
#   'tags': ['fnf animation compilation',
#    'friday night funkin animation compilation squid game',
#    'fnf animation',
#    'friday night funkin',
#    'fnf',
#    'fnf compilation',
#    'friday night funkin squid game',
#    'fnf funny animation',
#    'fnf squid game animation sky',
#    'fnf animation squid game new',
#    'squid game',
#    'squid game animation',
#    'fnf animation compilation bratoons',
#    'bratoons squidgame',
#    'bratoons new animation squid game',
#    'fnf cartoon',
#    'fnf meme',
#    'fnf animation garcello',
#    'fnf animation whitty',
#    'fnf animation boyfriend squid game'],
#   'likes': 40415,
#   'dislikes': 1988,
#   'ratings_enabled': True},
#  'Kdo3VfD3S7U': {'title': 'Answer This Question to Get Into Harvard',
#   'published_at': '2021-10-14 22:36:45',
#   'duration': '00:00:29',
#   'category': 'Education',
#   'views': 3271744,
#   'tags': [''],
#   'likes': 191177,
#   'dislikes': 2994,
#   'ratings_enabled': True},
#  '52zuk_GcGUI': {'title': 'Enter the World of Tzeentch | Total War: WARHAMMER III',
#   'published_at': '2021-10-15 13:59:34',
#   'duration': '00:01:23',
#   'category': 'Gaming',
#   'views': 522013,
#   'tags': ['Total War',
#    'warhammer',
#    'total war warhammer',
#    'rome total war',
#    'warhammer 2 total war',
#    'total war rome 2',
#    'arena total war',
#    'total war empire',
#    'medieval total war',
#    'medieval total war 2',
#    'three kingdoms total war',
#    'total war gameplay',
#    'shogun 2 total war',
#    'total war saga',
#    'total war warhammer gameplay',
#    '3 kingdoms',
#    'new',
#    'gameplay',
#    'trailer',
#    'tzeentch',
#    'kairos',
#    'tzeentch warhammer 3',
#    'warhammer 3',
#    'total war warhammer 3'],
#   'likes': 22441,
#   'dislikes': 347,
#   'ratings_enabled': True},
#  'BlLMALH5Fzk': {'title': 'Minecraft, But You Can Upgrade TNT...',
#   'published_at': '2021-10-14 22:54:06',
#   'duration': '00:29:36',
#   'category': 'Gaming',
#   'views': 1365234,
#   'tags': ['Minecraft',
#    'Competitive Minecraft',
#    'Minecraft PvP',
#    'TapL',
#    'UHC',
#    'Ultra Hardcore',
#    'Crazy UHC',
#    'Insane Minecraft',
#    'Minecraft Minigames',
#    'Tapple',
#    'Tapple Events',
#    'Tapple Minecraft',
#    'Tapple Server',
#    'Tapple UHC',
#    'TapL UHC',
#    'TapL Challenge',
#    'Challenge',
#    'Tapple Challenge',
#    'Minecraft But',
#    'Minecraft UHC But',
#    'MinecraftBut',
#    'Minecraft Challenge',
#    'Minecraft Challenges',
#    'Minecraft Hardcore',
#    'Beating Minecraft',
#    'Minecraft OP',
#    'OP Minecraft',
#    'Blessed Minecraft',
#    'Cursed Minecraft',
#    'Minecraft Scenario',
#    'Minecraft UHC'],
#   'likes': 55771,
#   'dislikes': 911,
#   'ratings_enabled': True},
#  'v9pprUeZRU0': {'title': 'Power Book II: Ghost | Season 2 Trailer | STARZ',
#   'published_at': '2021-10-14 21:00:52',
#   'duration': '00:01:36',
#   'category': 'Entertainment',
#   'views': 7008850,
#   'tags': ['Power book II',
#    'Ghost',
#    'Power Ghost',
#    'Power never ends',
#    'legacy',
#    'sneak peek',
#    'preview',
#    'Starz',
#    'television',
#    'tv',
#    'new power',
#    'Tariq St. Patrick',
#    'aftermath',
#    'spinoff',
#    'Power spinoff',
#    'finale',
#    'new',
#    'new episodes',
#    'Tasha',
#    'Power',
#    'Power on Starz',
#    'Power II on Starz',
#    'bts',
#    'Power Book II: Ghost clip',
#    'Power book II: Ghost Official Clip',
#    'power book 2',
#    'power book ghost',
#    'official clip',
#    'clip',
#    'deal',
#    'Trailer',
#    'season 2 teaser',
#    'Season 2 Trailer',
#    'Power Book II: Ghost Season 2 Trailer'],
#   'likes': 17696,
#   'dislikes': 201,
#   'ratings_enabled': True},
#  'Zw9Ezf43zmk': {'title': 'Lava Vs Bulletproof Glass!',
#   'published_at': '2021-10-14 20:00:04',
#   'duration': '00:08:06',
#   'category': 'Comedy',
#   'views': 1270357,
#   'tags': ['socksfor1',
#    'sockreacts',
#    'tiktok',
#    'fail compilation',
#    'react',
#    'experiment',
#    'science experiment',
#    'lava vs bulletproof glass',
#    'experiments',
#    'lava experiment',
#    'experiment car',
#    'lava vs glass',
#    'bulletproof glass vs lava',
#    'science experiments',
#    'bulletproof glass',
#    'experiment: lava vs pool',
#    'lava vs bulletproof glass experiment',
#    'bulletproof glass experiment',
#    'lava vs glass experiment',
#    'experiment car vs',
#    'experiment lava vs bullet proof glass',
#    'lavavsbulletproof glass experiment',
#    'science',
#    'satisfying experiments'],
#   'likes': 51722,
#   'dislikes': 779,
#   'ratings_enabled': True},
#  '3AJyg6sGBzs': {'title': 'GOOD NEWS!! COURT DAY + BABY E & ME PHOTOSHOOT!',
#   'published_at': '2021-10-15 01:11:55',
#   'duration': '00:11:35',
#   'category': 'Entertainment',
#   'views': 501140,
#   'tags': ['elsy Guevara',
#    'alondradessy',
#    'alo and elsy',
#    'alo and benny',
#    'alo and tre',
#    'ace family',
#    'Logan Paul',
#    'Charli damelio',
#    'James Charles',
#    'dixie damelio',
#    'lve family',
#    'Kylie jenner',
#    'JAKE PAUL',
#    'addison rae',
#    'morning routine',
#    'day in my life',
#    'jojo siwa',
#    'ADDISON rae',
#    'bryce hall'],
#   'likes': 26915,
#   'dislikes': 223,
#   'ratings_enabled': True},
#  'sNsfvfEi27Y': {'title': 'Chocolate & Coffee Dry Aged Ribeye #shorts',
#   'published_at': '2021-10-14 20:00:10',
#   'duration': '00:00:40',
#   'category': 'People & Blogs',
#   'views': 2003303,
#   'tags': ['dry age at home',
#    'dry aged beef',
#    'dry age beef',
#    'dry aged steak',
#    'dry aging steak at home',
#    'dry aged beef at home',
#    'how to dry age steak at home',
#    'dry aged beef process',
#    'dry aging meat',
#    'dry age beef in fridge',
#    'how to make dry age steak at home',
#    'dry aging experiment',
#    'should I get a dry ager',
#    'dry ager',
#    'dry ager ux1000',
#    'how to use a dry ager fridge',
#    'how to dry age steak',
#    'cool dry aging experiment',
#    'dry aging experiments',
#    'coffee and chocolate steak',
#    'butter basting steak',
#    'butter baste'],
#   'likes': 160570,
#   'dislikes': 1866,
#   'ratings_enabled': True},
#  'Meaw4DlhNRE': {'title': 'RCXD Cars Are Bugged Right Now, Right? #warzone #callofduty #pipboyfresh',
#   'published_at': '2021-10-15 05:05:29',
#   'duration': '00:00:40',
#   'category': 'Gaming',
#   'views': 140227,
#   'tags': ['RCXD',
#    'call of duty',
#    'warzone',
#    'cod',
#    'cod warzone',
#    'rebirth Island'],
#   'likes': 7205,
#   'dislikes': 184,
#   'ratings_enabled': True},
#  'GbPEQHzJaw0': {'title': '30 Things You NEVER Seen In Fortnite',
#   'published_at': '2021-10-14 20:02:03',
#   'duration': '00:08:30',
#   'category': 'Gaming',
#   'views': 340914,
#   'tags': ["31 Things In Fortnite You'll Probably Never See",
#    'fortnite',
#    'fortnite battle royale',
#    'fortnite secrets',
#    'fortnite rare occurrences',
#    'fortnite rarest occurrences',
#    'fortnite luckiest moments',
#    'FORTNITE Items ONLY 0.01% Of Players USED!',
#    'fortnite new',
#    'fortnite new items',
#    'rarest fortnite items',
#    'rarest fortnite',
#    'fortnite rarest items',
#    'fortnite items only 0.01% of players used',
#    'bancily'],
#   'likes': 8029,
#   'dislikes': 143,
#   'ratings_enabled': True},
#  'kDFE92gA3Ag': {'title': 'Generational Shift: New Acura Integra Reveals Manual Transmission',
#   'published_at': '2021-10-14 13:00:22',
#   'duration': '00:00:24',
#   'category': 'Autos & Vehicles',
#   'views': 489146,
#   'tags': ['Integra',
#    'new integra',
#    'acura integra',
#    'integra manual',
#    'integra prototype'],
#   'likes': 17533,
#   'dislikes': 202,
#   'ratings_enabled': True},
#  'Z_xUiW-ozHw': {'title': 'Buccaneers vs. Eagles Week 6 Highlights | NFL 2021',
#   'published_at': '2021-10-15 03:37:15',
#   'duration': '00:12:53',
#   'category': 'Sports',
#   'views': 2568119,
#   'tags': [''],
#   'likes': 25310,
#   'dislikes': 1098,
#   'ratings_enabled': True},
#  'p646h_jLbeM': {'title': "All 15 of Ed's cars are for sale! What's next?",
#   'published_at': '2021-10-15 14:00:20',
#   'duration': '00:09:44',
#   'category': 'Autos & Vehicles',
#   'views': 340963,
#   'tags': ['vinwiki',
#    'ed bolian',
#    'car stories',
#    'car collection',
#    'bugatti',
#    'mclaren f1',
#    'mclaren',
#    'veyron',
#    'chiron',
#    'car hunting',
#    'search',
#    'car trek',
#    'ferrari',
#    'lamborghini',
#    'gated',
#    'manual',
#    'lp640',
#    'roadster',
#    'vehicle history',
#    'app'],
#   'likes': 13661,
#   'dislikes': 210,
#   'ratings_enabled': True},
#  '2nv7qmefMqc': {'title': 'the worst part of squid game (SPOILERS)',
#   'published_at': '2021-10-14 19:24:19',
#   'duration': '00:00:21',
#   'category': 'Film & Animation',
#   'views': 1133440,
#   'tags': [''],
#   'likes': 69604,
#   'dislikes': 578,
#   'ratings_enabled': True},
#  'unkqwbJAKHs': {'title': 'Stephon Marbury calls out Stephen A. for his comments on Kyrie Irving | First Take',
#   'published_at': '2021-10-15 16:59:42',
#   'duration': '00:07:21',
#   'category': 'Sports',
#   'views': 702879,
#   'tags': ['stephon marbury',
#    'stephon marbury china',
#    'nba',
#    'basketball',
#    'first take',
#    'first take today',
#    'first take espn',
#    'stephen a smith',
#    'stephen a smith first take',
#    'stephen a',
#    'espn',
#    'first take espn today',
#    'espn first take',
#    'nfl espn',
#    '#espn',
#    'stephen a. smith',
#    'nfl on espn',
#    'espn first take today',
#    'first take nfl',
#    'kyrie irving',
#    'kyrie irving nets',
#    'kyrie irving espn',
#    'kyrie irving brooklyn nets',
#    'kyrie irving vaccine talk',
#    'kyrie irving vaccine mandate'],
#   'likes': 10518,
#   'dislikes': 3539,
#   'ratings_enabled': True},
#  'zRCMPMGDN00': {'title': 'Curb Your Enthusiasm (2021) | Season 11 Official Trailer | HBO',
#   'published_at': '2021-10-13 17:00:03',
#   'duration': '00:01:55',
#   'category': 'Entertainment',
#   'views': 714795,
#   'tags': ['curb your enthusiasm',
#    'hbo',
#    'curb your enthusiasm trailer',
#    'curb your enthusiasm season 11 trailer',
#    'curb your enthusiasm 2021 trailer',
#    'curb your enthusiasm new season',
#    'curb your enthusiasm 2021',
#    'larry david',
#    'curb your enthusiasm new season guest stars'],
#   'likes': 14524,
#   'dislikes': 173,
#   'ratings_enabled': True},
#  'Oz2CuVf1MGo': {'title': "Bun B: Pimp C Told Jay Z The TV Ain't Got No Temperature, Jay Looked At Me And Said.. Big Pimpin $1M",
#   'published_at': '2021-10-13 13:30:03',
#   'duration': '00:07:23',
#   'category': 'Entertainment',
#   'views': 594292,
#   'tags': [''],
#   'likes': 12727,
#   'dislikes': 188,
#   'ratings_enabled': True},
#  'ZMgY-J51i54': {'title': 'Playing SQUID GAME in Real Life! △○□',
#   'published_at': '2021-10-16 14:45:01',
#   'duration': '00:09:30',
#   'category': 'Entertainment',
#   'views': 6612210,
#   'tags': ['funny', 'comedy', 'challenge', 'family', 'brianna', 'preston'],
#   'likes': 160307,
#   'dislikes': 7331,
#   'ratings_enabled': True},
#  'Ht9v8YLy-O4': {'title': 'Minecraft Death Shuffle...',
#   'published_at': '2021-10-16 07:15:09',
#   'duration': '00:28:17',
#   'category': 'Gaming',
#   'views': 12245359,
#   'tags': ['Dream Minecraft',
#    'dream Minecraft youtube',
#    'minecraft',
#    'dream',
#    'Minecraft Death Shuffle',
#    'Minecraft Block Shuffle',
#    'Minecraft but gravity changes',
#    'Minecraft but water rises every minute',
#    'minecraft but lava rises every minute',
#    'minecraft but challenge',
#    'minecraft challenge',
#    'challenge',
#    'minecraft 1.14',
#    'beating minecraft',
#    'skeppy'],
#   'likes': 970773,
#   'dislikes': 22366,
#   'ratings_enabled': True},
#  'OODneEUWUQY': {'title': 'Peacemaker | Official Teaser | HBO Max',
#   'published_at': '2021-10-16 17:58:38',
#   'duration': '00:02:59',
#   'category': 'Film & Animation',
#   'views': 16424871,
#   'tags': ['hbo',
#    'hbo max',
#    'hbo max series',
#    'peacemaker',
#    'suicide squad',
#    'dcu',
#    'dc universe',
#    'dc superheros',
#    'dc villians',
#    'dc comic books',
#    'suicide squad comic books',
#    'suicide squad dc',
#    'peacemaker series',
#    'peacemaker show hbo',
#    'peacemaker john cena',
#    'john cena',
#    'peacemaker new series'],
#   'likes': 95212,
#   'dislikes': 3963,
#   'ratings_enabled': True},
#  'QPRiHtDLdag': {'title': 'Dream - Minecraft Death Shuffle Extra Scenes',
#   'published_at': '2021-10-16 07:45:37',
#   'duration': '00:10:10',
#   'category': 'People & Blogs',
#   'views': 1308194,
#   'tags': [''],
#   'likes': 121204,
#   'dislikes': 607,
#   'ratings_enabled': True},
#  '5qcKiL7AOD8': {'title': 'Lesnar returns for the Universal Title Match Contract Signing with Reigns: SmackDown, Oct. 15, 2021',
#   'published_at': '2021-10-16 03:34:57',
#   'duration': '00:05:07',
#   'category': 'Sports',
#   'views': 4600535,
#   'tags': ['Brock Lesnar',
#    'Paul Heyman',
#    'Roman Reigns',
#    'SmackDown',
#    'superstars',
#    'world wrestling entertainment',
#    'wrestle',
#    'wrestler',
#    'wrestling',
#    'wwe',
#    'wwe 2021',
#    'مصارعه',
#    'कुश्ती',
#    'डब्लू डब्लू ई',
#    'पहलवान',
#    'मैच',
#    'व्यावसायिक कुश्ती',
#    'सुपरस्टार',
#    'Smackdown clips',
#    'smackdown highlights',
#    'smackdown winners',
#    'smackdown match card',
#    'smackdown tonight',
#    'friday night smackdown',
#    'wwe smackdown',
#    'smackdown 2021',
#    'smackdown fox',
#    'brock lesnar vs roman reigns crown jewel 2021'],
#   'likes': 108967,
#   'dislikes': 2359,
#   'ratings_enabled': True},
#  '3B8g1RsZrlw': {'title': 'The Demonic Possession of the Conjuring House',
#   'published_at': '2021-10-15 22:00:04',
#   'duration': '00:43:30',
#   'category': 'People & Blogs',
#   'views': 4050013,
#   'tags': ['SffZ',
#    'The Demonic Possession of the Conjuring House',
#    'anabelle',
#    'buzzfeed',
#    'buzzfeed supernatural',
#    'buzzfeed unsolved',
#    'buzzfeed unsolved marathon',
#    'buzzfeed unsolved network',
#    'buzzfeed unsolved supernatural',
#    'buzzfeedunsolved',
#    'creepy',
#    'demonic possession',
#    'horror',
#    'investigate',
#    'investigative',
#    'posessed',
#    'scary',
#    'shane unsolved',
#    'supernatural',
#    'the conjuring',
#    'the conjuring house tour',
#    'true crime'],
#   'likes': 222640,
#   'dislikes': 1890,
#   'ratings_enabled': True},
#  'htok8ZvRwhM': {'title': 'WE’RE PREGNANT!!!! (16 WEEKS)',
#   'published_at': '2021-10-16 17:00:04',
#   'duration': '00:18:06',
#   'category': 'People & Blogs',
#   'views': 382304,
#   'tags': ['Carmen and Corey',
#    'We’re pregnant',
#    'Pregnancy',
#    'Carmen and Corey pregnant',
#    '16 weeks pregnant',
#    '16 weeks',
#    'Update',
#    'Vlog',
#    'Carmen pregnant',
#    'Carmen and Corey YouTube',
#    'corey pritchett',
#    'carmen pritchett',
#    'the pritchett family',
#    'carmen and corey drama'],
#   'likes': 33910,
#   'dislikes': 380,
#   'ratings_enabled': True},
#  '6KZi3PviIbA': {'title': '100 Days, But There Are Custom Dimensions...',
#   'published_at': '2021-10-16 13:25:57',
#   'duration': '00:48:20',
#   'category': 'Gaming',
#   'views': 2785685,
#   'tags': ['minecraft',
#    'gaming',
#    'sb737',
#    'sb minecraft',
#    'sb',
#    "let's play",
#    'minecraft hardcore',
#    'hardcore',
#    'surviving 100 days',
#    '100 days',
#    '100 days hardcore',
#    'minecraft 100 days',
#    'custom dimensions',
#    '100 days custom dimensions',
#    'modded dimensions',
#    'modded bosses',
#    'boss mod',
#    'dimensions mod',
#    'custom dimension mod',
#    'hardcore dimension',
#    'hardcore boss',
#    'minecraft dimension mod',
#    'twilight forest',
#    'good nights sleep',
#    'herobrine',
#    'herobrine mod',
#    'atum',
#    'atum 2',
#    'soniccraft',
#    'sonic dimension',
#    'herobrine dimension'],
#   'likes': 86977,
#   'dislikes': 1480,
#   'ratings_enabled': True},
#  'awTXXr6D9nc': {'title': 'I found out which countries have the most GOLD 😳💰',
#   'published_at': '2021-10-15 19:15:00',
#   'duration': '00:01:00',
#   'category': 'Gaming',
#   'views': 4621596,
#   'tags': [''],
#   'likes': 283298,
#   'dislikes': 9335,
#   'ratings_enabled': True}}

# %%
# Make sure you pass the following tests:

assert videos['fkMW60W180E']['title'] == 'SWAWS | Totally Accurate Battlegrounds'

# This is how we test whether you hardcoded the column indices

shuffled_videos = get_videos(os.path.join("data", 'video_data_shuffled.csv'), \
                             os.path.join("data", 'video_ids.json'))

assert videos['fkMW60W180E']['title'] == shuffled_videos['fkMW60W180E']['title']

# %% [markdown]
# **Warning:** `video_data_shuffled.csv` is *not* part of the dataset for the project. When you start on p10, either download the data.zip for p10 from the github repo, or delete `video_data_shuffled.csv`.

# %% [markdown]
# ### Task 3.3: More basic data
#
# Great. We now have the structure of videos ready. Go back and modify `get_videos` to add the following data to each video:
# - published_at
# - duration
# - category
# - views (should be an int)

# %%
assert videos['fkMW60W180E']['published_at'] == "2021-10-12 19:01:41"
assert videos['fkMW60W180E']['duration'] == "00:18:46"
assert videos['fkMW60W180E']['category'] == "Gaming"
assert videos['fkMW60W180E']['views'] == 3172185

# this is how we test whether you hardcoded the column indices

shuffled_videos = get_videos(os.path.join("data", 'video_data_shuffled.csv'), \
                             os.path.join("data", 'video_ids.json'))

assert shuffled_videos['fkMW60W180E']['published_at'] == "2021-10-12 19:01:41"
assert shuffled_videos['fkMW60W180E']['category'] == "Gaming"
assert shuffled_videos['fkMW60W180E']['views'] == 3172185

# %% [markdown]
# ### Task 3.4: Add tags to your video dictionaries
#
# Now, add the `tags` key to each video dictionary.
#
# *Note:* The tags are stored as a string of the form
#
# ```python
# 'Science|quantum physics|the action lab'
# ```
#
# and you need store them as a list that looks like:
#
# ```python
# ['Science', 'quantum physics', 'the action lab']
# ```
#
# What method might be useful for processing these tags?

# %%
# TODO: modify your get_videos function so that each video dictionary also has a tags key
# Make sure it passes the following test:

assert videos['fkMW60W180E']['tags'] == ['tot',
  'totally accurate battlegrounds',
  'tabg',
  'totally accurate battle simulator',
  'totally accurate battlegrounds gameplay',
  'totally accurate battle grounds',
  'tabg gameplay',
  'tabg game',
  'tabs',
  'totally accurate',
  'totally accurate battle royale',
  'battle royale',
  'tabg funny',
  'fortnite',
  'battlegrounds',
  'tabs battle royale',
  'new battle royale',
  'pubg',
  'totally accurate battlegrounds funny',
  'swaws',
  'swaws meme',
  'swaws russian badger',
  'tabg update',
  'tabg win',
  'tabg br',
  'free to play pc games',
  'free to play']

# %% [markdown]
# ### Task 3.5: Add likes, dislikes and ratings_enabled
#
# Some videos have their ratings disabled. We will assume that ratings have been disabled if `likes` or `dislikes` have a value of `''` (the empty string). Each video will have `likes`, `dislikes` and `ratings_enabled` as follows:
#
# - `ratings_enabled` is True if neither `likes` nor `dislikes` is `''`. Otherwise, it is False.
# - The value stored for `likes` and `dislikes` should be `None` if `ratings_enabled` is False.
# - If `ratings_enabled` is True, then `likes` and `dislikes` should just be stored as the ints we read from the csv.
#
# Go back and modify `get_videos` accordingly.

# %%
assert videos['fkMW60W180E']['likes'] == 210951
assert videos['fkMW60W180E']['dislikes'] == 1824
assert videos['fkMW60W180E']['ratings_enabled'] == True

assert videos['UeFnH1DKYIE']['likes'] == None
assert videos['UeFnH1DKYIE']['dislikes'] == None
assert videos['UeFnH1DKYIE']['ratings_enabled'] == False

# %% [markdown]
# There's a few more modifications we need to make to `get_videos`, such as reading in the channel name, but we'll do that in the project. That's it for the lab! Feel free to start working on p10.
