# %% [markdown]
# # Lab-P12:  Web Requests, Caching, DataFrames and Scraping
# Version: 4/20, 11:40PM

# %% [markdown]
# ## Segment 1: Web Requests and File Downloads

# %% [markdown]
# Import the `time`, `requests`, `os`, `json`, `pandas` and `BeautifulSoup` modules.
#
# For `pandas`, import it as `pd` - as was done in lecture. You can refer to the [lecture material](https://github.com/tylerharter/caraza-harter-com/blob/master/tyler/meena/cs220/s22/materials/readings/pandas-intro.ipynb) for help.

# %%
#Write import statements here

import time
import requests
import os
import json
import pandas as pd

from bs4 import BeautifulSoup

# %% [markdown]
# ### Task 1.1 Fetch `rankings.json` from an internet URL
#
# Use the `requests` library to fetch the file at this URL: `https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/rankings.json`. Make sure to call the appropriate function to raise an HTTPError if status code is not 200.
#
# Recall that you can invoke the `.json` method using the response object instance to convert the response content into the appropriate Python data structure. Store the JSON representation into a variable called `data_json`.

# %%
# Write your code here

url = "https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/rankings.json"

try:
    r = requests.get(url)
    r.raise_for_status()
    data_json = r.json()
    
except requests.HTTPError as e:
    print("oops!!", e)

# %%
assert(data_json[25]["Institution"] == "New York University")
assert(data_json[-10]["Score"] == 65.8)
assert(data_json[5]["National Rank"] == 4)

# %% [markdown]
# ### Task 1.2 Measure the time taken to fetch `rankings.json` from an Internet URL
#
# The `time.time()` function returns the time at which it was called. By enclosing some code between two time values, we can measure how long it takes to run. Try it for the code in Task 1.1.

# %%
t1 = time.time()

# Copy and paste your Task 1.1 code here

url = "https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/rankings.json"

try:
    r = requests.get(url)
    r.raise_for_status()
    data_json = r.json()
    
except requests.HTTPError as e:
    print("oops!!", e)

t2 = time.time()

duration = (t2-t1) * 1000 #converting seconds to milliseconds
print("Fetching the data from a URL took {:.2f} milliseconds".format(duration))
# Out:
# Fetching the data from a URL took 345.98 milliseconds

# %% [markdown]
# ### Task 1.3 Save `rankings.json` as a file
#
# Save the `data_json` variable defined in the previous task to a file `rankings.json`.
#
# **Hint**: Recall the use of the `json.dump` function from [lecture](https://www.msyamkumar.com/cs220/s22/materials/lecture_ppts/lec_19_S22.pdf)

# %%
# Your code here

def write_json(path, data):
    with open(path, 'w', encoding="utf-8") as f:
        json.dump(data, f, indent=2)

write_json("rankings.json", data_json)

# %%
assert(os.path.exists("rankings.json"))

# %% [markdown]
# Check your `lab12` directory in Finder (Mac) / Explorer (Windows). It should have a file `rankings.json`.

# %% [markdown]
# ### Task 1.4 Measure the time taken to fetch `rankings.json` from a saved file

# %% [markdown]
# Read the contents of the file saved in Task 1.3 into a variable called `read_data` and measure how long it takes. Use the `read_json` method from [lecture](https://www.msyamkumar.com/cs220/s22/materials/lecture_ppts/lec_19_S22.pdf) to read JSON data from a file.

# %%
t1 = time.time()

# Write your code here

def read_json(path):
    with open(path, encoding="utf-8") as f:
        return json.load(f) 

read_data = read_json("rankings.json")   

t2 = time.time()

duration = (t2-t1) * 1000

print("Fetching the data from a file took {:.2f} milliseconds".format(duration))
# Out:
# Fetching the data from a file took 15.06 milliseconds

# %%
assert(read_data[25]["Institution"] == "New York University")
assert(read_data[-10]["Score"] == 65.8)
assert(read_data[5]["National Rank"] == 4)

# %% [markdown]
# Fetching the file from your computer should have been much faster than fetching it from a URL. If this was not the case, ask a TA!
#
# Web browsers use a similar technique to make browsing faster. The first time you visit a page, the web browser will download the content, and also save it on your computer. If you need to view the same page again soon, your browser may use the file on your computer instead of re-fetching the original. This technique is called **caching**.

# %% [markdown]
# ### Task 1.5 Implement caching via the `download` function
#
# Now, implement a function `download` to download data from the internet and save it to a file.
#
# This function takes in two arguments `filename` and `url`. The contents at the address pointed to by the `url` field should be saved into the file whose path is specified by `filename`.
#
# This function will implement caching. Before downloading the file from the internet, the function should check if the file is already downloaded. If it is, return a message indicating that the file already exists and do not send a request to the URL.

# %%
def download(filename, url):
    if os.path.exists(str(filename)):
        return (str(filename) + " already exists!")

    try:
        r = requests.get(url)
        r.raise_for_status()
        data_json = r.json()
        
        write_json(str(filename), data_json)
        
    except requests.HTTPError as e:
        print("oops!!", e)
        
    except json.JSONDecodeError: 
        data_text = r.text
        
        file_obj = open(str(filename), "w")
        file_obj.write(data_text)
        file_obj.close()
    
    return (str(filename) + " created!")

# def download(filename, url):
#     if os.path.exists(str(filename)):
#         return (str(filename) + " already exists!")

#     try:
#         r = requests.get(url)
#         r.raise_for_status()
#         data_json = r.json()
        
#         write_json(str(filename), data_json)
        
#     except requests.HTTPError as e:
#         print("oops!!", e)

    
#     return (str(filename) + " created!")

# %% [markdown]
# ### Task 1.6 Test the `download` function
#
# Run the cell below to test your function. Think about why the test code is written in this way. Ask a TA if you're not sure.

# %%
rankings_url = "https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/rankings.json"
os.remove("rankings.json") ## delete the existing file
download("rankings.json", rankings_url)

assert(os.path.exists("rankings.json"))
assert(os.path.getsize("rankings.json") > 1600000 and os.path.getsize("rankings.json") < 2500000)
assert (download("rankings.json",rankings_url) == "rankings.json already exists!" )

# %% [markdown]
# You will have to use this `download` function to download files during p12. This will ensure that you do not download the files each time you 'Restart & Run All'.

# %% [markdown]
# ## Segment 2:  Creating DataFrames
#
# For this project, we will be analyzing statistics about world university rankings adapted from
# [here](https://cwur.org/). The `rankings.json` file was created by scraping content from pages on the linked website.
#
# We are going to use `pandas` throughout the lab and project to analyze this dataset.

# %% [markdown]
# ### Task 2.1 Load data from `rankings.json` into a dataframe

# %% [markdown]
# In lecture, you reviewed different ways to create pandas DataFrames. For this task, create a DataFrame `rankings` by reading the JSON data saved in `rankings.json`.
#
# We covered the `read_csv` method of pandas in lecture to read CSV files into a DataFrame. Now, we are going to use a similar method `read_json` to read a JSON file into a dataframe. Try this below, and seek help from a TA if you face any trouble.
#
# Remember to cast the return value explicitly into a DataFrame object. You must do this throughout the lab and project.
# Sometimes, the `read_json` function's returned DataFrame has type issues on Windows laptops. Hence the need for explicit type conversion.

# %%
# Use the read_json method of pandas to create a DataFrame by reading from a file
# Cast the return value of read_json to a DataFrame explicitly

rankings = pd.DataFrame(read_json("rankings.json"))

rankings.head()
# Out:
#    World Rank       Year                            Institution  \
# 0           1  2019-2020                     Harvard University
# 1           2  2019-2020  Massachusetts Institute of Technology
# 2           3  2019-2020                    Stanford University
# 3           4  2019-2020                University of Cambridge
# 4           5  2019-2020                   University of Oxford
#
#           Country  National Rank  Quality of Education Rank  \
# 0             USA              1                        2.0
# 1             USA              2                        1.0
# 2             USA              3                        9.0
# 3  United Kingdom              1                        4.0
# 4  United Kingdom              2                       10.0
#
#    Alumni Employment Rank  Quality of Faculty Rank  Research Performance Rank  \
# 0                     1.0                      1.0                        1.0
# 1                    10.0                      2.0                        5.0
# 2                     3.0                      3.0                        2.0
# 3                    19.0                      5.0                       11.0
# 4                    24.0                     10.0                        4.0
#
#    Score
# 0  100.0
# 1   96.7
# 2   95.2
# 3   94.1
# 4   93.3

# %%
assert(type(rankings) == pd.DataFrame)
assert(rankings.iloc[0]["Institution"] == 'Harvard University')
assert(rankings.iloc[1]["Score"]== 96.7)

# %% [markdown]
# ### Task 2.2 Find the unique universities in the dataset
#
# As the dataset contains rankings for three different years, the same university may have featured multiple times. Find the names of the unique universities that are represented in the dataset.
#
# First, extract just the names of the institutions as a pandas Series. Then, make a list of unique names called `institutions`. Think about what data structure(s) you have been using to extract unique values from a list. Series can be easily converted into that useful data structure, and that data structure can be converted back into a series.

# %%
# Create a pandas `Series` of just the institution names in the dataset. 

institutions = pd.Series(rankings['Institution'].unique())

university_count = len(institutions)

print(university_count)
print(type(institutions))
# Out:
# 2156
# <class 'pandas.core.series.Series'>

# %%
assert(type(institutions) == pd.Series)
assert(len(institutions) == 2156)

# %% [markdown]
# ### Task 2.3 Use `value_counts` to count instances in a dataframe
#
# Now, let's find the country that is the 5th most represented in the dataframe, and the number of times it features. Recall that `value_counts` enables us to count number of occurrences of unique values in a pandas Series.
#
# #### Task 2.3a Obtain the counts for all countries
#
# First, use the `value_counts` function to return a pandas series called `country_counts`. This series contains each country in the dataset and the number of times it occurs.

# %%
country_counts = rankings['Country'].value_counts()

# %%
assert(type(country_counts) == pd.Series)
assert(country_counts["USA"] == 1062)
assert(len(country_counts) == 103)

# %% [markdown]
# #### Task 2.3b Find the 5th most represented country
#
# Use the `.index` attribute of the `Series` `country_counts` to fetch the name of the 5th most represented country. Use `loc` or `iloc` to fetch the count of this country. Make sure to use the pandas series defined in Task 2.3a.
#
# **Hint**: The pandas `Series.index` works differently from the `.index` method you are familiar with for python lists. `Series.index` takes in the numerical index of the element you want to access, and returns the label you can pass to `.loc` to access it.

# %%
country = country_counts.index[4]
count = country_counts.iloc[4]

print(country, count)
# Out:
# France 256

# %%
assert(country == "France")
assert(count == 256)

# %% [markdown]
# ### Task 2.4 `loc` vs `iloc`

# %% [markdown]
# In this lab and project, you must only use `iloc`. Using `loc` will be considered hardcording. This is since `iloc` selects rows and columns at the given integer position while `loc` selects rows at the given pandas index.
#
# Intuition: Recall that row index can be given meaningful names like string indices. Consider a scenario where you add rows to the beginning of the DataFrame - if you use `.loc` indexing, your answer will become incorrect if the data changes. Whereas if you use `.iloc`, you will always get the correct answer.
#
# This distinction may not be as intuitive for the current `rankings` dataframe. As an example, use both `loc` and `iloc` to fetch the first row in `rankings`.

# %%
first_row_iloc = rankings.iloc[0]
print(first_row_iloc)

print()

first_row_loc = rankings.loc[0]
print(first_row_loc)
# Out:
# World Rank                                    1
# Year                                  2019-2020
# Institution                  Harvard University
# Country                                     USA
# National Rank                                 1
# Quality of Education Rank                   2.0
# Alumni Employment Rank                      1.0
# Quality of Faculty Rank                     1.0
# Research Performance Rank                   1.0
# Score                                     100.0
# Name: 0, dtype: object
#
# World Rank                                    1
# Year                                  2019-2020
# Institution                  Harvard University
# Country                                     USA
# National Rank                                 1
# Quality of Education Rank                   2.0
# Alumni Employment Rank                      1.0
# Quality of Faculty Rank                     1.0
# Research Performance Rank                   1.0
# Score                                     100.0
# Name: 0, dtype: object

# %% [markdown]
# The results are exactly the same! This happens since the integer positions correspond to the pandas indices in the `rankings` dataframe. However, this will not always hold true - as we see in the next task.

# %% [markdown]
# ### Task 2.5 Use boolean indexing to filter data

# %% [markdown]
# Now, use boolean indexing to extract data from the dataframe. Recall boolean indexing from [lecture](https://github.com/tylerharter/caraza-harter-com/blob/master/tyler/meena/cs220/s22/materials/meena_lec_notes/lec-28/lec_28_pandas2.ipynb)
#
# Create a dataframe `rankings_arg_bra` that only consists of rankings of universities from Argentina and Brazil. Extract the first value in this new dataframe. As you'll see, using `loc` will not work the same way it did before. The code in line 5 of the next cell should now return a KeyError.
#
# **Hint**: When implementing boolean indexing in pandas, the `or` operator is represented by `|` and the `and` operator is represented by `&`.

# %%
rankings_arg_bra = rankings[(rankings['Country'] == 'Argentina') | (rankings['Country'] == 'Brazil')]

rankings_arg_bra
# Out:
#       World Rank       Year                                 Institution  \
# 127          128  2019-2020                     University of São Paulo
# 343          344  2019-2020                  University of Buenos Aires
# 348          349  2019-2020        Federal University of Rio de Janeiro
# 352          353  2019-2020                      University of Campinas
# 443          444  2019-2020                  São Paulo State University
# ...          ...        ...                                         ...
# 5870        1871  2021-2022  Federal Rural University of Rio de Janeiro
# 5908        1909  2021-2022                 Federal University of Piauí
# 5944        1945  2021-2022              Federal University of Amazonas
# 5975        1976  2021-2022              National University of Tucumán
# 5995        1996  2021-2022             Santa Catarina State University
#
#         Country  National Rank  Quality of Education Rank  \
# 127      Brazil              1                      457.0
# 343   Argentina              1                      238.0
# 348      Brazil              2                      378.0
# 352      Brazil              3                        NaN
# 443      Brazil              4                        NaN
# ...         ...            ...                        ...
# 5870     Brazil             53                        NaN
# 5908     Brazil             54                        NaN
# 5944     Brazil             55                        NaN
# 5975  Argentina             10                        NaN
# 5995     Brazil             56                        NaN
#
#       Alumni Employment Rank  Quality of Faculty Rank  \
# 127                    264.0                    219.0
# 343                   1222.0                      NaN
# 348                    408.0                      NaN
# 352                      NaN                      NaN
# 443                      NaN                      NaN
# ...                      ...                      ...
# 5870                     NaN                      NaN
# 5908                     NaN                      NaN
# 5944                     NaN                      NaN
# 5975                     NaN                      NaN
# 5995                   936.0                      NaN
#
#       Research Performance Rank  Score
# 127                        89.0   80.7
# 343                       320.0   76.1
# 348                       335.0   76.0
# 352                       324.0   76.0
# 443                       416.0   74.8
# ...                         ...    ...
# 5870                     1793.0   66.2
# 5908                     1834.0   66.1
# 5944                     1870.0   65.9
# 5975                     1901.0   65.8
# 5995                     1938.0   65.8
#
# [196 rows x 10 columns]

# %%
first_row_iloc = rankings_arg_bra.iloc[0]
print(first_row_iloc)

# first_row_loc = rankings_arg_bra.loc[0]
# print(first_row_loc)
# Out:
# World Rank                                       128
# Year                                       2019-2020
# Institution                  University of São Paulo
# Country                                       Brazil
# National Rank                                      1
# Quality of Education Rank                      457.0
# Alumni Employment Rank                         264.0
# Quality of Faculty Rank                        219.0
# Research Performance Rank                       89.0
# Score                                           80.7
# Name: 127, dtype: object

# %% [markdown]
# Oops! We see that using `.loc` now causes a KeyError.
#
# `.loc[0]` tries to find the row with the *labeled* index 0. Run the cell below and notice how `rankings_arg_bra` starts at the labeled index 127. There is no 0. Hence the KeyError.

# %%
rankings_arg_bra.head()
# Out:
#      World Rank       Year                           Institution    Country  \
# 127         128  2019-2020               University of São Paulo     Brazil
# 343         344  2019-2020            University of Buenos Aires  Argentina
# 348         349  2019-2020  Federal University of Rio de Janeiro     Brazil
# 352         353  2019-2020                University of Campinas     Brazil
# 443         444  2019-2020            São Paulo State University     Brazil
#
#      National Rank  Quality of Education Rank  Alumni Employment Rank  \
# 127              1                      457.0                   264.0
# 343              1                      238.0                  1222.0
# 348              2                      378.0                   408.0
# 352              3                        NaN                     NaN
# 443              4                        NaN                     NaN
#
#      Quality of Faculty Rank  Research Performance Rank  Score
# 127                    219.0                       89.0   80.7
# 343                      NaN                      320.0   76.1
# 348                      NaN                      335.0   76.0
# 352                      NaN                      324.0   76.0
# 443                      NaN                      416.0   74.8

# %% [markdown]
# ### Task 2.6 Sort the dataframe

# %% [markdown]
# The dataframe in Task 2.5 is sorted by World Rank, with the result that universities from Argentina and Brazil are interleaved throughout the data. Re-sort the data to sort by country so that all universities from Argentina appear first followed by universities from Brazil. Within each country, the universities should be sorted by their National Rank.
#
# Use the `sort_values` function of `pandas`. Remember - by default, `pandas` returns a new sorted DataFrame and does not modify the existing one.
#
# Recall that `sort_values` takes an argument for the parameter `by` as the column name, based on which you want to do the sorting. If you want to use one column for primary sorting and another for secondary sorting, you can specify a list of column names.

# %%
sorted_rankings_arg_bra = rankings_arg_bra.sort_values(["Country", "National Rank"])

sorted_rankings_arg_bra.head()
# Out:
#       World Rank       Year                      Institution    Country  \
# 343          344  2019-2020       University of Buenos Aires  Argentina
# 2353         354  2020-2021       University of Buenos Aires  Argentina
# 4355         356  2021-2022       University of Buenos Aires  Argentina
# 595          596  2019-2020  National University of La Plata  Argentina
# 2618         619  2020-2021  National University of La Plata  Argentina
#
#       National Rank  Quality of Education Rank  Alumni Employment Rank  \
# 343               1                      238.0                  1222.0
# 2353              1                      327.0                  1281.0
# 4355              1                      319.0                  1347.0
# 595               2                      495.0                  1337.0
# 2618              2                        NaN                  1404.0
#
#       Quality of Faculty Rank  Research Performance Rank  Score
# 343                       NaN                      320.0   76.1
# 2353                      NaN                      321.0   75.9
# 4355                      NaN                      324.0   75.9
# 595                       NaN                      557.0   73.2
# 2618                      NaN                      583.0   73.0

# %%
assert(sorted_rankings_arg_bra.iloc[0]["Institution"] == "University of Buenos Aires")
assert(sorted_rankings_arg_bra.iloc[-1]["World Rank"] == 1997)

# %% [markdown]
# ### Task 2.7 Create a new, simplified dataframe to track changes in rankings

# %% [markdown]
# As we have seen, universities that have featured in rankings of multiple years are featured repeatedly. To simplify comparisons, we want to feature each university once and remove all other metrics.
#
# This time - instead of simply ranking universities, we want to find the absolute change in universities' rankings between the year 2019-2020 and 2020-2021. We are only interested in the absolute change and not whether the rank improved or declined.
#
# First, let's attempt to measure the change for one particular university.
#
# **Hint**: The `abs` function can be used to find the absolute value.
#
# #### Task 2.7a Find the absolute difference in World Rank for "University of Madras" between 2019-2020 and 2020-2021
#
# Store the difference in a variable `absolute_diff_madras`

# %%
# First find the ranking of "University of Madras" in the year "2019-2020"
# Then find the ranking of "University of Madras" in the year "2020-2021
# Remember to use .iloc[0] to extract the value

univ_of_madras_19_20 = rankings[(rankings['Institution'] == "University of Madras") \
                          & (rankings['Year'] == "2019-2020")]

univ_of_madras_20_21 = rankings[(rankings['Institution'] == "University of Madras") \
                          & (rankings['Year'] == "2020-2021")]

absolute_diff_madras = abs(univ_of_madras_19_20.iloc[0]['World Rank'] - univ_of_madras_20_21.iloc[0]['World Rank'])

absolute_diff_madras
# Out:
# 108

# %%
assert(absolute_diff_madras == 108)

# %% [markdown]
# #### Task 2.7b Create a Series with the absolute difference in ranks for "University of Madras" between 2019-2020 and 2020-2021
#
# First, create a dictionary with the keys as "Institution" and "Absolute Change". The values should be the relevant values for "University of Madras". Then, convert this dictionary to a Series called `madras_series`.

# %%
madras_dict = {}

madras_dict['Institution'] = univ_of_madras_19_20['Institution'].iloc[0]
madras_dict['Absolute Change'] = absolute_diff_madras

madras_series = pd.Series(madras_dict)

madras_series
# Out:
# Institution        University of Madras
# Absolute Change                     108
# dtype: object

# %%
assert(madras_series["Institution"] == "University of Madras")
assert(madras_series["Absolute Change"] == 108)

# %% [markdown]
# #### Task 2.7c Create the `change_in_rankings` dataframe
#
# Now, create a dataframe `change_in_rankings` with just 2 columns, "Institution" and "Absolute Change" where each university is only featured once. For this task, we are interested in universities in all countries. If the institution is not present in the rankings of either year, we will ignore it.
#
# The institutions should be sorted in increasing order of their absolute change. For institutions with the same absolute change, sort them alphabetically by their names.
#
# Note: this cell may take a few seconds to run.

# %%
y1 = "2019-2020"
y2 = "2020-2021"

rank_list = []
   
for inst in institutions:
    tr = rankings[rankings['Institution'] == inst]

    years = tr.Year.tolist()

    if y1 not in years or y2 not in years:
        continue
           
    y1_rank = int(tr[tr['Year'] == y1].iloc[0]['World Rank'])
    y2_rank = int(tr[tr['Year'] == y2].iloc[0]['World Rank'])
    
    abs_diff = abs(y2_rank - y1_rank)
    
    inst_dict = {'Institution': inst, 'Absolute Change': abs_diff}

    rank_list.append(inst_dict)

change_in_rankings = pd.DataFrame(rank_list)

change_in_rankings = change_in_rankings.sort_values(['Absolute Change', 'Institution'])

change_in_rankings
# Out:
#                                            Institution  Absolute Change
# 10                  California Institute of Technology                0
# 229                       Charles University in Prague                0
# 5                                  Columbia University                0
# 28                                          ETH Zurich                0
# 0                                   Harvard University                0
# ...                                                ...              ...
# 1306                                   Trinity College              620
# 990                        Franklin & Marshall College              725
# 383       École des Hautes Études en Sciences Sociales              810
# 1875                                   Antioch College             1046
# 1832  USI - University of Italian Speaking Switzerland             1081
#
# [1891 rows x 2 columns]

# %% [markdown]
# Test your function below.

# %%
change_in_rankings.iloc[-1]
# Out:
# Institution        USI - University of Italian Speaking Switzerland
# Absolute Change                                                1081
# Name: 1832, dtype: object

# %%
assert(change_in_rankings.iloc[100]["Institution"] == "Vrije Universiteit Brussel")
assert(change_in_rankings.iloc[-1]["Absolute Change"] == 1081)
assert(change_in_rankings.shape[1] == 2)

# %% [markdown]
# # Segment 3: Lint
#
# The p12 autograder introduces lint checks to detect bad coding style.
# "Lint" refers to bad code that is not necessarily buggy (though "bad" coding style often leads to bugs).  A linter helps warn you about common issues. If you are interested in finding out about the origins of this term, check out the [Wikipedia page](https://en.wikipedia.org/wiki/Lint_(software)).
#
# For project p12, we're adding a linter as part of `test.py`. It will notify you of code that is bad style, deducting 1% per issue (for a max of a 10% penalty).

# %% [markdown]
# ### Task 3.1 Install the pylint module
#
# For the linter to run properly, install the `pylint` module by running this command in your terminal.
#
# `
# pip install pylint
# `
#
# Verify that the installation worked by simply running the `pylint` command in your terminal. You should see text explaining the various `pylint` options available. If you see a `command not found` error, ask a TA!

# %% [markdown]
# ### Task 3.2 Run the pylint module
#
# In a new notebook (e.g., named `lint_nb.ipynb`), paste the following code and save the notebook.

# %%
def abs(list):
    # Objective: return a new list, which contains absolute values of 
    #            items from the original list
    list = list[:] # copy it
    for i in range(len(list)):
        if list[i] < 0:
            list[i] = -list[i]
    return list

abs([-1, -3, 5, -4, 8])
# Out:
# [1, 3, 5, 4, 8]

# %% [markdown]
# Now open your terminal (Windows: PowerShell, Mac: Terminal), navigate to the directory you are currently working on (the folder which contains the lint_nb.ipynb and lint.py), and run the linter:
#
# `
# python lint.py -v lint_nb.ipynb
# `
#
# The command above assumes your code is in a notebook called `lint_nb.ipynb`. If you want to test some other code you've written in a different notebook, simply substitute `lint_nb.ipynb` with the name of your notebook (e.g. `main.ipynb`)
#
# Consider why the linter is complaining, then write a better version of the function to make the linter happy. Recall that any word with green syntax highlighting in jupyter notebook is a Python keyword. You should not be using such words as variable names or function names.
#
# You can find extensive documentation for the file lint.py [here](https://github.com/msyamkumar/cs220-s22-projects/tree/main/linter). If you find the linter confusing, please read the full documentation there!

# %% [markdown]
# # Segment 4: BeautifulSoup

# %% [markdown]
# As mentioned in Segment 2, the `rankings.json` file is created by parsing HTML content on the Web, specifically the web pages listed below.
# * https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/2019-2020.html
# * https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/2020-2021.html
# * https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/2021-2022.html
#
# Now, let's write a function to do this ourselves. We will use the `BeautifulSoup` library to scrape web pages and extract information.

# %% [markdown]
# ### Task 4.1 Download the HTML files
# Use the `download` function you previously created to download the contents of each of the URLs above and save them into files. Name the files `2019-2020.html`, `2020-2021.html` and `2021-2022.html` based on the respective URL.

# %%
# Your code here

url_1 = "https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/2019-2020.html"
url_2 = "https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/2020-2021.html"
url_3 = "https://raw.githubusercontent.com/msyamkumar/cs220-s22-projects/main/p12/2021-2022.html"

download('2019-2020.html', url_1)
download('2020-2021.html', url_2)
download('2021-2022.html', url_3)
# Out:
# '2021-2022.html already exists!'

# %% [markdown]
# ### Task 4.2 Read `2019-2020.html` content into a variable
#
# **Note:** If you get a `UnicodeDecodeError`, make sure all your calls to `open()` have the keyword argument `encoding="utf-8"`. Delete the downloaded files and run the cell above again.

# %%
# Your code here

file_obj = open("2019-2020.html", "r")

content = file_obj.read()

file_obj.close()

print(content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#
# <meta name="description" content="The Center for World University Rankings (CWUR) is a leading consulting organization and publisher of the largest academic ranking of global universities.">
#
# <meta name="keywords" content="ranking, rankings, university, universities, college, colleges, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, world, top, best, global, Ranking universitario mundial, Classement mondial des universités , Weltweites Universitätsranking, Zentrum für weltweite Universitätsrankings , דירוג האוניברסיטאות העולמי, המרכז לדירוג האוניברסיטאות העולמי, 세계 대학순위, が世界の大学トップ, 世界大學排名中心, 세계대학랭킹센터,世界大学ランキングセンター, Ranking mundial universitário, Рейтинг университетов мира , разработки рейтинга университетов мира, مركز ,تصنيف الجامعات العالمية ,تصنيف, الجامعات, جامعات, العالم, تصنيف الجامعات, مركز تصنيف الجامعات العالمية, Ranking de universidades del mundo, subject, subjects, journal, journals, ranking by subjects, country ranking, country rankings">
#
# <link rel="icon" type="image/png" href="../../favicon.png" />
#
# <!-- Bootstrap core CSS -->
# <link href="../../dist/css/bootstrap.min.css" rel="stylesheet">
# <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->
# <link href="../../assets/css/ie10-viewport-bug-workaround.css" rel="stylesheet">
#
# <!-- Custom styles for this template -->
# <link href="../../starter-template.css" rel="stylesheet">
#
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# <![endif]-->
#
# <style type="text/css">
# /* CSS used here will be applied after bootstrap.css */
#
# .navbar-custom {
#     color: #FFFFFF;
#     background-color: #222222;
#     border-color: #222222;
# }
#
# </style><title>World University Rankings 2019-20</title>
# </head>
#
# <body>
# <nav class="navbar navbar-inverse navbar-fixed-top">
#       <div class="container">
#             <div class="navbar-header">
#               <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#navbar" aria-expanded="false" aria-controls="navbar">
#                 <span class="sr-only">Toggle navigation</span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#               </button>
#               <a href="http://cwur.org"><img src="../images/logo_944_400.png" height="50"></a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#             </div>
#             <div id="navbar" class="navbar-collapse collapse">
#               <ul class="nav navbar-nav">
#                 <li><a href="../about.php" style="color:white">About</a></li>
#
#                 <li class="dropdown">
#                   <a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false" style="color:white">World University Rankings <span class="caret"></span></a>
#                   <ul class="dropdown-menu">
#                     <li class="dropdown-header">World University Rankings</li>
#                     <li><a href="../2021-22.php">2021-22</a></li>
#                     <li><a href="../2020-21.php">2020-21</a></li>
#                     <li><a href="../2019-20.php">2019-20</a></li>
#                     <li><a href="../2018-19.php">2018-19</a></li>
#                     <li><a href="../2017.php">2017</a></li>
#                     <li><a href="../2016.php">2016</a></li>
#                     <li><a href="../2015.php">2015</a></li>
#                     <li><a href="../2014.php">2014</a></li>
#                     <li><a href="../2013.php">2013</a></li>
#                     <li><a href="../2012.php">2012</a></li>
#                     <li role="separator" class="divider"></li>
#                     <li class="dropdown-header">University Rankings by Country</li>
#                     <li><a href="../2018-19/country.php">2018-19</a></li>
#                     <li><a href="../2017/country.php">2017</a></li>
#                     <li><a href="../2016/country.php">2016</a></li>
#                     <li><a href="../2015/country.php">2015</a></li>
#                     <li><a href="../2014/country.php">2014</a></li>
#                     <li role="separator" class="divider"></li>
#
#                     <li><a href="../2017/subjects.php">Rankings by Subject</a></li>
#                   </ul>
#                 </li>
#                 <li class="dropdown">
#                   <a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false" style="color:white">Methodology <span class="caret"></span></a>
#                   <ul class="dropdown-menu">
#                     <li><a href="../methodology/world-university-rankings.php">World University Rankings</a></li>
#                     <li><a href="../methodology/subject-rankings.php">Subject Rankings</a></li>
#                   </ul>
#                 </li>
#                 <li><a href="../media.php" style="color:white">Media</a></li>
#               </ul>
#             </div>
#           </div>
#         </nav>
#
#
# <div class="container">
#  <div class="page-header">
#   <h4>World University Rankings 2019-20</h4>
#
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <!-- <div class="addthis_toolbox addthis_default_style addthis_32x32_style"> <a class="addthis_button_preferred_1"></a> <a class="addthis_button_preferred_2"></a> <a class="addthis_button_preferred_3"></a> <a class="addthis_button_preferred_4"></a><a class="addthis_button_compact"></a></div> --> </div>
#
#  <div class="row">
#   <div class="col-md-12">
#        <div class="table-responsive">
#     <table class="table">
#     <style>
#           table {
#                  border-collapse: collapse;
#                  width: 100%;
#                 }
#          th, td {
#                   text-align: left;
#                   padding: 0px;
#                   border-style:hidden;
#                  }
#           tr:nth-child(even){background-color: #f2f2f2}
#
#           th {
#               background-color: #222222;
#               color: #ffffff;
#               font-weight: lighter;
#               font-color: white
#              }
#
#          </style>
#     <thead>
#     <tr>
#     <th style="vertical-align:middle">World Rank</th>
#     <th style="vertical-align:middle">Institution</th>
#     <th style="vertical-align:middle">Country</th>
#     <th style="vertical-align:middle">National Rank</th>
#     <th style="vertical-align:middle">Quality of Education Rank</th>
#     <th style="vertical-align:middle">Alumni Employment Rank</th>
#     <th style="vertical-align:middle">Quality of Faculty Rank</th>
#     <th style="vertical-align:middle">Research Performance Rank</th>
#     <th style="vertical-align:middle">Score</th>
#     </tr>
#     </thead>
#     <tbody>
#
# <tr><td>1</td><td><a href="2019-2020/Harvard-University.php">Harvard University</a></td><td>USA</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>100</td></tr><tr><td>2</td><td><a href="2019-2020/Massachusetts-Institute-of-Technology.php">Massachusetts Institute of Technology</a></td><td>USA</td><td>2</td><td>1</td><td>10</td><td>2</td><td>5</td><td>96.7</td></tr><tr><td>3</td><td><a href="2019-2020/Stanford-University.php">Stanford University</a></td><td>USA</td><td>3</td><td>9</td><td>3</td><td>3</td><td>2</td><td>95.2</td></tr><tr><td>4</td><td><a href="2019-2020/University-of-Cambridge.php">University of Cambridge</a></td><td>United Kingdom</td><td>1</td><td>4</td><td>19</td><td>5</td><td>11</td><td>94.1</td></tr><tr><td>5</td><td><a href="2019-2020/University-of-Oxford.php">University of Oxford</a></td><td>United Kingdom</td><td>2</td><td>10</td><td>24</td><td>10</td><td>4</td><td>93.3</td></tr><tr><td>6</td><td><a href="2019-2020/Columbia-University.php">Columbia University</a></td><td>USA</td><td>4</td><td>13</td><td>12</td><td>8</td><td>12</td><td>92.6</td></tr><tr><td>7</td><td><a href="2019-2020/Princeton-University.php">Princeton University</a></td><td>USA</td><td>5</td><td>6</td><td>14</td><td>6</td><td>54</td><td>92.0</td></tr><tr><td>8</td><td><a href="2019-2020/University-of-California,-Berkeley.php">University of California, Berkeley</a></td><td>USA</td><td>6</td><td>5</td><td>48</td><td>9</td><td>6</td><td>91.6</td></tr><tr><td>9</td><td><a href="2019-2020/University-of-Pennsylvania.php">University of Pennsylvania</a></td><td>USA</td><td>7</td><td>15</td><td>8</td><td>30</td><td>14</td><td>91.1</td></tr><tr><td>10</td><td><a href="2019-2020/University-of-Chicago.php">University of Chicago</a></td><td>USA</td><td>8</td><td>11</td><td>18</td><td>19</td><td>16</td><td>90.7</td></tr><tr><td>11</td><td><a href="2019-2020/California-Institute-of-Technology.php">California Institute of Technology</a></td><td>USA</td><td>9</td><td>3</td><td>179</td><td>4</td><td>52</td><td>90.4</td></tr><tr><td>12</td><td><a href="2019-2020/Yale-University.php">Yale University</a></td><td>USA</td><td>10</td><td>8</td><td>32</td><td>12</td><td>17</td><td>90.1</td></tr><tr><td>13</td><td><a href="2019-2020/University-of-Tokyo.php">University of Tokyo</a></td><td>Japan</td><td>1</td><td>22</td><td>6</td><td>69</td><td>23</td><td>89.8</td></tr><tr><td>14</td><td><a href="2019-2020/Cornell-University.php">Cornell University</a></td><td>USA</td><td>11</td><td>12</td><td>26</td><td>13</td><td>22</td><td>89.5</td></tr><tr><td>15</td><td><a href="2019-2020/Northwestern-University.php">Northwestern University</a></td><td>USA</td><td>12</td><td>160</td><td>16</td><td>31</td><td>24</td><td>89.3</td></tr><tr><td>16</td><td><a href="2019-2020/University-of-California,-Los-Angeles.php">University of California, Los Angeles</a></td><td>USA</td><td>13</td><td>32</td><td>57</td><td>15</td><td>10</td><td>89.0</td></tr><tr><td>17</td><td><a href="2019-2020/University-of-Michigan,-Ann-Arbor.php">University of Michigan, Ann Arbor</a></td><td>USA</td><td>14</td><td>35</td><td>35</td><td>85</td><td>9</td><td>88.8</td></tr><tr><td>18</td><td><a href="2019-2020/Johns-Hopkins-University.php">Johns Hopkins University</a></td><td>USA</td><td>15</td><td>31</td><td>164</td><td>20</td><td>7</td><td>88.6</td></tr><tr><td>19</td><td><a href="2019-2020/University-of-Washington---Seattle.php">University of Washington - Seattle</a></td><td>USA</td><td>16</td><td>47</td><td>208</td><td>14</td><td>8</td><td>88.4</td></tr><tr><td>20</td><td><a href="2019-2020/University-of-Illinois-at-Urbana–Champaign.php">University of Illinois at Urbana–Champaign</a></td><td>USA</td><td>17</td><td>16</td><td>129</td><td>17</td><td>46</td><td>88.2</td></tr><tr><td>21</td><td><a href="2019-2020/Kyoto-University.php">Kyoto University</a></td><td>Japan</td><td>2</td><td>33</td><td>29</td><td>36</td><td>58</td><td>88.0</td></tr><tr><td>22</td><td><a href="2019-2020/University-College-L ...
#
#         </tbody>
#     </table>
#    </div>
#    <p>Copyright &copy; 2012-2021 Center for World University Rankings</p>  </div>
#  </div>
#
# </div>
#
#
# <!-- Bootstrap core JavaScript
# ================================================== -->
# <!-- Placed at the end of the document so the pages load faster -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script>window.jQuery || document.write('<script src="../../assets/js/vendor/jquery.min.js"><\/script>')</script>
# <script src="../../dist/js/bootstrap.min.js"></script>
# <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->
# <script src="../../assets/js/ie10-viewport-bug-workaround.js"></script>
#
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <!--<script type="text/javascript" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5316b43f5ee1fc57"></script> -->
# </body>
# </html>

# %% [markdown]
# ### Task 4.3 Initialize BeautifulSoup object instance
#
# Use the variable defined in Task 4.2.

# %%
# Your code here

bs_obj = BeautifulSoup(content, "html.parser")
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta content="The Center for World University Rankings (CWUR) is a leading consulting organization and publisher of the largest academic ranking of global universities." name="description"/>
# <meta content="ranking, rankings, university, universities, college, colleges, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, world, top, best, global, Ranking universitario mundial, Classement mondial des universités , Weltweites Universitätsranking, Zentrum für weltweite Universitätsrankings , דירוג האוניברסיטאות העולמי, המרכז לדירוג האוניברסיטאות העולמי, 세계 대학순위, が世界の大学トップ, 世界大學排名中心, 세계대학랭킹센터,世界大学ランキングセンター, Ranking mundial universitário, Рейтинг университетов мира , разработки рейтинга университетов мира, مركز ,تصنيف الجامعات العالمية ,تصنيف, الجامعات, جامعات, العالم, تصنيف الجامعات, مركز تصنيف الجامعات العالمية, Ranking de universidades del mundo, subject, subjects, journal, journals, ranking by subjects, country ranking, country rankings" name="keywords"/>
# <link href="../../favicon.png" rel="icon" type="image/png"/>
# <!-- Bootstrap core CSS -->
# <link href="../../dist/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->
# <link href="../../assets/css/ie10-viewport-bug-workaround.css" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="../../starter-template.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# <![endif]-->
# <style type="text/css">
# /* CSS used here will be applied after bootstrap.css */
#
# .navbar-custom {
#     color: #FFFFFF;
#     background-color: #222222;
#     border-color: #222222;
# }
#
# </style><title>World University Rankings 2019-20</title>
# </head>
# <body>
# <nav class="navbar navbar-inverse navbar-fixed-top">
# <div class="container">
# <div class="navbar-header">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a href="http://cwur.org"><img height="50" src="../images/logo_944_400.png"/></a>
#             </div>
# <div class="navbar-collapse collapse" id="navbar">
# <ul class="nav navbar-nav">
# <li><a href="../about.php" style="color:white">About</a></li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button" style="color:white">World University Rankings <span class="caret"></span></a>
# <ul class="dropdown-menu">
# <li class="dropdown-header">World University Rankings</li>
# <li><a href="../2021-22.php">2021-22</a></li>
# <li><a href="../2020-21.php">2020-21</a></li>
# <li><a href="../2019-20.php">2019-20</a></li>
# <li><a href="../2018-19.php">2018-19</a></li>
# <li><a href="../2017.php">2017</a></li>
# <li><a href="../2016.php">2016</a></li>
# <li><a href="../2015.php">2015</a></li>
# <li><a href="../2014.php">2014</a></li>
# <li><a href="../2013.php">2013</a></li>
# <li><a href="../2012.php">2012</a></li>
# <li class="divider" role="separator"></li>
# <li class="dropdown-header">University Rankings by Country</li>
# <li><a href="../2018-19/country.php">2018-19</a></li>
# <li><a href="../2017/country.php">2017</a></li>
# <li><a href="../2016/country.php">2016</a></li>
# <li><a href="../2015/country.php">2015</a></li>
# <li><a href="../2014/country.php">2014</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="../2017/subjects.php">Rankings by Subject</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button" style="color:white">Methodology <span class="caret"></span></a>
# <ul class="dropdown-menu">
# <li><a href="../methodology/world-university-rankings.php">World University Rankings</a></li>
# <li><a href="../methodology/subject-rankings.php">Subject Rankings</a></li>
# </ul>
# </li>
# <li><a href="../media.php" style="color:white">Media</a></li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="container">
# <div class="page-header">
# <h4>World University Rankings 2019-20</h4>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <!-- <div class="addthis_toolbox addthis_default_style addthis_32x32_style"> <a class="addthis_button_preferred_1"></a> <a class="addthis_button_preferred_2"></a> <a class="addthis_button_preferred_3"></a> <a class="addthis_button_preferred_4"></a><a class="addthis_button_compact"></a></div> --> </div>
# <div class="row">
# <div class="col-md-12">
# <div class="table-responsive">
# <table class="table">
# <style>
#           table {
#                  border-collapse: collapse;
#                  width: 100%;
#                 }
#          th, td {
#                   text-align: left;
#                   padding: 0px;
#                   border-style:hidden;
#                  }
#           tr:nth-child(even){background-color: #f2f2f2}
#
#           th {
#               background-color: #222222;
#               color: #ffffff;
#               font-weight: lighter;
#               font-color: white
#              }
#
#          </style>
# <thead>
# <tr>
# <th style="vertical-align:middle">World Rank</th>
# <th style="vertical-align:middle">Institution</th>
# <th style="vertical-align:middle">Country</th>
# <th style="vertical-align:middle">National Rank</th>
# <th style="vertical-align:middle">Quality of Education Rank</th>
# <th style="vertical-align:middle">Alumni Employment Rank</th>
# <th style="vertical-align:middle">Quality of Faculty Rank</th>
# <th style="vertical-align:middle">Research Performance Rank</th>
# <th style="vertical-align:middle">Score</th>
# </tr>
# </thead>
# <tbody>
# <tr><td>1</td><td><a href="2019-2020/Harvard-University.php">Harvard University</a></td><td>USA</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>100</td></tr><tr><td>2</td><td><a href="2019-2020/Massachusetts-Institute-of-Technology.php">Massachusetts Institute of Technology</a></td><td>USA</td><td>2</td><td>1</td><td>10</td><td>2</td><td>5</td><td>96.7</td></tr><tr><td>3</td><td><a href="2019-2020/Stanford-University.php">Stanford University</a></td><td>USA</td><td>3</td><td>9</td><td>3</td><td>3</td><td>2</td><td>95.2</td></tr><tr><td>4</td><td><a href="2019-2020/University-of-Cambridge.php">University of Cambridge</a></td><td>United Kingdom</td><td>1</td><td>4</td><td>19</td><td>5</td><td>11</td><td>94.1</td></tr><tr><td>5</td><td><a href="2019-2020/University-of-Oxford.php">University of Oxford</a></td><td>United Kingdom</td><td>2</td><td>10</td><td>24</td><td>10</td><td>4</td><td>93.3</td></tr><tr><td>6</td><td><a href="2019-2020/Columbia-University.php">Columbia University</a></td><td>USA</td><td>4</td><td>13</td><td>12</td><td>8</td><td>12</td><td>92.6</td></tr><tr><td>7</td><td><a href="2019-2020/Princeton-University.php">Princeton University</a></td><td>USA</td><td>5</td><td>6</td><td>14</td><td>6</td><td>54</td><td>92.0</td></tr><tr><td>8</td><td><a href="2019-2020/University-of-California,-Berkeley.php">University of California, Berkeley</a></td><td>USA</td><td>6</td><td>5</td><td>48</td><td>9</td><td>6</td><td>91.6</td></tr><tr><td>9</td><td><a href="2019-2020/University-of-Pennsylvania.php">University of Pennsylvania</a></td><td>USA</td><td>7</td><td>15</td><td>8</td><td>30</td><td>14</td><td>91.1</td></tr><tr><td>10</td><td><a href="2019-2020/University-of-Chicago.php">University of Chicago</a></td><td>USA</td><td>8</td><td>11</td><td>18</td><td>19</td><td>16</td><td>90.7</td></tr><tr><td>11</td><td><a href="2019-2020/California-Institute-of-Technology.php">California Institute of Technology</a></td><td>USA</td><td>9</td><td>3</td><td>179</td><td>4</td><td>52</td><td>90.4</td></tr><tr><td>12</td><td><a href="2019-2020/Yale-University.php">Yale University</a></td><td>USA</td><td>10</td><td>8</td><td>32</td><td>12</td><td>17</td><td>90.1</td></tr><tr><td>13</td><td><a href="2019-2020/University-of-Tokyo.php">University of Tokyo</a></td><td>Japan</td><td>1</td><td>22</td><td>6</td><td>69</td><td>23</td><td>89.8</td></tr><tr><td>14</td><td><a href="2019-2020/Cornell-University.php">Cornell University</a></td><td>USA</td><td>11</td><td>12</td><td>26</td><td>13</td><td>22</td><td>89.5</td></tr><tr><td>15</td><td><a href="2019-2020/Northwestern-University.php">Northwestern University</a></td><td>USA</td><td>12</td><td>160</td><td>16</td><td>31</td><td>24</td><td>89.3</td></tr><tr><td>16</td><td><a href="2019-2020/University-of-California,-Los-Angeles.php">University of California, Los Angeles</a></td><td>USA</td><td>13</td><td>32</td><td>57</td><td>15</td><td>10</td><td>89.0</td></tr><tr><td>17</td><td><a href="2019-2020/University-of-Michigan,-Ann-Arbor.php">University of Michigan, Ann Arbor</a></td><td>USA</td><td>14</td><td>35</td><td>35</td><td>85</td><td>9</td><td>88.8</td></tr><tr><td>18</td><td><a href="2019-2020/Johns-Hopkins-University.php">Johns Hopkins University</a></td><td>USA</td><td>15</td><td>31</td><td>164</td><td>20</td><td>7</td><td>88.6</td></tr><tr><td>19</td><td><a href="2019-2020/University-of-Washington---Seattle.php">University of Washington - Seattle</a></td><td>USA</td><td>16</td><td>47</td><td>208</td><td>14</td><td>8</td><td>88.4</td></tr><tr><td>20</td><td><a href="2019-2020/University-of-Illinois-at-Urbana–Champaign.php">University of Illinois at Urbana–Champaign</a></td><td>USA</td><td>17</td><td>16</td><td>129</td><td>17</td><td>46</td><td>88.2</td></tr><tr><td>21</td><td><a href="2019-2020/Kyoto-University.php">Kyoto University</a></td><td>Japan</td><td>2</td><td>33</td><td>29</td><td>36</td><td>58</td><td>88.0</td></tr><tr><td>22</td><td><a href="2019-2020/University-College-L ...
# </tbody>
# </table>
# </div>
# <p>Copyright © 2012-2021 Center for World University Rankings</p> </div>
# </div>
# </div>
# <!-- Bootstrap core JavaScript
# ================================================== -->
# <!-- Placed at the end of the document so the pages load faster -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script>window.jQuery || document.write('<script src="../../assets/js/vendor/jquery.min.js"><\/script>')</script>
# <script src="../../dist/js/bootstrap.min.js"></script>
# <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->
# <script src="../../assets/js/ie10-viewport-bug-workaround.js"></script>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <!--<script type="text/javascript" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5316b43f5ee1fc57"></script> -->
# </body>
# </html>

# %% [markdown]
# ### Task 4.4 Find the table element
#
# The webpage has a table containing all the data we're trying to extract. Write the code to find this element and store it in a variable. Use the BeautifulSoup object instance defined in Task 4.3.

# %%
# Write your code here

table = bs_obj.find('table')

table
# Out:
# <table class="table">
# <style>
#           table {
#                  border-collapse: collapse;
#                  width: 100%;
#                 }
#          th, td {
#                   text-align: left;
#                   padding: 0px;
#                   border-style:hidden;
#                  }
#           tr:nth-child(even){background-color: #f2f2f2}
#
#           th {
#               background-color: #222222;
#               color: #ffffff;
#               font-weight: lighter;
#               font-color: white
#              }
#
#          </style>
# <thead>
# <tr>
# <th style="vertical-align:middle">World Rank</th>
# <th style="vertical-align:middle">Institution</th>
# <th style="vertical-align:middle">Country</th>
# <th style="vertical-align:middle">National Rank</th>
# <th style="vertical-align:middle">Quality of Education Rank</th>
# <th style="vertical-align:middle">Alumni Employment Rank</th>
# <th style="vertical-align:middle">Quality of Faculty Rank</th>
# <th style="vertical-align:middle">Research Performance Rank</th>
# <th style="vertical-align:middle">Score</th>
# </tr>
# </thead>
# <tbody>
# <tr><td>1</td><td><a href="2019-2020/Harvard-University.php">Harvard University</a></td><td>USA</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>100</td></tr><tr><td>2</td><td><a href="2019-2020/Massachusetts-Institute-of-Technology.php">Massachusetts Institute of Technology</a></td><td>USA</td><td>2</td><td>1</td><td>10</td><td>2</td><td>5</td><td>96.7</td></tr><tr><td>3</td><td><a href="2019-2020/Stanford-University.php">Stanford University</a></td><td>USA</td><td>3</td><td>9</td><td>3</td><td>3</td><td>2</td><td>95.2</td></tr><tr><td>4</td><td><a href="2019-2020/University-of-Cambridge.php">University of Cambridge</a></td><td>United Kingdom</td><td>1</td><td>4</td><td>19</td><td>5</td><td>11</td><td>94.1</td></tr><tr><td>5</td><td><a href="2019-2020/University-of-Oxford.php">University of Oxford</a></td><td>United Kingdom</td><td>2</td><td>10</td><td>24</td><td>10</td><td>4</td><td>93.3</td></tr><tr><td>6</td><td><a href="2019-2020/Columbia-University.php">Columbia University</a></td><td>USA</td><td>4</td><td>13</td><td>12</td><td>8</td><td>12</td><td>92.6</td></tr><tr><td>7</td><td><a href="2019-2020/Princeton-University.php">Princeton University</a></td><td>USA</td><td>5</td><td>6</td><td>14</td><td>6</td><td>54</td><td>92.0</td></tr><tr><td>8</td><td><a href="2019-2020/University-of-California,-Berkeley.php">University of California, Berkeley</a></td><td>USA</td><td>6</td><td>5</td><td>48</td><td>9</td><td>6</td><td>91.6</td></tr><tr><td>9</td><td><a href="2019-2020/University-of-Pennsylvania.php">University of Pennsylvania</a></td><td>USA</td><td>7</td><td>15</td><td>8</td><td>30</td><td>14</td><td>91.1</td></tr><tr><td>10</td><td><a href="2019-2020/University-of-Chicago.php">University of Chicago</a></td><td>USA</td><td>8</td><td>11</td><td>18</td><td>19</td><td>16</td><td>90.7</td></tr><tr><td>11</td><td><a href="2019-2020/California-Institute-of-Technology.php">California Institute of Technology</a></td><td>USA</td><td>9</td><td>3</td><td>179</td><td>4</td><td>52</td><td>90.4</td></tr><tr><td>12</td><td><a href="2019-2020/Yale-University.php">Yale University</a></td><td>USA</td><td>10</td><td>8</td><td>32</td><td>12</td><td>17</td><td>90.1</td></tr><tr><td>13</td><td><a href="2019-2020/University-of-Tokyo.php">University of Tokyo</a></td><td>Japan</td><td>1</td><td>22</td><td>6</td><td>69</td><td>23</td><td>89.8</td></tr><tr><td>14</td><td><a href="2019-2020/Cornell-University.php">Cornell University</a></td><td>USA</td><td>11</td><td>12</td><td>26</td><td>13</td><td>22</td><td>89.5</td></tr><tr><td>15</td><td><a href="2019-2020/Northwestern-University.php">Northwestern University</a></td><td>USA</td><td>12</td><td>160</td><td>16</td><td>31</td><td>24</td><td>89.3</td></tr><tr><td>16</td><td><a href="2019-2020/University-of-California,-Los-Angeles.php">University of California, Los Angeles</a></td><td>USA</td><td>13</td><td>32</td><td>57</td><td>15</td><td>10</td><td>89.0</td></tr><tr><td>17</td><td><a href="2019-2020/University-of-Michigan,-Ann-Arbor.php">University of Michigan, Ann Arbor</a></td><td>USA</td><td>14</td><td>35</td><td>35</td><td>85</td><td>9</td><td>88.8</td></tr><tr><td>18</td><td><a href="2019-2020/Johns-Hopkins-University.php">Johns Hopkins University</a></td><td>USA</td><td>15</td><td>31</td><td>164</td><td>20</td><td>7</td><td>88.6</td></tr><tr><td>19</td><td><a href="2019-2020/University-of-Washington---Seattle.php">University of Washington - Seattle</a></td><td>USA</td><td>16</td><td>47</td><td>208</td><td>14</td><td>8</td><td>88.4</td></tr><tr><td>20</td><td><a href="2019-2020/University-of-Illinois-at-Urbana–Champaign.php">University of Illinois at Urbana–Champaign</a></td><td>USA</td><td>17</td><td>16</td><td>129</td><td>17</td><td>46</td><td>88.2</td></tr><tr><td>21</td><td><a href="2019-2020/Kyoto-University.php">Kyoto University</a></td><td>Japan</td><td>2</td><td>33</td><td>29</td><td>36</td><td>58</td><td>88.0</td></tr><tr><td>22</td><td><a href="2019-2020/University-College-L ...
# </tbody>
# </table>

# %%
# Pulling out the year data 

table_rows = table.find_all("tr")

data = table_rows[1]

row_data = data.find_all('td')

year_data = data.find('a')

"".join([v[:9] for (k,v) in year_data.attrs.items()])
# Out:
# '2019-2020'

# %% [markdown]
# ### Task 4.5 Find all th tags, to parse the table header
#
# Use the variable defined in Task 4.4. Save your answer to a variable named `header` in order to pass the asserts.
#
# **Hint**: The header should be a list of elements, that can be obtained by using the `get_text()` method for each `th` element in the table. List comprehension may be useful here.

# %%
# Write your code here

header = [th.get_text() for th in table.find_all("th")]

header
# Out:
# ['World Rank',
#  'Institution',
#  'Country',
#  'National Rank',
#  'Quality of Education Rank',
#  'Alumni Employment Rank',
#  'Quality of Faculty Rank',
#  'Research Performance Rank',
#  'Score']

# %%
assert(len(header) == 9)
assert(type(header) == list)
assert(header[0] == "World Rank")
assert(header[-1] == "Score")

# %% [markdown]
# Great work! The next tasks are optional. You may choose to skip them and start the lab! You can revisit this section when you are solving the relevant portion of P12.

# %% [markdown]
# ### Task 4.6 (Optional) Build row dictionary for one row
#
# Scrape the second row (the first one is the header!), convert data to the appropriate types, and populate the data into a row dictionary. The keys of the dictionary are the columns in the dataframe. Avoid hardcoding these keys - instead, use the variable obtained in the previous task.
#
# **Hint**: Rows can be found by locating the `tr` elements in the table.
#
# - "World Rank", "National Rank", "Quality of Education Rank", "Alumni Employment Rank", "Quality of Faculty Rank", "Research Performance Rank": `int` conversion
# - "Score"  : `float` conversion
#
# You can compare your parsing output to `rankings.json` file contents, to confirm your result.

# %%
table_rows = table.find_all("tr")

data = table_rows[1]

row_data = data.find_all('td')

row_data[0].get_text()

#data_list[row.get_text(header.index('World Rank')]
# Out:
# '1'

# %%
# Write your code here

table_rows = table.find_all("tr")

data = table_rows[1]

rankings_dict = {}

world_rank_idx = header.index('World Rank')
institution_idx = header.index('Institution')
country_idx = header.index('Country')
national_rank_idx = header.index('National Rank')
qual_edu_rank_idx = header.index('Quality of Education Rank')
alumni_emp_rank_idx = header.index('Alumni Employment Rank')
qual_faculty_rank_idx = header.index('Quality of Faculty Rank')
research_perf_rank_idx = header.index('Research Performance Rank')
score_idx = header.index('Score')

row_data = data.find_all('td')

world_rank = int(row_data[world_rank_idx].get_text())
institution = row_data[institution_idx].get_text()
country = row_data[country_idx].get_text()
national_rank = int(row_data[national_rank_idx].get_text())
qual_edu_rank = int(row_data[qual_edu_rank_idx].get_text())
alumni_emp_rank = int(row_data[alumni_emp_rank_idx].get_text())
qual_faculty_rank = int(row_data[qual_faculty_rank_idx].get_text())
research_perf_rank = int(row_data[research_perf_rank_idx].get_text())
score = float(row_data[score_idx].get_text())
    
rankings_dict = { 'World Rank': world_rank, 
                  'Institution': institution, 
                  'Country': country, 
                  'National Rank': national_rank, 
                  'Quality of Education Rank': qual_edu_rank,
                  'Alumni Employment Rank': alumni_emp_rank,  
                  'Quality of Faculty Rank': qual_faculty_rank,
                  'Research Performance Rank': research_perf_rank,
                  'Score': score
                }
    
rankings_dict
# Out:
# {'World Rank': 1,
#  'Institution': 'Harvard University',
#  'Country': 'USA',
#  'National Rank': 1,
#  'Quality of Education Rank': 2,
#  'Alumni Employment Rank': 1,
#  'Quality of Faculty Rank': 1,
#  'Research Performance Rank': 1,
#  'Score': 100.0}

# %%
read_data = read_json("rankings.json")
len(read_data)
# Out:
# 6000

# %% [markdown]
# ### Task 4.7 (Optional) Build list of all row dictionaries
#
# Scrape all rows, convert data to appropriate types, and populate data into a row dictionary and append row dictionaries into a list.
#
# This is a natural extension of Task 4.6. You can use a loop to extract all rows and populate the list.
#
# **Important**:
# * Some fields in the dataset have missing values, represented simply as `-`.
# * The "Year" value isn't present in the dataset. Think of a different way to populate this field.

# %%
# Write your code here

table_rows = table.find_all("tr")

data = table_rows[1:]

rankings_list = []
rankings_dict = {}

world_rank_idx = header.index('World Rank')
institution_idx = header.index('Institution')
country_idx = header.index('Country')
national_rank_idx = header.index('National Rank')
qual_edu_rank_idx = header.index('Quality of Education Rank')
alumni_emp_rank_idx = header.index('Alumni Employment Rank')
qual_faculty_rank_idx = header.index('Quality of Faculty Rank')
research_perf_rank_idx = header.index('Research Performance Rank')
score_idx = header.index('Score')

for row in data:
    try:
        row_data = row.find_all('td')
        
        year_data = row.find('a')
        year = "".join([v[:9] for (k,v) in year_data.attrs.items()])

        world_rank = row_data[world_rank_idx].get_text()
        institution = row_data[institution_idx].get_text()
        country = row_data[country_idx].get_text()
        national_rank = row_data[national_rank_idx].get_text()
        qual_edu_rank = row_data[qual_edu_rank_idx].get_text()
        alumni_emp_rank = row_data[alumni_emp_rank_idx].get_text()
        qual_faculty_rank = row_data[qual_faculty_rank_idx].get_text()
        research_perf_rank = row_data[research_perf_rank_idx].get_text()
        score = row_data[score_idx].get_text()

        int_list = [world_rank, national_rank, qual_edu_rank, alumni_emp_rank, \
                    qual_faculty_rank, research_perf_rank]
        
        float_list = [score]
        
        for item in int_list:
            if item != "-":
                item = int(item)
                
        for item in float_list:
            if item != "-":
                item = float(item)
                
        rankings_dict = { 'World Rank': world_rank,
                          'Year': year,
                          'Institution': institution, 
                          'Country': country, 
                          'National Rank': national_rank, 
                          'Quality of Education Rank': qual_edu_rank,
                          'Alumni Employment Rank': alumni_emp_rank,
                          'Quality of Faculty Rank': qual_faculty_rank,
                          'Research Performance Rank': research_perf_rank,
                          'Score': score
                         }
            
        rankings_list.append(rankings_dict)
            
    except ValueError:
        continue
    
rankings_list
# Out:
# [{'World Rank': '1',
#   'Year': '2019-2020',
#   'Institution': 'Harvard University',
#   'Country': 'USA',
#   'National Rank': '1',
#   'Quality of Education Rank': '2',
#   'Alumni Employment Rank': '1',
#   'Quality of Faculty Rank': '1',
#   'Research Performance Rank': '1',
#   'Score': '100'},
#  {'World Rank': '2',
#   'Year': '2019-2020',
#   'Institution': 'Massachusetts Institute of Technology',
#   'Country': 'USA',
#   'National Rank': '2',
#   'Quality of Education Rank': '1',
#   'Alumni Employment Rank': '10',
#   'Quality of Faculty Rank': '2',
#   'Research Performance Rank': '5',
#   'Score': '96.7'},
#  {'World Rank': '3',
#   'Year': '2019-2020',
#   'Institution': 'Stanford University',
#   'Country': 'USA',
#   'National Rank': '3',
#   'Quality of Education Rank': '9',
#   'Alumni Employment Rank': '3',
#   'Quality of Faculty Rank': '3',
#   'Research Performance Rank': '2',
#   'Score': '95.2'},
#  {'World Rank': '4',
#   'Year': '2019-2020',
#   'Institution': 'University of Cambridge',
#   'Country': 'United Kingdom',
#   'National Rank': '1',
#   'Quality of Education Rank': '4',
#   'Alumni Employment Rank': '19',
#   'Quality of Faculty Rank': '5',
#   'Research Performance Rank': '11',
#   'Score': '94.1'},
#  {'World Rank': '5',
#   'Year': '2019-2020',
#   'Institution': 'University of Oxford',
#   'Country': 'United Kingdom',
#   'National Rank': '2',
#   'Quality of Education Rank': '10',
#   'Alumni Employment Rank': '24',
#   'Quality of Faculty Rank': '10',
#   'Research Performance Rank': '4',
#   'Score': '93.3'},
#  {'World Rank': '6',
#   'Year': '2019-2020',
#   'Institution': 'Columbia University',
#   'Country': 'USA',
#   'National Rank': '4',
#   'Quality of Education Rank': '13',
#   'Alumni Employment Rank': '12',
#   'Quality of Faculty Rank': '8',
#   'Research Performance Rank': '12',
#   'Score': '92.6'},
#  {'World Rank': '7',
#   'Year': '2019-2020',
#   'Institution': 'Princeton University',
#   'Country': 'USA',
#   'National Rank': '5',
#   'Quality of Education Rank': '6',
#   'Alumni Employment Rank': '14',
#   'Quality of Faculty Rank': '6',
#   'Research Performance Rank': '54',
#   'Score': '92.0'},
#  {'World Rank': '8',
#   'Year': '2019-2020',
#   'Institution': 'University of California, Berkeley',
#   'Country': 'USA',
#   'National Rank': '6',
#   'Quality of Education Rank': '5',
#   'Alumni Employment Rank': '48',
#   'Quality of Faculty Rank': '9',
#   'Research Performance Rank': '6',
#   'Score': '91.6'},
#  {'World Rank': '9',
#   'Year': '2019-2020',
#   'Institution': 'University of Pennsylvania',
#   'Country': 'USA',
#   'National Rank': '7',
#   'Quality of Education Rank': '15',
#   'Alumni Employment Rank': '8',
#   'Quality of Faculty Rank': '30',
#   'Research Performance Rank': '14',
#   'Score': '91.1'},
#  {'World Rank': '10',
#   'Year': '2019-2020',
#   'Institution': 'University of Chicago',
#   'Country': 'USA',
#   'National Rank': '8',
#   'Quality of Education Rank': '11',
#   'Alumni Employment Rank': '18',
#   'Quality of Faculty Rank': '19',
#   'Research Performance Rank': '16',
#   'Score': '90.7'},
#  {'World Rank': '11',
#   'Year': '2019-2020',
#   'Institution': 'California Institute of Technology',
#   'Country': 'USA',
#   'National Rank': '9',
#   'Quality of Education Rank': '3',
#   'Alumni Employment Rank': '179',
#   'Quality of Faculty Rank': '4',
#   'Research Performance Rank': '52',
#   'Score': '90.4'},
#  {'World Rank': '12',
#   'Year': '2019-2020',
#   'Institution': 'Yale University',
#   'Country': 'USA',
#   'National Rank': '10',
#   'Quality of Education Rank': '8',
#   'Alumni Employment Rank': '32',
#   'Quality of Faculty Rank': '12',
#   'Research Performance Rank': '17',
#   'Score': '90.1'},
#  {'World Rank': '13',
#   'Year': '2019-2020',
#   'Institution': 'University of Tokyo',
#   'Country': 'Japan',
#   'National Rank': '1',
#   'Quality of Education Rank': '22',
#   'Alumni Employment Rank': '6',
#   'Quality of Faculty Rank': '69',
#   'Research Performance Rank': '23',
#   'Score': '89.8'},
#  {'World Rank': '14',
#   'Year': '2019-2020',
#   'Institution': 'Cornell University',
#   'Country': 'USA',
#   'National Rank': '11',
#   'Quality of Education Rank': '12',
#   'Alumni Employment Rank': '26',
#   'Quality of Faculty Rank': '13',
#   'Research Performance Rank': '22',
#   'Score': '89.5'},
#  {'World Rank': '15',
#   'Year': '2019-2020',
#   'Institution': 'Northwestern University',
#   'Country': 'USA',
#   'National Rank': '12',
#   'Quality of Education Rank': '160',
#   'Alumni Employment Rank': '16',
#   'Quality of Faculty Rank': '31',
#   'Research Performance Rank': '24',
#   'Score': '89.3'},
#  {'World Rank': '16',
#   'Year': '2019-2020',
#   'Institution': 'University of California, Los Angeles',
#   'Country': 'USA',
#   'National Rank': '13',
#   'Quality of Education Rank': '32',
#   'Alumni Employment Rank': '57',
#   'Quality of Faculty Rank': '15',
#   'Research Performance Rank': '10',
#   'Score': '89.0'},
#  {'World Rank': '17',
#   'Year': '2019-2020',
#   'Institution': 'University of Michigan, Ann Arbor',
#   'Country': 'USA',
#   'National Rank': '14',
#   'Quality of Education Rank': '35',
#   'Alumni Employment Rank': '35',
#   'Quality of Faculty Rank': '85',
#   'Research Performance Rank': '9',
#   'Score': '88.8'},
#  {'World Rank': '18',
#   'Year': '2019-2020',
#   'Institution': 'Johns Hopkins University',
#   'Country': 'USA',
#   'National Rank': '15',
#   'Quality of Education Rank': '31',
#   'Alumni Employment Rank': '164',
#   'Quality of Faculty Rank': '20',
#   'Research Performance Rank': '7',
#   'Score': '88.6'},
#  {'World Rank': '19',
#   'Year': '2019-2020',
#   'Institution': 'University of Washington - Seattle',
#   'Country': 'USA',
#   'National Rank': '16',
#   'Quality of Education Rank': '47',
#   'Alumni Employment Rank': '208',
#   'Quality of Faculty Rank': '14',
#   'Research Performance Rank': '8',
#   'Score': '88.4'},
#  {'World Rank': '20',
#   'Year': '2019-2020',
#   'Institution': 'University of Illinois at Urbana–Champaign',
#   'Country': 'USA',
#   'National Rank': '17',
#   'Quality of Education Rank': '16',
#   'Alumni Employment Rank': '129',
#   'Quality of Faculty Rank': '17',
#   'Research Performance Rank': '46',
#   'Score': '88.2'},
#  {'World Rank': '21',
#   'Year': '2019-2020',
#   'Institution': 'Kyoto University',
#   'Country': 'Japan',
#   'National Rank': '2',
#   'Quality of Education Rank': '33',
#   'Alumni Employment Rank': '29',
#   'Quality of Faculty Rank': '36',
#   'Research Performance Rank': '58',
#   'Score': '88.0'},
#  {'World Rank': '22',
#   'Year': '2019-2020',
#   'Institution': 'University College London',
#   'Country': 'United Kingdom',
#   'National Rank': '3',
#   'Quality of Education Rank': '36',
#   'Alumni Employment Rank': '669',
#   'Quality of Faculty Rank': '18',
#   'Research Performance Rank': '13',
#   'Score': '87.8'},
#  {'World Rank': '23',
#   'Year': '2019-2020',
#   'Institution': 'Duke University',
#   'Country': 'USA',
#   'National Rank': '18',
#   'Quality of Education Rank': '100',
#   'Alumni Employment Rank': '46',
#   'Quality of Faculty Rank': '25',
#   'Research Performance Rank': '20',
#   'Score': '87.7'},
#  {'World Rank': '24',
#   'Year': '2019-2020',
#   'Institution': 'University of Toronto',
#   'Country': 'Canada',
#   'National Rank': '1',
#   'Quality of Education Rank': '236',
#   'Alumni Employment Rank': '162',
#   'Quality of Faculty Rank': '24',
#   'Research Performance Rank': '3',
#   'Score': '87.5'},
#  {'World Rank': '25',
#   'Year': '2019-2020',
#   'Institution': 'University of Wisconsin–Madison',
#   'Country': 'USA',
#   'National Rank': '19',
#   'Quality of Education Rank': '28',
#   'Alumni Employment Rank': '80',
#   'Quality of Faculty Rank': '35',
#   'Research Performance Rank': '27',
#   'Score': '87.3'},
#  {'World Rank': '26',
#   'Year': '2019-2020',
#   'Institution': 'New York University',
#   'Country': 'USA',
#   'National Rank': '20',
#   'Quality of Education Rank': '64',
#   'Alumni Employment Rank': '39',
#   'Quality of Faculty Rank': '37',
#   'Research Performance Rank': '39',
#   'Score': '87.2'},
#  {'World Rank': '27',
#   'Year': '2019-2020',
#   'Institution': 'University of California San Diego',
#   'Country': 'USA',
#   'National Rank': '21',
#   'Quality of Education Rank': '67',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '16',
#   'Research Performance Rank': '15',
#   'Score': '87.1'},
#  {'World Rank': '28',
#   'Year': '2019-2020',
#   'Institution': 'Imperial College London',
#   'Country': 'United Kingdom',
#   'National Rank': '4',
#   'Quality of Education Rank': '60',
#   'Alumni Employment Rank': '101',
#   'Quality of Faculty Rank': '53',
#   'Research Performance Rank': '18',
#   'Score': '86.9'},
#  {'World Rank': '29',
#   'Year': '2019-2020',
#   'Institution': 'ETH Zurich',
#   'Country': 'Switzerland',
#   'National Rank': '1',
#   'Quality of Education Rank': '41',
#   'Alumni Employment Rank': '90',
#   'Quality of Faculty Rank': '28',
#   'Research Performance Rank': '36',
#   'Score': '86.8'},
#  {'World Rank': '30',
#   'Year': '2019-2020',
#   'Institution': 'McGill University',
#   'Country': 'Canada',
#   'National Rank': '2',
#   'Quality of Education Rank': '27',
#   'Alumni Employment Rank': '91',
#   'Quality of Faculty Rank': '71',
#   'Research Performance Rank': '41',
#   'Score': '86.7'},
#  {'World Rank': '31',
#   'Year': '2019-2020',
#   'Institution': 'University of Texas at Austin',
#   'Country': 'USA',
#   'National Rank': '22',
#   'Quality of Education Rank': '72',
#   'Alumni Employment Rank': '58',
#   'Quality of Faculty Rank': '43',
#   'Research Performance Rank': '44',
#   'Score': '86.5'},
#  {'World Rank': '32',
#   'Year': '2019-2020',
#   'Institution': 'École Polytechnique',
#   'Country': 'France',
#   'National Rank': '1',
#   'Quality of Education Rank': '94',
#   'Alumni Employment Rank': '4',
#   'Quality of Faculty Rank': '178',
#   'Research Performance Rank': '356',
#   'Score': '86.4'},
#  {'World Rank': '33',
#   'Year': '2019-2020',
#   'Institution': 'Seoul National University',
#   'Country': 'South Korea',
#   'National Rank': '1',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '21',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '48',
#   'Score': '86.3'},
#  {'World Rank': '34',
#   'Year': '2019-2020',
#   'Institution': 'University of California, San Francisco',
#   'Country': 'USA',
#   'National Rank': '23',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '11',
#   'Research Performance Rank': '21',
#   'Score': '86.2'},
#  {'World Rank': '35',
#   'Year': '2019-2020',
#   'Institution': 'Sorbonne University',
#   'Country': 'France',
#   'National Rank': '2',
#   'Quality of Education Rank': '55',
#   'Alumni Employment Rank': '339',
#   'Quality of Faculty Rank': '82',
#   'Research Performance Rank': '19',
#   'Score': '86.1'},
#  {'World Rank': '36',
#   'Year': '2019-2020',
#   'Institution': 'University of North Carolina at Chapel Hill',
#   'Country': 'USA',
#   'National Rank': '24',
#   'Quality of Education Rank': '214',
#   'Alumni Employment Rank': '107',
#   'Quality of Faculty Rank': '46',
#   'Research Performance Rank': '28',
#   'Score': '85.9'},
#  {'World Rank': '37',
#   'Year': '2019-2020',
#   'Institution': 'University of Edinburgh',
#   'Country': 'United Kingdom',
#   'National Rank': '5',
#   'Quality of Education Rank': '38',
#   'Alumni Employment Rank': '336',
#   'Quality of Faculty Rank': '65',
#   'Research Performance Rank': '47',
#   'Score': '85.8'},
#  {'World Rank': '38',
#   'Year': '2019-2020',
#   'Institution': 'University of Minnesota - Twin Cities',
#   'Country': 'USA',
#   'National Rank': '25',
#   'Quality of Education Rank': '77',
#   'Alumni Employment Rank': '291',
#   'Quality of Faculty Rank': '90',
#   'Research Performance Rank': '25',
#   'Score': '85.7'},
#  {'World Rank': '39',
#   'Year': '2019-2020',
#   'Institution': 'University of Copenhagen',
#   'Country': 'Denmark',
#   'National Rank': '1',
#   'Quality of Education Rank': '119',
#   'Alumni Employment Rank': '352',
#   'Quality of Faculty Rank': '48',
#   'Research Performance Rank': '26',
#   'Score': '85.6'},
#  {'World Rank': '40',
#   'Year': '2019-2020',
#   'Institution': 'University of Texas Southwestern Medical Center',
#   'Country': 'USA',
#   'National Rank': '26',
#   'Quality of Education Rank': '19',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '21',
#   'Research Performance Rank': '142',
#   'Score': '85.5'},
#  {'World Rank': '41',
#   'Year': '2019-2020',
#   'Institution': 'Washington University in St. Louis',
#   'Country': 'USA',
#   'National Rank': '27',
#   'Quality of Education Rank': '150',
#   'Alumni Employment Rank': '163',
#   'Quality of Faculty Rank': '42',
#   'Research Performance Rank': '35',
#   'Score': '85.4'},
#  {'World Rank': '42',
#   'Year': '2019-2020',
#   'Institution': 'Karolinska Institute',
#   'Country': 'Sweden',
#   'National Rank': '1',
#   'Quality of Education Rank': '49',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '39',
#   'Research Performance Rank': '59',
#   'Score': '85.3'},
#  {'World Rank': '43',
#   'Year': '2019-2020',
#   'Institution': 'École normale supérieure',
#   'Country': 'France',
#   'National Rank': '3',
#   'Quality of Education Rank': '7',
#   'Alumni Employment Rank': '543',
#   'Quality of Faculty Rank': '123',
#   'Research Performance Rank': '360',
#   'Score': '85.2'},
#  {'World Rank': '44',
#   'Year': '2019-2020',
#   'Institution': 'University of Southern California',
#   'Country': 'USA',
#   'National Rank': '28',
#   'Quality of Education Rank': '271',
#   'Alumni Employment Rank': '115',
#   'Quality of Faculty Rank': '23',
#   'Research Performance Rank': '66',
#   'Score': '85.2'},
#  {'World Rank': '45',
#   'Year': '2019-2020',
#   'Institution': 'Brown University',
#   'Country': 'USA',
#   'National Rank': '29',
#   'Quality of Education Rank': '66',
#   'Alumni Employment Rank': '49',
#   'Quality of Faculty Rank': '81',
#   'Research Performance Rank': '118',
#   'Score': '85.1'},
#  {'World Rank': '46',
#   'Year': '2019-2020',
#   'Institution': 'Vanderbilt University',
#   'Country': 'USA',
#   'National Rank': '30',
#   'Quality of Education Rank': '387',
#   'Alumni Employment Rank': '86',
#   'Quality of Faculty Rank': '51',
#   'Research Performance Rank': '65',
#   'Score': '85.0'},
#  {'World Rank': '47',
#   'Year': '2019-2020',
#   'Institution': 'Pennsylvania State University',
#   'Country': 'USA',
#   'National Rank': '31',
#   'Quality of Education Rank': '320',
#   'Alumni Employment Rank': '161',
#   'Quality of Faculty Rank': '52',
#   'Research Performance Rank': '45',
#   'Score': '84.9'},
#  {'World Rank': '48',
#   'Year': '2019-2020',
#   'Institution': 'Rutgers University–New Brunswick',
#   'Country': 'USA',
#   'National Rank': '32',
#   'Quality of Education Rank': '190',
#   'Alumni Employment Rank': '96',
#   'Quality of Faculty Rank': '44',
#   'Research Performance Rank': '70',
#   'Score': '84.8'},
#  {'World Rank': '49',
#   'Year': '2019-2020',
#   'Institution': 'Dartmouth College',
#   'Country': 'USA',
#   'National Rank': '33',
#   'Quality of Education Rank': '109',
#   'Alumni Employment Rank': '17',
#   'Quality of Faculty Rank': '131',
#   'Research Performance Rank': '243',
#   'Score': '84.7'},
#  {'World Rank': '50',
#   'Year': '2019-2020',
#   'Institution': 'University of California, Davis',
#   'Country': 'USA',
#   'National Rank': '34',
#   'Quality of Education Rank': '97',
#   'Alumni Employment Rank': '565',
#   'Quality of Faculty Rank': '56',
#   'Research Performance Rank': '43',
#   'Score': '84.6'},
#  {'World Rank': '51',
#   'Year': '2019-2020',
#   'Institution': 'Ludwig Maximilian University of Munich',
#   'Country': 'Germany',
#   'National Rank': '1',
#   'Quality of Education Rank': '81',
#   'Alumni Employment Rank': '245',
#   'Quality of Faculty Rank': '78',
#   'Research Performance Rank': '50',
#   'Score': '84.6'},
#  {'World Rank': '52',
#   'Year': '2019-2020',
#   'Institution': 'University of British Columbia',
#   'Country': 'Canada',
#   'National Rank': '3',
#   'Quality of Education Rank': '158',
#   'Alumni Employment Rank': '662',
#   'Quality of Faculty Rank': '99',
#   'Research Performance Rank': '29',
#   'Score': '84.5'},
#  {'World Rank': '53',
#   'Year': '2019-2020',
#   'Institution': 'University of Virginia',
#   'Country': 'USA',
#   'National Rank': '35',
#   'Quality of Education Rank': '315',
#   'Alumni Employment Rank': '30',
#   'Quality of Faculty Rank': '136',
#   'Research Performance Rank': '121',
#   'Score': '84.4'},
#  {'World Rank': '54',
#   'Year': '2019-2020',
#   'Institution': 'Ohio State University',
#   'Country': 'USA',
#   'National Rank': '36',
#   'Quality of Education Rank': '113',
#   'Alumni Employment Rank': '233',
#   'Quality of Faculty Rank': '113',
#   'Research Performance Rank': '32',
#   'Score': '84.3'},
#  {'World Rank': '55',
#   'Year': '2019-2020',
#   'Institution': "King's College London",
#   'Country': 'United Kingdom',
#   'National Rank': '6',
#   'Quality of Education Rank': '62',
#   'Alumni Employment Rank': '341',
#   'Quality of Faculty Rank': '66',
#   'Research Performance Rank': '64',
#   'Score': '84.3'},
#  {'World Rank': '56',
#   'Year': '2019-2020',
#   'Institution': 'University of Oslo',
#   'Country': 'Norway',
#   'National Rank': '1',
#   'Quality of Education Rank': '30',
#   'Alumni Employment Rank': '636',
#   'Quality of Faculty Rank': '67',
#   'Research Performance Rank': '103',
#   'Score': '84.2'},
#  {'World Rank': '57',
#   'Year': '2019-2020',
#   'Institution': 'University of Colorado Boulder',
#   'Country': 'USA',
#   'National Rank': '37',
#   'Quality of Education Rank': '139',
#   'Alumni Employment Rank': '168',
#   'Quality of Faculty Rank': '29',
#   'Research Performance Rank': '81',
#   'Score': '84.1'},
#  {'World Rank': '58',
#   'Year': '2019-2020',
#   'Institution': 'Weizmann Institute of Science',
#   'Country': 'Israel',
#   'National Rank': '1',
#   'Quality of Education Rank': '17',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '34',
#   'Research Performance Rank': '232',
#   'Score': '84.0'},
#  {'World Rank': '59',
#   'Year': '2019-2020',
#   'Institution': 'Peking University',
#   'Country': 'China',
#   'National Rank': '1',
#   'Quality of Education Rank': '351',
#   'Alumni Employment Rank': '63',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '33',
#   'Score': '84.0'},
#  {'World Rank': '60',
#   'Year': '2019-2020',
#   'Institution': 'University of Manchester',
#   'Country': 'United Kingdom',
#   'National Rank': '7',
#   'Quality of Education Rank': '123',
#   'Alumni Employment Rank': '243',
#   'Quality of Faculty Rank': '77',
#   'Research Performance Rank': '49',
#   'Score': '83.9'},
#  {'World Rank': '61',
#   'Year': '2019-2020',
#   'Institution': 'Purdue University',
#   'Country': 'USA',
#   'National Rank': '38',
#   'Quality of Education Rank': '107',
#   'Alumni Employment Rank': '76',
#   'Quality of Faculty Rank': '64',
#   'Research Performance Rank': '102',
#   'Score': '83.8'},
#  {'World Rank': '62',
#   'Year': '2019-2020',
#   'Institution': 'Hebrew University of Jerusalem',
#   'Country': 'Israel',
#   'National Rank': '2',
#   'Quality of Education Rank': '25',
#   'Alumni Employment Rank': '381',
#   'Quality of Faculty Rank': '41',
#   'Research Performance Rank': '150',
#   'Score': '83.8'},
#  {'World Rank': '63',
#   'Year': '2019-2020',
#   'Institution': 'University of Pittsburgh',
#   'Country': 'USA',
#   'National Rank': '39',
#   'Quality of Education Rank': '237',
#   'Alumni Employment Rank': '210',
#   'Quality of Faculty Rank': '149',
#   'Research Performance Rank': '30',
#   'Score': '83.7'},
#  {'World Rank': '64',
#   'Year': '2019-2020',
#   'Institution': 'University of Melbourne',
#   'Country': 'Australia',
#   'National Rank': '1',
#   'Quality of Education Rank': '134',
#   'Alumni Employment Rank': '377',
#   'Quality of Faculty Rank': '135',
#   'Research Performance Rank': '34',
#   'Score': '83.6'},
#  {'World Rank': '65',
#   'Year': '2019-2020',
#   'Institution': 'University of California, Irvine',
#   'Country': 'USA',
#   'National Rank': '40',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1427',
#   'Quality of Faculty Rank': '22',
#   'Research Performance Rank': '85',
#   'Score': '83.6'},
#  {'World Rank': '66',
#   'Year': '2019-2020',
#   'Institution': 'University of California, Santa Barbara',
#   'Country': 'USA',
#   'National Rank': '41',
#   'Quality of Education Rank': '74',
#   'Alumni Employment Rank': '534',
#   'Quality of Faculty Rank': '26',
#   'Research Performance Rank': '115',
#   'Score': '83.5'},
#  {'World Rank': '67',
#   'Year': '2019-2020',
#   'Institution': 'Rockefeller University',
#   'Country': 'USA',
#   'National Rank': '42',
#   'Quality of Education Rank': '20',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '7',
#   'Research Performance Rank': '336',
#   'Score': '83.5'},
#  {'World Rank': '68',
#   'Year': '2019-2020',
#   'Institution': 'University of Zurich',
#   'Country': 'Switzerland',
#   'National Rank': '2',
#   'Quality of Education Rank': '118',
#   'Alumni Employment Rank': '713',
#   'Quality of Faculty Rank': '50',
#   'Research Performance Rank': '72',
#   'Score': '83.4'},
#  {'World Rank': '69',
#   'Year': '2019-2020',
#   'Institution': 'University of Arizona',
#   'Country': 'USA',
#   'National Rank': '43',
#   'Quality of Education Rank': '276',
#   'Alumni Employment Rank': '180',
#   'Quality of Faculty Rank': '47',
#   'Research Performance Rank': '86',
#   'Score': '83.3'},
#  {'World Rank': '70',
#   'Year': '2019-2020',
#   'Institution': 'Tsinghua University',
#   'Country': 'China',
#   'National Rank': '2',
#   'Quality of Education Rank': '403',
#   'Alumni Employment Rank': '100',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '37',
#   'Score': '83.3'},
#  {'World Rank': '71',
#   'Year': '2019-2020',
#   'Institution': 'Free University of Berlin',
#   'Country': 'Germany',
#   'National Rank': '2',
#   'Quality of Education Rank': '133',
#   'Alumni Employment Rank': '1197',
#   'Quality of Faculty Rank': '54',
#   'Research Performance Rank': '73',
#   'Score': '83.2'},
#  {'World Rank': '72',
#   'Year': '2019-2020',
#   'Institution': 'Heidelberg University',
#   'Country': 'Germany',
#   'National Rank': '3',
#   'Quality of Education Rank': '83',
#   'Alumni Employment Rank': '854',
#   'Quality of Faculty Rank': '115',
#   'Research Performance Rank': '61',
#   'Score': '83.2'},
#  {'World Rank': '73',
#   'Year': '2019-2020',
#   'Institution': 'Utrecht University',
#   'Country': 'Netherlands',
#   'National Rank': '1',
#   'Quality of Education Rank': '241',
#   'Alumni Employment Rank': '353',
#   'Quality of Faculty Rank': '143',
#   'Research Performance Rank': '42',
#   'Score': '83.1'},
#  {'World Rank': '74',
#   'Year': '2019-2020',
#   'Institution': 'Boston University',
#   'Country': 'USA',
#   'National Rank': '44',
#   'Quality of Education Rank': '487',
#   'Alumni Employment Rank': '112',
#   'Quality of Faculty Rank': '144',
#   'Research Performance Rank': '62',
#   'Score': '83.0'},
#  {'World Rank': '75',
#   'Year': '2019-2020',
#   'Institution': 'National Taiwan University',
#   'Country': 'Taiwan',
#   'National Rank': '1',
#   'Quality of Education Rank': '155',
#   'Alumni Employment Rank': '36',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '114',
#   'Score': '83.0'},
#  {'World Rank': '76',
#   'Year': '2019-2020',
#   'Institution': 'Technical University of Munich',
#   'Country': 'Germany',
#   'National Rank': '4',
#   'Quality of Education Rank': '45',
#   'Alumni Employment Rank': '323',
#   'Quality of Faculty Rank': '145',
#   'Research Performance Rank': '83',
#   'Score': '82.9'},
#  {'World Rank': '77',
#   'Year': '2019-2020',
#   'Institution': 'University of Bristol',
#   'Country': 'United Kingdom',
#   'National Rank': '8',
#   'Quality of Education Rank': '210',
#   'Alumni Employment Rank': '273',
#   'Quality of Faculty Rank': '61',
#   'Research Performance Rank': '79',
#   'Score': '82.9'},
#  {'World Rank': '78',
#   'Year': '2019-2020',
#   'Institution': 'Paris-Sud University',
#   'Country': 'France',
#   'National Rank': '4',
#   'Quality of Education Rank': '90',
#   'Alumni Employment Rank': '862',
#   'Quality of Faculty Rank': '57',
#   'Research Performance Rank': '90',
#   'Score': '82.8'},
#  {'World Rank': '79',
#   'Year': '2019-2020',
#   'Institution': 'École Polytechnique Fédérale de Lausanne',
#   'Country': 'Switzerland',
#   'National Rank': '3',
#   'Quality of Education Rank': '177',
#   'Alumni Employment Rank': '88',
#   'Quality of Faculty Rank': '121',
#   'Research Performance Rank': '104',
#   'Score': '82.8'},
#  {'World Rank': '80',
#   'Year': '2019-2020',
#   'Institution': 'Osaka University',
#   'Country': 'Japan',
#   'National Rank': '3',
#   'Quality of Education Rank': '80',
#   'Alumni Employment Rank': '56',
#   'Quality of Faculty Rank': '217',
#   'Research Performance Rank': '109',
#   'Score': '82.7'},
#  {'World Rank': '81',
#   'Year': '2019-2020',
#   'Institution': 'University of Florida',
#   'Country': 'USA',
#   'National Rank': '45',
#   'Quality of Education Rank': '243',
#   'Alumni Employment Rank': '453',
#   'Quality of Faculty Rank': '124',
#   'Research Performance Rank': '55',
#   'Score': '82.7'},
#  {'World Rank': '82',
#   'Year': '2019-2020',
#   'Institution': 'Georgia Institute of Technology',
#   'Country': 'USA',
#   'National Rank': '46',
#   'Quality of Education Rank': '193',
#   'Alumni Employment Rank': '156',
#   'Quality of Faculty Rank': '91',
#   'Research Performance Rank': '93',
#   'Score': '82.6'},
#  {'World Rank': '83',
#   'Year': '2019-2020',
#   'Institution': 'University of Utah',
#   'Country': 'USA',
#   'National Rank': '47',
#   'Quality of Education Rank': '152',
#   'Alumni Employment Rank': '175',
#   'Quality of Faculty Rank': '88',
#   'Research Performance Rank': '97',
#   'Score': '82.6'},
#  {'World Rank': '84',
#   'Year': '2019-2020',
#   'Institution': 'Carnegie Mellon University',
#   'Country': 'USA',
#   'National Rank': '48',
#   'Quality of Education Rank': '71',
#   'Alumni Employment Rank': '140',
#   'Quality of Faculty Rank': '38',
#   'Research Performance Rank': '169',
#   'Score': '82.5'},
#  {'World Rank': '85',
#   'Year': '2019-2020',
#   'Institution': 'National University of Singapore',
#   'Country': 'Singapore',
#   'National Rank': '1',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '159',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '40',
#   'Score': '82.5'},
#  {'World Rank': '86',
#   'Year': '2019-2020',
#   'Institution': 'Keio University',
#   'Country': 'Japan',
#   'National Rank': '4',
#   'Quality of Education Rank': '429',
#   'Alumni Employment Rank': '11',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '357',
#   'Score': '82.4'},
#  {'World Rank': '87',
#   'Year': '2019-2020',
#   'Institution': 'Texas A&M University, College Station',
#   'Country': 'USA',
#   'National Rank': '49',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '155',
#   'Quality of Faculty Rank': '83',
#   'Research Performance Rank': '105',
#   'Score': '82.4'},
#  {'World Rank': '88',
#   'Year': '2019-2020',
#   'Institution': 'Paris Diderot University',
#   'Country': 'France',
#   'National Rank': '5',
#   'Quality of Education Rank': '216',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '55',
#   'Research Performance Rank': '96',
#   'Score': '82.3'},
#  {'World Rank': '89',
#   'Year': '2019-2020',
#   'Institution': 'University of Alberta',
#   'Country': 'Canada',
#   'National Rank': '4',
#   'Quality of Education Rank': '404',
#   'Alumni Employment Rank': '387',
#   'Quality of Faculty Rank': '110',
#   'Research Performance Rank': '75',
#   'Score': '82.3'},
#  {'World Rank': '90',
#   'Year': '2019-2020',
#   'Institution': 'Emory University',
#   'Country': 'USA',
#   'National Rank': '50',
#   'Quality of Education Rank': '430',
#   'Alumni Employment Rank': '202',
#   'Quality of Faculty Rank': '182',
#   'Research Performance Rank': '57',
#   'Score': '82.2'},
#  {'World Rank': '91',
#   'Year': '2019-2020',
#   'Institution': 'University of Groningen',
#   'Country': 'Netherlands',
#   'National Rank': '2',
#   'Quality of Education Rank': '182',
#   'Alumni Employment Rank': '479',
#   'Quality of Faculty Rank': '98',
#   'Research Performance Rank': '78',
#   'Score': '82.2'},
#  {'World Rank': '92',
#   'Year': '2019-2020',
#   'Institution': 'Leiden University',
#   'Country': 'Netherlands',
#   'National Rank': '3',
#   'Quality of Education Rank': '98',
#   'Alumni Employment Rank': '1154',
#   'Quality of Faculty Rank': '84',
#   'Research Performance Rank': '95',
#   'Score': '82.1'},
#  {'World Rank': '93',
#   'Year': '2019-2020',
#   'Institution': 'University of Texas MD Anderson Cancer Center',
#   'Country': 'USA',
#   'National Rank': '51',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '59',
#   'Research Performance Rank': '100',
#   'Score': '82.1'},
#  {'World Rank': '94',
#   'Year': '2019-2020',
#   'Institution': 'Tufts University',
#   'Country': 'USA',
#   'National Rank': '52',
#   'Quality of Education Rank': '44',
#   'Alumni Employment Rank': '62',
#   'Quality of Faculty Rank': '127',
#   'Research Performance Rank': '207',
#   'Score': '82.0'},
#  {'World Rank': '95',
#   'Year': '2019-2020',
#   'Institution': 'Aarhus University',
#   'Country': 'Denmark',
#   'National Rank': '2',
#   'Quality of Education Rank': '164',
#   'Alumni Employment Rank': '345',
#   'Quality of Faculty Rank': '105',
#   'Research Performance Rank': '82',
#   'Score': '82.0'},
#  {'World Rank': '96',
#   'Year': '2019-2020',
#   'Institution': 'University of Chinese Academy of Sciences',
#   'Country': 'China',
#   'National Rank': '3',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1051',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '31',
#   'Score': '82.0'},
#  {'World Rank': '97',
#   'Year': '2019-2020',
#   'Institution': 'University of Rochester',
#   'Country': 'USA',
#   'National Rank': '53',
#   'Quality of Education Rank': '65',
#   'Alumni Employment Rank': '70',
#   'Quality of Faculty Rank': '198',
#   'Research Performance Rank': '136',
#   'Score': '81.9'},
#  {'World Rank': '98',
#   'Year': '2019-2020',
#   'Institution': 'Erasmus University Rotterdam',
#   'Country': 'Netherlands',
#   'National Rank': '4',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '83',
#   'Quality of Faculty Rank': '234',
#   'Research Performance Rank': '77',
#   'Score': '81.9'},
#  {'World Rank': '99',
#   'Year': '2019-2020',
#   'Institution': 'University of Maryland, College Park',
#   'Country': 'USA',
#   'National Rank': '54',
#   'Quality of Education Rank': '106',
#   'Alumni Employment Rank': '438',
#   'Quality of Faculty Rank': '201',
#   'Research Performance Rank': '60',
#   'Score': '81.8'},
#  {'World Rank': '100',
#   'Year': '2019-2020',
#   'Institution': 'University of Sydney',
#   'Country': 'Australia',
#   'National Rank': '2',
#   'Quality of Education Rank': '201',
#   'Alumni Employment Rank': '588',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '38',
#   'Score': '81.8'},
#  {'World Rank': '101',
#   'Year': '2019-2020',
#   'Institution': 'Humboldt University of Berlin',
#   'Country': 'Germany',
#   'National Rank': '5',
#   'Quality of Education Rank': '402',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '125',
#   'Research Performance Rank': '71',
#   'Score': '81.7'},
#  {'World Rank': '102',
#   'Year': '2019-2020',
#   'Institution': 'Monash University',
#   'Country': 'Australia',
#   'National Rank': '3',
#   'Quality of Education Rank': '441',
#   'Alumni Employment Rank': '390',
#   'Quality of Faculty Rank': '162',
#   'Research Performance Rank': '68',
#   'Score': '81.7'},
#  {'World Rank': '103',
#   'Year': '2019-2020',
#   'Institution': 'Uppsala University',
#   'Country': 'Sweden',
#   'National Rank': '2',
#   'Quality of Education Rank': '196',
#   'Alumni Employment Rank': '478',
#   'Quality of Faculty Rank': '111',
#   'Research Performance Rank': '98',
#   'Score': '81.7'},
#  {'World Rank': '104',
#   'Year': '2019-2020',
#   'Institution': 'University of Tübingen',
#   'Country': 'Germany',
#   'National Rank': '6',
#   'Quality of Education Rank': '50',
#   'Alumni Employment Rank': '1045',
#   'Quality of Faculty Rank': '89',
#   'Research Performance Rank': '148',
#   'Score': '81.6'},
#  {'World Rank': '105',
#   'Year': '2019-2020',
#   'Institution': 'University of Montreal',
#   'Country': 'Canada',
#   'National Rank': '5',
#   'Quality of Education Rank': '397',
#   'Alumni Employment Rank': '431',
#   'Quality of Faculty Rank': '116',
#   'Research Performance Rank': '92',
#   'Score': '81.6'},
#  {'World Rank': '106',
#   'Year': '2019-2020',
#   'Institution': 'University of Basel',
#   'Country': 'Switzerland',
#   'National Rank': '4',
#   'Quality of Education Rank': '51',
#   'Alumni Employment Rank': '290',
#   'Quality of Faculty Rank': '122',
#   'Research Performance Rank': '147',
#   'Score': '81.5'},
#  {'World Rank': '107',
#   'Year': '2019-2020',
#   'Institution': 'University of Amsterdam',
#   'Country': 'Netherlands',
#   'National Rank': '5',
#   'Quality of Education Rank': '148',
#   'Alumni Employment Rank': '926',
#   'Quality of Faculty Rank': '247',
#   'Research Performance Rank': '51',
#   'Score': '81.5'},
#  {'World Rank': '108',
#   'Year': '2019-2020',
#   'Institution': 'Australian National University',
#   'Country': 'Australia',
#   'National Rank': '4',
#   'Quality of Education Rank': '114',
#   'Alumni Employment Rank': '670',
#   'Quality of Faculty Rank': '75',
#   'Research Performance Rank': '123',
#   'Score': '81.4'},
#  {'World Rank': '109',
#   'Year': '2019-2020',
#   'Institution': 'Rice University',
#   'Country': 'USA',
#   'National Rank': '55',
#   'Quality of Education Rank': '102',
#   'Alumni Employment Rank': '81',
#   'Quality of Faculty Rank': '70',
#   'Research Performance Rank': '190',
#   'Score': '81.4'},
#  {'World Rank': '110',
#   'Year': '2019-2020',
#   'Institution': 'Tokyo Institute of Technology',
#   'Country': 'Japan',
#   'National Rank': '5',
#   'Quality of Education Rank': '183',
#   'Alumni Employment Rank': '69',
#   'Quality of Faculty Rank': '49',
#   'Research Performance Rank': '228',
#   'Score': '81.4'},
#  {'World Rank': '111',
#   'Year': '2019-2020',
#   'Institution': 'Technion – Israel Institute of Technology',
#   'Country': 'Israel',
#   'National Rank': '3',
#   'Quality of Education Rank': '57',
#   'Alumni Employment Rank': '283',
#   'Quality of Faculty Rank': '40',
#   'Research Performance Rank': '215',
#   'Score': '81.3'},
#  {'World Rank': '112',
#   'Year': '2019-2020',
#   'Institution': 'KU Leuven',
#   'Country': 'Belgium',
#   'National Rank': '1',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '395',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '53',
#   'Score': '81.3'},
#  {'World Rank': '113',
#   'Year': '2019-2020',
#   'Institution': 'University of New South Wales',
#   'Country': 'Australia',
#   'National Rank': '5',
#   'Quality of Education Rank': '466',
#   'Alumni Employment Rank': '117',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '76',
#   'Score': '81.3'},
#  {'World Rank': '114',
#   'Year': '2019-2020',
#   'Institution': 'Case Western Reserve University',
#   'Country': 'USA',
#   'National Rank': '56',
#   'Quality of Education Rank': '46',
#   'Alumni Employment Rank': '244',
#   'Quality of Faculty Rank': '195',
#   'Research Performance Rank': '127',
#   'Score': '81.2'},
#  {'World Rank': '115',
#   'Year': '2019-2020',
#   'Institution': 'University of Queensland',
#   'Country': 'Australia',
#   'National Rank': '6',
#   'Quality of Education Rank': '281',
#   'Alumni Employment Rank': '554',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '56',
#   'Score': '81.2'},
#  {'World Rank': '116',
#   'Year': '2019-2020',
#   'Institution': 'Nagoya University',
#   'Country': 'Japan',
#   'National Rank': '6',
#   'Quality of Education Rank': '59',
#   'Alumni Employment Rank': '284',
#   'Quality of Faculty Rank': '68',
#   'Research Performance Rank': '179',
#   'Score': '81.1'},
#  {'World Rank': '117',
#   'Year': '2019-2020',
#   'Institution': 'University of Nottingham',
#   'Country': 'United Kingdom',
#   'National Rank': '9',
#   'Quality of Education Rank': '218',
#   'Alumni Employment Rank': '394',
#   'Quality of Faculty Rank': '72',
#   'Research Performance Rank': '128',
#   'Score': '81.1'},
#  {'World Rank': '118',
#   'Year': '2019-2020',
#   'Institution': 'KTH Royal Institute of Technology',
#   'Country': 'Sweden',
#   'National Rank': '3',
#   'Quality of Education Rank': '132',
#   'Alumni Employment Rank': '44',
#   'Quality of Faculty Rank': '130',
#   'Research Performance Rank': '218',
#   'Score': '81.1'},
#  {'World Rank': '119',
#   'Year': '2019-2020',
#   'Institution': 'Shanghai Jiao Tong University',
#   'Country': 'China',
#   'National Rank': '4',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '216',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '69',
#   'Score': '81.0'},
#  {'World Rank': '120',
#   'Year': '2019-2020',
#   'Institution': 'University of Geneva',
#   'Country': 'Switzerland',
#   'National Rank': '5',
#   'Quality of Education Rank': '78',
#   'Alumni Employment Rank': '359',
#   'Quality of Faculty Rank': '160',
#   'Research Performance Rank': '122',
#   'Score': '81.0'},
#  {'World Rank': '121',
#   'Year': '2019-2020',
#   'Institution': 'Zhejiang University',
#   'Country': 'China',
#   'National Rank': '5',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '475',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '63',
#   'Score': '81.0'},
#  {'World Rank': '122',
#   'Year': '2019-2020',
#   'Institution': 'University of Birmingham',
#   'Country': 'United Kingdom',
#   'National Rank': '10',
#   'Quality of Education Rank': '85',
#   'Alumni Employment Rank': '356',
#   'Quality of Faculty Rank': '171',
#   'Research Performance Rank': '113',
#   'Score': '80.9'},
#  {'World Rank': '123',
#   'Year': '2019-2020',
#   'Institution': 'Baylor College of Medicine',
#   'Country': 'USA',
#   'National Rank': '57',
#   'Quality of Education Rank': '175',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '101',
#   'Research Performance Rank': '125',
#   'Score': '80.9'},
#  {'World Rank': '124',
#   'Year': '2019-2020',
#   'Institution': 'University of Freiburg',
#   'Country': 'Germany',
#   'National Rank': '7',
#   'Quality of Education Rank': '84',
#   'Alumni Employment Rank': '200',
#   'Quality of Faculty Rank': '118',
#   'Research Performance Rank': '152',
#   'Score': '80.8'},
#  {'World Rank': '125',
#   'Year': '2019-2020',
#   'Institution': 'University of Southampton',
#   'Country': 'United Kingdom',
#   'National Rank': '11',
#   'Quality of Education Rank': '468',
#   'Alumni Employment Rank': '328',
#   'Quality of Faculty Rank': '134',
#   'Research Performance Rank': '112',
#   'Score': '80.8'},
#  {'World Rank': '126',
#   'Year': '2019-2020',
#   'Institution': 'University of Western Australia',
#   'Country': 'Australia',
#   'National Rank': '7',
#   'Quality of Education Rank': '101',
#   'Alumni Employment Rank': '671',
#   'Quality of Faculty Rank': '128',
#   'Research Performance Rank': '124',
#   'Score': '80.8'},
#  {'World Rank': '127',
#   'Year': '2019-2020',
#   'Institution': 'McMaster University',
#   'Country': 'Canada',
#   'National Rank': '6',
#   'Quality of Education Rank': '153',
#   'Alumni Employment Rank': '673',
#   'Quality of Faculty Rank': '153',
#   'Research Performance Rank': '108',
#   'Score': '80.7'},
#  {'World Rank': '128',
#   'Year': '2019-2020',
#   'Institution': 'University of São Paulo',
#   'Country': 'Brazil',
#   'National Rank': '1',
#   'Quality of Education Rank': '457',
#   'Alumni Employment Rank': '264',
#   'Quality of Faculty Rank': '219',
#   'Research Performance Rank': '89',
#   'Score': '80.7'},
#  {'World Rank': '129',
#   'Year': '2019-2020',
#   'Institution': 'University of Barcelona',
#   'Country': 'Spain',
#   'National Rank': '1',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '450',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '74',
#   'Score': '80.7'},
#  {'World Rank': '130',
#   'Year': '2019-2020',
#   'Institution': 'Nanyang Technological University',
#   'Country': 'Singapore',
#   'National Rank': '2',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1186',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '67',
#   'Score': '80.6'},
#  {'World Rank': '131',
#   'Year': '2019-2020',
#   'Institution': 'INSEAD',
#   'Country': 'France',
#   'National Rank': '6',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '2',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '1583',
#   'Score': '80.6'},
#  {'World Rank': '132',
#   'Year': '2019-2020',
#   'Institution': 'Fudan University',
#   'Country': 'China',
#   'National Rank': '6',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '167',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '99',
#   'Score': '80.6'},
#  {'World Rank': '133',
#   'Year': '2019-2020',
#   'Institution': 'University of Strasbourg',
#   'Country': 'France',
#   'National Rank': '7',
#   'Quality of Education Rank': '99',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '32',
#   'Research Performance Rank': '208',
#   'Score': '80.5'},
#  {'World Rank': '134',
#   'Year': '2019-2020',
#   'Institution': 'University of Helsinki',
#   'Country': 'Finland',
#   'National Rank': '1',
#   'Quality of Education Rank': '417',
#   'Alumni Employment Rank': '1007',
#   'Quality of Faculty Rank': '226',
#   'Research Performance Rank': '80',
#   'Score': '80.5'},
#  {'World Rank': '135',
#   'Year': '2019-2020',
#   'Institution': 'University of Bonn',
#   'Country': 'Germany',
#   'National Rank': '8',
#   'Quality of Education Rank': '110',
#   'Alumni Employment Rank': '472',
#   'Quality of Faculty Rank': '112',
#   'Research Performance Rank': '149',
#   'Score': '80.5'},
#  {'World Rank': '136',
#   'Year': '2019-2020',
#   'Institution': 'Ghent University',
#   'Country': 'Belgium',
#   'National Rank': '2',
#   'Quality of Education Rank': '415',
#   'Alumni Employment Rank': '621',
#   'Quality of Faculty Rank': '233',
#   'Research Performance Rank': '84',
#   'Score': '80.4'},
#  {'World Rank': '137',
#   'Year': '2019-2020',
#   'Institution': 'University of Glasgow',
#   'Country': 'United Kingdom',
#   'National Rank': '12',
#   'Quality of Education Rank': '282',
#   'Alumni Employment Rank': '280',
#   'Quality of Faculty Rank': '164',
#   'Research Performance Rank': '119',
#   'Score': '80.4'},
#  {'World Rank': '138',
#   'Year': '2019-2020',
#   'Institution': 'Sapienza University of Rome',
#   'Country': 'Italy',
#   'National Rank': '1',
#   'Quality of Education Rank': '421',
#   'Alumni Employment Rank': '454',
#   'Quality of Faculty Rank': '155',
#   'Research Performance Rank': '117',
#   'Score': '80.4'},
#  {'World Rank': '139',
#   'Year': '2019-2020',
#   'Institution': 'Cardiff University',
#   'Country': 'United Kingdom',
#   'National Rank': '13',
#   'Quality of Education Rank': '310',
#   'Alumni Employment Rank': '480',
#   'Quality of Faculty Rank': '58',
#   'Research Performance Rank': '166',
#   'Score': '80.3'},
#  {'World Rank': '140',
#   'Year': '2019-2020',
#   'Institution': 'University of Notre Dame',
#   'Country': 'USA',
#   'National Rank': '58',
#   'Quality of Education Rank': '147',
#   'Alumni Employment Rank': '33',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '277',
#   'Score': '80.3'},
#  {'World Rank': '141',
#   'Year': '2019-2020',
#   'Institution': 'Lund University',
#   'Country': 'Sweden',
#   'National Rank': '4',
#   'Quality of Education Rank': '203',
#   'Alumni Employment Rank': '684',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '87',
#   'Score': '80.3'},
#  {'World Rank': '142',
#   'Year': '2019-2020',
#   'Institution': 'University of Iowa',
#   'Country': 'USA',
#   'National Rank': '59',
#   'Quality of Education Rank': '197',
#   'Alumni Employment Rank': '300',
#   'Quality of Faculty Rank': '142',
#   'Research Performance Rank': '134',
#   'Score': '80.2'},
#  {'World Rank': '143',
#   'Year': '2019-2020',
#   'Institution': 'Tel Aviv University',
#   'Country': 'Israel',
#   'National Rank': '4',
#   'Quality of Education Rank': '401',
#   'Alumni Employment Rank': '136',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '116',
#   'Score': '80.2'},
#  {'World Rank': '144',
#   'Year': '2019-2020',
#   'Institution': 'Radboud University',
#   'Country': 'Netherlands',
#   'National Rank': '6',
#   'Quality of Education Rank': '163',
#   'Alumni Employment Rank': '571',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '94',
#   'Score': '80.2'},
#  {'World Rank': '145',
#   'Year': '2019-2020',
#   'Institution': 'Grenoble Alpes University',
#   'Country': 'France',
#   'National Rank': '8',
#   'Quality of Education Rank': '317',
#   'Alumni Employment Rank': '1227',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '88',
#   'Score': '80.2'},
#  {'World Rank': '146',
#   'Year': '2019-2020',
#   'Institution': 'VU Amsterdam',
#   'Country': 'Netherlands',
#   'National Rank': '7',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1015',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '91',
#   'Score': '80.1'},
#  {'World Rank': '147',
#   'Year': '2019-2020',
#   'Institution': 'Brandeis University',
#   'Country': 'USA',
#   'National Rank': '60',
#   'Quality of Education Rank': '21',
#   'Alumni Employment Rank': '227',
#   'Quality of Faculty Rank': '27',
#   'Research Performance Rank': '520',
#   'Score': '80.1'},
#  {'World Rank': '148',
#   'Year': '2019-2020',
#   'Institution': 'Icahn School of Medicine at Mount Sinai',
#   'Country': 'USA',
#   'National Rank': '61',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '210',
#   'Research Performance Rank': '107',
#   'Score': '80.1'},
#  {'World Rank': '149',
#   'Year': '2019-2020',
#   'Institution': 'University of Colorado Denver | Anschutz Medical Campus',
#   'Country': 'USA',
#   'National Rank': '62',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '100',
#   'Research Performance Rank': '154',
#   'Score': '80.0'},
#  {'World Rank': '150',
#   'Year': '2019-2020',
#   'Institution': 'University of Science and Technology of China',
#   'Country': 'China',
#   'National Rank': '7',
#   'Quality of Education Rank': '385',
#   'Alumni Employment Rank': '360',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '106',
#   'Score': '80.0'},
#  {'World Rank': '151',
#   'Year': '2019-2020',
#   'Institution': 'Aix-Marseille University',
#   'Country': 'France',
#   'National Rank': '9',
#   'Quality of Education Rank': '494',
#   'Alumni Employment Rank': '924',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '101',
#   'Score': '80.0'},
#  {'World Rank': '152',
#   'Year': '2019-2020',
#   'Institution': 'Indiana University Bloomington',
#   'Country': 'USA',
#   'National Rank': '63',
#   'Quality of Education Rank': '162',
#   'Alumni Employment Rank': '75',
#   'Quality of Faculty Rank': '188',
#   'Research Performance Rank': '193',
#   'Score': '79.9'},
#  {'World Rank': '153',
#   'Year': '2019-2020',
#   'Institution': 'Michigan State University',
#   'Country': 'USA',
#   'National Rank': '64',
#   'Quality of Education Rank': '263',
#   'Alumni Employment Rank': '258',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '110',
#   'Score': '79.9'},
#  {'World Rank': '154',
#   'Year': '2019-2020',
#   'Institution': 'University of Göttingen',
#   'Country': 'Germany',
#   'National Rank': '9',
#   'Quality of Education Rank': '56',
#   'Alumni Employment Rank': '292',
#   'Quality of Faculty Rank': '237',
#   'Research Performance Rank': '158',
#   'Score': '79.9'},
#  {'World Rank': '155',
#   'Year': '2019-2020',
#   'Institution': 'Goethe University Frankfurt',
#   'Country': 'Germany',
#   'National Rank': '10',
#   'Quality of Education Rank': '217',
#   'Alumni Employment Rank': '693',
#   'Quality of Faculty Rank': '76',
#   'Research Performance Rank': '186',
#   'Score': '79.9'},
#  {'World Rank': '156',
#   'Year': '2019-2020',
#   'Institution': 'University of Gothenburg',
#   'Country': 'Sweden',
#   'National Rank': '5',
#   'Quality of Education Rank': '405',
#   'Alumni Employment Rank': '396',
#   'Quality of Faculty Rank': '94',
#   'Research Performance Rank': '176',
#   'Score': '79.8'},
#  {'World Rank': '157',
#   'Year': '2019-2020',
#   'Institution': 'University of Bern',
#   'Country': 'Switzerland',
#   'National Rank': '6',
#   'Quality of Education Rank': '169',
#   'Alumni Employment Rank': '1212',
#   'Quality of Faculty Rank': '166',
#   'Research Performance Rank': '133',
#   'Score': '79.8'},
#  {'World Rank': '158',
#   'Year': '2019-2020',
#   'Institution': 'Tohoku University',
#   'Country': 'Japan',
#   'National Rank': '7',
#   'Quality of Education Rank': '140',
#   'Alumni Employment Rank': '147',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '135',
#   'Score': '79.8'},
#  {'World Rank': '159',
#   'Year': '2019-2020',
#   'Institution': 'University of Massachusetts Amherst',
#   'Country': 'USA',
#   'National Rank': '65',
# ...
#   'Country': 'Canada',
#   'National Rank': '27',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '911',
#   'Score': '70.6'},
#  {'World Rank': '949',
#   'Year': '2019-2020',
#   'Institution': 'University of Technology, Malaysia',
#   'Country': 'Malaysia',
#   'National Rank': '5',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '912',
#   'Score': '70.6'},
#  {'World Rank': '950',
#   'Year': '2019-2020',
#   'Institution': 'University of Toyama',
#   'Country': 'Japan',
#   'National Rank': '47',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '471',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '939',
#   'Score': '70.6'},
#  {'World Rank': '951',
#   'Year': '2019-2020',
#   'Institution': 'Shiraz University',
#   'Country': 'Iran',
#   'National Rank': '10',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '913',
#   'Score': '70.6'},
#  {'World Rank': '952',
#   'Year': '2019-2020',
#   'Institution': 'China Pharmaceutical University',
#   'Country': 'China',
#   'National Rank': '102',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1194',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '915',
#   'Score': '70.6'},
#  {'World Rank': '953',
#   'Year': '2019-2020',
#   'Institution': 'Nara Institute of Science and Technology',
#   'Country': 'Japan',
#   'National Rank': '48',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '914',
#   'Score': '70.6'},
#  {'World Rank': '954',
#   'Year': '2019-2020',
#   'Institution': 'Northumbria University',
#   'Country': 'United Kingdom',
#   'National Rank': '62',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '829',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '921',
#   'Score': '70.6'},
#  {'World Rank': '955',
#   'Year': '2019-2020',
#   'Institution': 'University of Bucharest',
#   'Country': 'Romania',
#   'National Rank': '3',
#   'Quality of Education Rank': '419',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '918',
#   'Score': '70.6'},
#  {'World Rank': '956',
#   'Year': '2019-2020',
#   'Institution': 'Florida Institute of Technology',
#   'Country': 'USA',
#   'National Rank': '210',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '584',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '935',
#   'Score': '70.5'},
#  {'World Rank': '957',
#   'Year': '2019-2020',
#   'Institution': 'Xiangtan University',
#   'Country': 'China',
#   'National Rank': '103',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '954',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '920',
#   'Score': '70.5'},
#  {'World Rank': '958',
#   'Year': '2019-2020',
#   'Institution': 'Federal University of ABC',
#   'Country': 'Brazil',
#   'National Rank': '20',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '922',
#   'Score': '70.5'},
#  {'World Rank': '959',
#   'Year': '2019-2020',
#   'Institution': 'COMSATS University Islamabad',
#   'Country': 'Pakistan',
#   'National Rank': '3',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '923',
#   'Score': '70.5'},
#  {'World Rank': '960',
#   'Year': '2019-2020',
#   'Institution': 'Metropolitan Autonomous University',
#   'Country': 'Mexico',
#   'National Rank': '4',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '924',
#   'Score': '70.5'},
#  {'World Rank': '961',
#   'Year': '2019-2020',
#   'Institution': 'Anhui University',
#   'Country': 'China',
#   'National Rank': '104',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '957',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '927',
#   'Score': '70.5'},
#  {'World Rank': '962',
#   'Year': '2019-2020',
#   'Institution': 'Nicolaus Copernicus University',
#   'Country': 'Poland',
#   'National Rank': '12',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '925',
#   'Score': '70.5'},
#  {'World Rank': '963',
#   'Year': '2019-2020',
#   'Institution': 'Åbo Akademi University',
#   'Country': 'Finland',
#   'National Rank': '8',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '926',
#   'Score': '70.5'},
#  {'World Rank': '964',
#   'Year': '2019-2020',
#   'Institution': 'American University',
#   'Country': 'USA',
#   'National Rank': '211',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '340',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '974',
#   'Score': '70.5'},
#  {'World Rank': '965',
#   'Year': '2019-2020',
#   'Institution': 'Guangzhou Medical University',
#   'Country': 'China',
#   'National Rank': '105',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '928',
#   'Score': '70.5'},
#  {'World Rank': '966',
#   'Year': '2019-2020',
#   'Institution': 'Creighton University',
#   'Country': 'USA',
#   'National Rank': '212',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '929',
#   'Score': '70.5'},
#  {'World Rank': '967',
#   'Year': '2019-2020',
#   'Institution': 'Hangzhou Normal University',
#   'Country': 'China',
#   'National Rank': '106',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1397',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '930',
#   'Score': '70.5'},
#  {'World Rank': '968',
#   'Year': '2019-2020',
#   'Institution': 'SUNY Upstate Medical University',
#   'Country': 'USA',
#   'National Rank': '213',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '931',
#   'Score': '70.5'},
#  {'World Rank': '969',
#   'Year': '2019-2020',
#   'Institution': 'Indian Institute of Technology Guwahati',
#   'Country': 'India',
#   'National Rank': '15',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '932',
#   'Score': '70.5'},
#  {'World Rank': '970',
#   'Year': '2019-2020',
#   'Institution': 'Auckland University of Technology',
#   'Country': 'New Zealand',
#   'National Rank': '6',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '933',
#   'Score': '70.5'},
#  {'World Rank': '971',
#   'Year': '2019-2020',
#   'Institution': 'Royal College of Surgeons in Ireland',
#   'Country': 'Ireland',
#   'National Rank': '6',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '934',
#   'Score': '70.5'},
#  {'World Rank': '972',
#   'Year': '2019-2020',
#   'Institution': 'New Jersey Institute of Technology',
#   'Country': 'USA',
#   'National Rank': '214',
#   'Quality of Education Rank': '412',
#   'Alumni Employment Rank': '712',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '942',
#   'Score': '70.5'},
#  {'World Rank': '973',
#   'Year': '2019-2020',
#   'Institution': 'Jichi Medical University',
#   'Country': 'Japan',
#   'National Rank': '49',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '936',
#   'Score': '70.4'},
#  {'World Rank': '974',
#   'Year': '2019-2020',
#   'Institution': 'Jawaharlal Nehru University',
#   'Country': 'India',
#   'National Rank': '16',
#   'Quality of Education Rank': '93',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '203',
#   'Research Performance Rank': '1196',
#   'Score': '70.4'},
#  {'World Rank': '975',
#   'Year': '2019-2020',
#   'Institution': 'Hallym University',
#   'Country': 'South Korea',
#   'National Rank': '34',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '938',
#   'Score': '70.4'},
#  {'World Rank': '976',
#   'Year': '2019-2020',
#   'Institution': 'Shanghai Normal University',
#   'Country': 'China',
#   'National Rank': '107',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1225',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '940',
#   'Score': '70.4'},
#  {'World Rank': '977',
#   'Year': '2019-2020',
#   'Institution': 'Alexandria University',
#   'Country': 'Egypt',
#   'National Rank': '4',
#   'Quality of Education Rank': '285',
#   'Alumni Employment Rank': '1469',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '944',
#   'Score': '70.4'},
#  {'World Rank': '978',
#   'Year': '2019-2020',
#   'Institution': 'Hunter College',
#   'Country': 'USA',
#   'National Rank': '215',
#   'Quality of Education Rank': '244',
#   'Alumni Employment Rank': '1142',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '951',
#   'Score': '70.4'},
#  {'World Rank': '979',
#   'Year': '2019-2020',
#   'Institution': 'University of Mannheim',
#   'Country': 'Germany',
#   'National Rank': '53',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '889',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '945',
#   'Score': '70.4'},
#  {'World Rank': '980',
#   'Year': '2019-2020',
#   'Institution': 'Postgraduate Institute of Medical Education and Research',
#   'Country': 'India',
#   'National Rank': '17',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '941',
#   'Score': '70.4'},
#  {'World Rank': '981',
#   'Year': '2019-2020',
#   'Institution': 'King Juan Carlos University',
#   'Country': 'Spain',
#   'National Rank': '35',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '943',
#   'Score': '70.4'},
#  {'World Rank': '982',
#   'Year': '2019-2020',
#   'Institution': 'Guangdong University of Technology',
#   'Country': 'China',
#   'National Rank': '108',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '946',
#   'Score': '70.4'},
#  {'World Rank': '983',
#   'Year': '2019-2020',
#   'Institution': 'Tomsk State University',
#   'Country': 'Russia',
#   'National Rank': '7',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '947',
#   'Score': '70.4'},
#  {'World Rank': '984',
#   'Year': '2019-2020',
#   'Institution': 'Ningbo University',
#   'Country': 'China',
#   'National Rank': '109',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1444',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '949',
#   'Score': '70.4'},
#  {'World Rank': '985',
#   'Year': '2019-2020',
#   'Institution': 'Zhejiang Normal University',
#   'Country': 'China',
#   'National Rank': '110',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '948',
#   'Score': '70.4'},
#  {'World Rank': '986',
#   'Year': '2019-2020',
#   'Institution': 'Dankook University',
#   'Country': 'South Korea',
#   'National Rank': '35',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1443',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '950',
#   'Score': '70.4'},
#  {'World Rank': '987',
#   'Year': '2019-2020',
#   'Institution': 'Anhui Medical University',
#   'Country': 'China',
#   'National Rank': '111',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '952',
#   'Score': '70.4'},
#  {'World Rank': '988',
#   'Year': '2019-2020',
#   'Institution': 'Howard University',
#   'Country': 'USA',
#   'National Rank': '216',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '953',
#   'Score': '70.4'},
#  {'World Rank': '989',
#   'Year': '2019-2020',
#   'Institution': 'Toulouse 1 Capitole University',
#   'Country': 'France',
#   'National Rank': '58',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '191',
#   'Research Performance Rank': '1083',
#   'Score': '70.3'},
#  {'World Rank': '990',
#   'Year': '2019-2020',
#   'Institution': 'Khalifa University',
#   'Country': 'United Arab Emirates',
#   'National Rank': '1',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '954',
#   'Score': '70.3'},
#  {'World Rank': '991',
#   'Year': '2019-2020',
#   'Institution': 'Florida Atlantic University',
#   'Country': 'USA',
#   'National Rank': '217',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '955',
#   'Score': '70.3'},
#  {'World Rank': '992',
#   'Year': '2019-2020',
#   'Institution': 'Capital Normal University',
#   'Country': 'China',
#   'National Rank': '112',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '923',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '959',
#   'Score': '70.3'},
#  {'World Rank': '993',
#   'Year': '2019-2020',
#   'Institution': 'Paderborn University',
#   'Country': 'Germany',
#   'National Rank': '54',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '1235',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '956',
#   'Score': '70.3'},
#  {'World Rank': '994',
#   'Year': '2019-2020',
#   'Institution': 'New York Medical College',
#   'Country': 'USA',
#   'National Rank': '218',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '957',
#   'Score': '70.3'},
#  {'World Rank': '995',
#   'Year': '2019-2020',
#   'Institution': 'Medical University of Gdańsk',
#   'Country': 'Poland',
#   'National Rank': '13',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '958',
#   'Score': '70.3'},
#  {'World Rank': '996',
#   'Year': '2019-2020',
#   'Institution': 'University of Augsburg',
#   'Country': 'Germany',
#   'National Rank': '55',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '960',
#   'Score': '70.3'},
#  {'World Rank': '997',
#   'Year': '2019-2020',
#   'Institution': 'Aston University',
#   'Country': 'United Kingdom',
#   'National Rank': '63',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '631',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '970',
#   'Score': '70.3'},
#  {'World Rank': '998',
#   'Year': '2019-2020',
#   'Institution': 'Henan University',
#   'Country': 'China',
#   'National Rank': '113',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '961',
#   'Score': '70.3'},
#  {'World Rank': '999',
#   'Year': '2019-2020',
#   'Institution': 'Guangxi University',
#   'Country': 'China',
#   'National Rank': '114',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '962',
#   'Score': '70.3'},
#  {'World Rank': '1000',
#   'Year': '2019-2020',
#   'Institution': 'Federal University of Rio Grande do Norte',
#   'Country': 'Brazil',
#   'National Rank': '21',
#   'Quality of Education Rank': '-',
#   'Alumni Employment Rank': '-',
#   'Quality of Faculty Rank': '-',
#   'Research Performance Rank': '963',
#   'Score': '70.3'},
#  ...]

# %% [markdown]
# ### Task 4.8 (Optional) Write the parse_html function
#
# Convert tasks 4.2 to 4.7 to a function. The function should take in a `filename` as input and return a list of dictionaries, each dictionary representing a row in the dataset.

# %%
def parse_html(filename):
    '''This function parses an HTML file and returns a list of dictionaries containing the tabular data'''
    #TODO: Write your code here
    
    file_obj = open(filename, "r")
    content = file_obj.read()
    file_obj.close()

    bs_obj = BeautifulSoup(content, "html.parser")
    
    table = bs_obj.find('table')
    
    header = [th.get_text() for th in table.find_all("th")]

    table_rows = table.find_all("tr")

    data = table_rows[1:]

    rankings_list = []
    rankings_dict = {}

    world_rank_idx = header.index('World Rank')
    institution_idx = header.index('Institution')
    country_idx = header.index('Country')
    national_rank_idx = header.index('National Rank')
    qual_edu_rank_idx = header.index('Quality of Education Rank')
    alumni_emp_rank_idx = header.index('Alumni Employment Rank')
    qual_faculty_rank_idx = header.index('Quality of Faculty Rank')
    research_perf_rank_idx = header.index('Research Performance Rank')
    score_idx = header.index('Score')

    for row in data:
        try:
            row_data = row.find_all('td')
            
            year_data = row.find('a')
            year = "".join([v[:9] for (k,v) in year_data.attrs.items()])

            world_rank = row_data[world_rank_idx].get_text()
            institution = row_data[institution_idx].get_text()
            country = row_data[country_idx].get_text()
            national_rank = row_data[national_rank_idx].get_text()
            qual_edu_rank = row_data[qual_edu_rank_idx].get_text()
            alumni_emp_rank = row_data[alumni_emp_rank_idx].get_text()
            qual_faculty_rank = row_data[qual_faculty_rank_idx].get_text()
            research_perf_rank = row_data[research_perf_rank_idx].get_text()
            score = row_data[score_idx].get_text()

            int_list = [world_rank, national_rank, qual_edu_rank, alumni_emp_rank, \
                        qual_faculty_rank, research_perf_rank]

            float_list = [score]

            for item in int_list:
                if item != "-":
                    item = int(item)
                    
            for item in float_list:
                if item != "-":
                    item = float(item)

            rankings_dict = { 'World Rank': world_rank,
                              'Year': year,
                              'Institution': institution, 
                              'Country': country, 
                              'National Rank': national_rank, 
                              'Quality of Education Rank': qual_edu_rank,
                              'Alumni Employment Rank': alumni_emp_rank,
                              'Quality of Faculty Rank': qual_faculty_rank,
                              'Research Performance Rank': research_perf_rank,
                              'Score': score
                             }

            rankings_list.append(rankings_dict)

        except ValueError:
            continue

    return rankings_list

# %% [markdown]
# Finally, test your code below.

# %%
file1 = parse_html("2019-2020.html")
print(len(file1))

file2 = parse_html("2020-2021.html")
print(len(file2))

file3 = parse_html("2021-2022.html")
print(len(file3))
# Out:
# 2000
# 2000
# 2000

# %%
print(file1[-1]["Institution"])
print(file1[50]["Quality of Faculty Rank"])
print(file1[0]["Year"])

print(file2[15]["Score"])
print(file2[-5]["National Rank"])
print(file2[40]["Research Performance Rank"])

print(file3[87]["Alumni Employment Rank"])
print(file3[100]["Country"])
print(file3[25]["World Rank"])
# Out:
# Government College University Faisalabad
# 78
# 2019-2020
# 89.0
# 15
# 398
# 464
# United Kingdom
# 26

# %%
assert(file1[-1]["Institution"] == 'Government College University Faisalabad')
assert(file1[50]["Quality of Faculty Rank"] == 78)
assert(file1[0]["Year"] == '2019-2020')

assert(file2[15]["Score"] == 89.0)
assert(file2[-5]["National Rank"] == 15)
assert(file2[40]["Research Performance Rank"] == 398)

assert(file3[87]["Alumni Employment Rank"] == 464)
assert(file3[100]["Country"] == 'United Kingdom')
assert(file3[25]["World Rank"] == 26)

# %%
print(parse_html("2019-2020.html")[-1]["Institution"])
print(parse_html("2019-2020.html")[50]["Quality of Faculty Rank"])
print(parse_html("2019-2020.html")[0]["Year"])

print(parse_html("2020-2021.html")[15]["Score"] )
print(parse_html("2020-2021.html")[-5]["National Rank"])
print(parse_html("2020-2021.html")[40]["Research Performance Rank"])

print(parse_html("2021-2022.html")[87]["Alumni Employment Rank"])
print(parse_html("2021-2022.html")[100]["Country"])
print(parse_html("2021-2022.html")[25]["World Rank"])
# Out:
# Government College University Faisalabad
# 78
# 2019-2020
# 89.0
# 15
# 398
# 464
# United Kingdom
# 26

# %%
# assert(parse_html("2019-2020.html")[-1]["Institution"] == 'Government College University Faisalabad')
# assert(parse_html("2019-2020.html")[50]["Quality of Faculty Rank"] == 78)
# assert(parse_html("2019-2020.html")[0]["Year"] == "2019-2020")

# assert(parse_html("2020-2021.html")[15]["Score"] == 89.0)
# assert(parse_html("2020-2021.html")[-5]["National Rank"] == 15)
# assert(parse_html("2020-2021.html")[40]["Research Performance Rank"] == 398)

# assert(parse_html("2021-2022.html")[87]["Alumni Employment Rank"] == 464)
# assert(parse_html("2021-2022.html")[100]["Country"] == 'United Kingdom')
# assert(parse_html("2021-2022.html")[25]["World Rank"] == 26)

# %%
# assert(parse_html("2019-2020.html")[-1]["Institution"] == 'Government College University Faisalabad')
# assert(parse_html("2020-2021.html")[15]["Score"] == 89.0)
# assert(parse_html("2021-2022.html")[100]["Country"] == 'United Kingdom')
# assert(parse_html("2021-2022.html")[25]["World Rank"] == 26)
# assert(parse_html("2020-2021.html")[-5]["National Rank"] == 15)
# assert(parse_html("2019-2020.html")[50]["Quality of Faculty Rank"] == 78)
# assert(parse_html("2021-2022.html")[87]["Alumni Employment Rank"] == 464)
# assert(parse_html("2020-2021.html")[40]["Research Performance Rank"] == 398)
# assert(parse_html("2019-2020.html")[0]["Year"] == "2019-2020")

# %% [markdown]
# ### Congratulations, you are now ready to start p12!
